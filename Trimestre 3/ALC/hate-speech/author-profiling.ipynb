# %%
import numpy as np
import os
import pickle

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Activation, Concatenate
from keras.layers import Embedding, LSTM, Bidirectional, Flatten
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D
from keras.optimizers import SGD, Adam
from keras.callbacks import ModelCheckpoint, CSVLogger
from keras.callbacks import LearningRateScheduler as LRS
from keras.models import load_model
from keras.utils import plot_model

import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import string
import re

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from transformers import TFBertForSequenceClassification

# %%
# !mkdir models
kaggle_path_pickle = '/kaggle/input/bert-preprocesed-author-profiling/'
kaggle_path_models = '/kaggle/working/'

# %%
def configure_callbacks(model_id, kpi_to_monitor='val_accuracy'):
    # Without log/ or models/ subfolder as not possible to access unexisting folders
    # If possible to train with jupyter revise
    path = kaggle_path_models + "models"
    name = "ap"
    
    log_filename = '%s/%s-%s.log' % (path,name, model_id)
    csv_logger = CSVLogger(log_filename)
    
    chk_1_model_filename = '%s/%s-%s-{epoch:04d}-{%s:.6f}.h5' % (path, name, model_id, kpi_to_monitor)
    chk_2_model_filename = '%s/%s-%s.h5' % (path, name, model_id)
    
    # Save best model fully not only weights after each epoch (period=1) 
    # with best accuracy value (mode=max, save_best_only=True)
    checkpoint1 = ModelCheckpoint(
        chk_1_model_filename,
        monitor=kpi_to_monitor,
        save_best_only=True,
        save_weights_only=False, 
        verbose=1, mode='max', period=1
    )

    checkpoint2 = ModelCheckpoint(
        chk_2_model_filename, 
        monitor=kpi_to_monitor,
        save_best_only=False,
        save_weights_only=False, 
        verbose=1, mode='auto', period=1
    )

    callbacks = [csv_logger, checkpoint1, checkpoint2]
    return callbacks

# %%
######### AUTHOR PROFILING FUNCTION FOR JOINING PREDICTIONS #########

# de 20 0s y 20 1s

def author_profiling_report(author_profile, number_authors=40):
    n = int(number_authors/2)
    a = np.zeros(n)
    b = np.ones(n)        
    author_profile = np.concatenate([a,b])
    
    # Check author profiling -> 8,000 predictions
    # Split into 40 authors -> 200 tweets per author
    author_predictions = np.average(np.array_split(predictions, number_authors), axis=1)
    author_predictions = np.array([1 if ap >= 0.5 else 0 for ap in author_predictions])

    print(classification_report(author_profile, author_predictions, labels=[0, 1], target_names=['not hate','hate']))

# %%
pickle_file = open(kaggle_path_pickle+'es_20.pickle', 'rb')
es_20 = pickle.load(pickle_file)

train_padded_es_20, y_train_es_20 = es_20[0], es_20[1]
valid_padded_es_20, y_valid_es_20 = es_20[2], es_20[3]
test_padded_es_20 = es_20[4]

pickle_file = open(kaggle_path_pickle+'en_20.pickle', 'rb')
en_20 = pickle.load(pickle_file)

train_padded_en_20, y_train_en_20 = en_20[0], en_20[1]
valid_padded_en_20, y_valid_en_20 = en_20[2], en_20[3]
test_padded_en_20 = en_20[4]

# Define a learning rate scheduler
def scheduler(epoch):
    if epoch < 25:
        return 0.001
    elif epoch < 50:
        return 0.0005
    elif epoch < 75:
        return 0.0001
    else:
        return 0.00005

scheduler_lr = LRS(scheduler)
# Optimizer
adam = Adam(learning_rate=0.001)
epochs = 100

# %%
# ES 20 JOINED TWEETS - TRAINABLE EMB COMPLEXER NET
max_words = 10000
word_embedding_size = 300
max_length = 250

model10 = Sequential()
model10.add(Embedding(max_words,
                    output_dim=word_embedding_size,
                    #weights=[embedding_matrix_en_indv], # embeddings
                    input_length=max_length,
                    trainable=True, # Changed to True
                    mask_zero=True))
model10.add(LSTM(units=512, return_sequences=True))
model10.add(LSTM(units=512, return_sequences=True))
model10.add(LSTM(units=512, return_sequences=True))
model10.add(LSTM(units=512, return_sequences=True))
model10.add(LSTM(units=512))
model10.add(Dense(1, activation='sigmoid'))

model10.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
model10.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 250, 300)          3000000
# _________________________________________________________________
# lstm (LSTM)                  (None, 250, 512)          1665024
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 250, 512)          2099200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 250, 512)          2099200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 250, 512)          2099200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 513
# =================================================================
# Total params: 13,062,337
# Trainable params: 13,062,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_10_es = model10
model_id = 'model_10_es'

model_10_es.fit(x=train_padded_es_20,
                y=y_train_es_20,
                batch_size=128,
                validation_data=(valid_padded_es_20, y_valid_es_20),
                shuffle=True,
                verbose=1,                
                epochs=epochs,
                callbacks=[configure_callbacks(model_id), scheduler_lr])
# Out:
# Epoch 1/100
# 310/310 [==============================] - 56s 125ms/step - loss: 0.6542 - accuracy: 0.6040 - val_loss: 0.5942 - val_accuracy: 0.6875
#
# Epoch 00001: val_accuracy improved from -inf to 0.68750, saving model to /kaggle/working/models/ap-model_10_es-0001-0.687500.h5
#
# Epoch 00001: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 2/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.5121 - accuracy: 0.7520 - val_loss: 0.5532 - val_accuracy: 0.7250
#
# Epoch 00002: val_accuracy improved from 0.68750 to 0.72500, saving model to /kaggle/working/models/ap-model_10_es-0002-0.725000.h5
#
# Epoch 00002: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 3/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.4383 - accuracy: 0.8003 - val_loss: 0.6711 - val_accuracy: 0.6525
#
# Epoch 00003: val_accuracy did not improve from 0.72500
#
# Epoch 00003: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 4/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.3633 - accuracy: 0.8376 - val_loss: 0.7848 - val_accuracy: 0.6600
#
# Epoch 00004: val_accuracy did not improve from 0.72500
#
# Epoch 00004: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 5/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.2932 - accuracy: 0.8692 - val_loss: 0.8511 - val_accuracy: 0.6675
#
# Epoch 00005: val_accuracy did not improve from 0.72500
#
# Epoch 00005: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 6/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.2445 - accuracy: 0.8941 - val_loss: 1.2914 - val_accuracy: 0.6175
#
# Epoch 00006: val_accuracy did not improve from 0.72500
#
# Epoch 00006: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 7/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.1971 - accuracy: 0.9138 - val_loss: 1.2833 - val_accuracy: 0.6400
#
# Epoch 00007: val_accuracy did not improve from 0.72500
#
# Epoch 00007: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 8/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.1571 - accuracy: 0.9314 - val_loss: 1.4152 - val_accuracy: 0.6375
#
# Epoch 00008: val_accuracy did not improve from 0.72500
#
# Epoch 00008: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 9/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.1273 - accuracy: 0.9450 - val_loss: 1.6106 - val_accuracy: 0.6450
#
# Epoch 00009: val_accuracy did not improve from 0.72500
#
# Epoch 00009: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 10/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.1053 - accuracy: 0.9548 - val_loss: 1.6135 - val_accuracy: 0.6325
#
# Epoch 00010: val_accuracy did not improve from 0.72500
#
# Epoch 00010: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 11/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0876 - accuracy: 0.9614 - val_loss: 1.8353 - val_accuracy: 0.6300
#
# Epoch 00011: val_accuracy did not improve from 0.72500
#
# Epoch 00011: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 12/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0783 - accuracy: 0.9671 - val_loss: 1.6045 - val_accuracy: 0.6350
#
# Epoch 00012: val_accuracy did not improve from 0.72500
#
# Epoch 00012: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 13/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0699 - accuracy: 0.9697 - val_loss: 1.8195 - val_accuracy: 0.6325
#
# Epoch 00013: val_accuracy did not improve from 0.72500
#
# Epoch 00013: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 14/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0541 - accuracy: 0.9772 - val_loss: 1.8192 - val_accuracy: 0.6300
#
# Epoch 00014: val_accuracy did not improve from 0.72500
#
# Epoch 00014: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 15/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0531 - accuracy: 0.9762 - val_loss: 1.8879 - val_accuracy: 0.6300
#
# Epoch 00015: val_accuracy did not improve from 0.72500
#
# Epoch 00015: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 16/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0495 - accuracy: 0.9788 - val_loss: 2.3476 - val_accuracy: 0.6275
#
# Epoch 00016: val_accuracy did not improve from 0.72500
#
# Epoch 00016: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 17/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0438 - accuracy: 0.9812 - val_loss: 2.1502 - val_accuracy: 0.6225
#
# Epoch 00017: val_accuracy did not improve from 0.72500
#
# Epoch 00017: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 18/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0386 - accuracy: 0.9840 - val_loss: 2.0220 - val_accuracy: 0.6350
#
# Epoch 00018: val_accuracy did not improve from 0.72500
#
# Epoch 00018: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 19/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0324 - accuracy: 0.9861 - val_loss: 2.0974 - val_accuracy: 0.6550
#
# Epoch 00019: val_accuracy did not improve from 0.72500
#
# Epoch 00019: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 20/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0334 - accuracy: 0.9864 - val_loss: 2.3349 - val_accuracy: 0.6400
#
# Epoch 00020: val_accuracy did not improve from 0.72500
#
# Epoch 00020: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 21/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0318 - accuracy: 0.9874 - val_loss: 2.3525 - val_accuracy: 0.6325
#
# Epoch 00021: val_accuracy did not improve from 0.72500
#
# Epoch 00021: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 22/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0298 - accuracy: 0.9879 - val_loss: 2.4274 - val_accuracy: 0.6275
#
# Epoch 00022: val_accuracy did not improve from 0.72500
#
# Epoch 00022: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 23/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0274 - accuracy: 0.9888 - val_loss: 2.3970 - val_accuracy: 0.6200
#
# Epoch 00023: val_accuracy did not improve from 0.72500
#
# Epoch 00023: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 24/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0271 - accuracy: 0.9882 - val_loss: 2.5824 - val_accuracy: 0.6225
#
# Epoch 00024: val_accuracy did not improve from 0.72500
#
# Epoch 00024: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 25/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0264 - accuracy: 0.9878 - val_loss: 2.3127 - val_accuracy: 0.6250
#
# Epoch 00025: val_accuracy did not improve from 0.72500
#
# Epoch 00025: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 26/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0193 - accuracy: 0.9919 - val_loss: 2.8958 - val_accuracy: 0.6450
#
# Epoch 00026: val_accuracy did not improve from 0.72500
#
# Epoch 00026: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 27/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0109 - accuracy: 0.9948 - val_loss: 3.3948 - val_accuracy: 0.6475
#
# Epoch 00027: val_accuracy did not improve from 0.72500
#
# Epoch 00027: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 28/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0099 - accuracy: 0.9947 - val_loss: 3.6000 - val_accuracy: 0.6475
#
# Epoch 00028: val_accuracy did not improve from 0.72500
#
# Epoch 00028: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 29/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0105 - accuracy: 0.9948 - val_loss: 3.7714 - val_accuracy: 0.6300
#
# Epoch 00029: val_accuracy did not improve from 0.72500
#
# Epoch 00029: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 30/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0134 - accuracy: 0.9939 - val_loss: 3.0167 - val_accuracy: 0.6350
#
# Epoch 00030: val_accuracy did not improve from 0.72500
#
# Epoch 00030: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 31/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0100 - accuracy: 0.9941 - val_loss: 3.1985 - val_accuracy: 0.6525
#
# Epoch 00031: val_accuracy did not improve from 0.72500
#
# Epoch 00031: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 32/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0109 - accuracy: 0.9940 - val_loss: 3.2520 - val_accuracy: 0.6475
#
# Epoch 00032: val_accuracy did not improve from 0.72500
#
# Epoch 00032: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 33/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0092 - accuracy: 0.9954 - val_loss: 2.9511 - val_accuracy: 0.6425
#
# Epoch 00033: val_accuracy did not improve from 0.72500
#
# Epoch 00033: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 34/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0099 - accuracy: 0.9948 - val_loss: 3.0975 - val_accuracy: 0.6500
#
# Epoch 00034: val_accuracy did not improve from 0.72500
#
# Epoch 00034: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 35/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0085 - accuracy: 0.9954 - val_loss: 3.4497 - val_accuracy: 0.6525
#
# Epoch 00035: val_accuracy did not improve from 0.72500
#
# Epoch 00035: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 36/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0077 - accuracy: 0.9958 - val_loss: 3.3996 - val_accuracy: 0.6450
#
# Epoch 00036: val_accuracy did not improve from 0.72500
#
# Epoch 00036: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 37/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0081 - accuracy: 0.9956 - val_loss: 3.4305 - val_accuracy: 0.6525
#
# Epoch 00037: val_accuracy did not improve from 0.72500
#
# Epoch 00037: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 38/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0113 - accuracy: 0.9947 - val_loss: 3.6943 - val_accuracy: 0.6425
#
# Epoch 00038: val_accuracy did not improve from 0.72500
#
# Epoch 00038: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 39/100
# 310/310 [==============================] - 34s 110ms/step - loss: 0.0105 - accuracy: 0.9952 - val_loss: 3.0468 - val_accuracy: 0.6300
#
# Epoch 00039: val_accuracy did not improve from 0.72500
#
# Epoch 00039: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 40/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0084 - accuracy: 0.9960 - val_loss: 2.8779 - val_accuracy: 0.6425
#
# Epoch 00040: val_accuracy did not improve from 0.72500
#
# Epoch 00040: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 41/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0082 - accuracy: 0.9955 - val_loss: 2.7040 - val_accuracy: 0.6525
#
# Epoch 00041: val_accuracy did not improve from 0.72500
#
# Epoch 00041: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 42/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0091 - accuracy: 0.9954 - val_loss: 2.9502 - val_accuracy: 0.6475
#
# Epoch 00042: val_accuracy did not improve from 0.72500
#
# Epoch 00042: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 43/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0090 - accuracy: 0.9951 - val_loss: 2.9396 - val_accuracy: 0.6600
#
# Epoch 00043: val_accuracy did not improve from 0.72500
#
# Epoch 00043: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 44/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0077 - accuracy: 0.9956 - val_loss: 3.0208 - val_accuracy: 0.6650
#
# Epoch 00044: val_accuracy did not improve from 0.72500
#
# Epoch 00044: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 45/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0069 - accuracy: 0.9958 - val_loss: 3.4960 - val_accuracy: 0.6575
#
# Epoch 00045: val_accuracy did not improve from 0.72500
#
# Epoch 00045: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 46/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0069 - accuracy: 0.9956 - val_loss: 3.6726 - val_accuracy: 0.6650
#
# Epoch 00046: val_accuracy did not improve from 0.72500
#
# Epoch 00046: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 47/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0074 - accuracy: 0.9960 - val_loss: 3.6578 - val_accuracy: 0.6575
#
# Epoch 00047: val_accuracy did not improve from 0.72500
#
# Epoch 00047: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 48/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0092 - accuracy: 0.9951 - val_loss: 3.4141 - val_accuracy: 0.6550
#
# Epoch 00048: val_accuracy did not improve from 0.72500
#
# Epoch 00048: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 49/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0108 - accuracy: 0.9947 - val_loss: 2.6709 - val_accuracy: 0.6725
#
# Epoch 00049: val_accuracy did not improve from 0.72500
#
# Epoch 00049: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 50/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0077 - accuracy: 0.9959 - val_loss: 2.9901 - val_accuracy: 0.6775
#
# Epoch 00050: val_accuracy did not improve from 0.72500
#
# Epoch 00050: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 51/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0074 - accuracy: 0.9961 - val_loss: 3.1260 - val_accuracy: 0.6650
#
# Epoch 00051: val_accuracy did not improve from 0.72500
#
# Epoch 00051: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 52/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0060 - accuracy: 0.9962 - val_loss: 3.1971 - val_accuracy: 0.6675
#
# Epoch 00052: val_accuracy did not improve from 0.72500
#
# Epoch 00052: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 53/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0061 - accuracy: 0.9965 - val_loss: 3.2800 - val_accuracy: 0.6650
#
# Epoch 00053: val_accuracy did not improve from 0.72500
#
# Epoch 00053: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 54/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0062 - accuracy: 0.9963 - val_loss: 3.3438 - val_accuracy: 0.6650
#
# Epoch 00054: val_accuracy did not improve from 0.72500
#
# Epoch 00054: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 55/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0059 - accuracy: 0.9961 - val_loss: 3.4160 - val_accuracy: 0.6675
#
# Epoch 00055: val_accuracy did not improve from 0.72500
#
# Epoch 00055: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 56/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0057 - accuracy: 0.9965 - val_loss: 3.4854 - val_accuracy: 0.6675
#
# Epoch 00056: val_accuracy did not improve from 0.72500
#
# Epoch 00056: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 57/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0054 - accuracy: 0.9966 - val_loss: 3.5354 - val_accuracy: 0.6675
#
# Epoch 00057: val_accuracy did not improve from 0.72500
#
# Epoch 00057: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 58/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0060 - accuracy: 0.9959 - val_loss: 3.5834 - val_accuracy: 0.6650
#
# Epoch 00058: val_accuracy did not improve from 0.72500
#
# Epoch 00058: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 59/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0056 - accuracy: 0.9961 - val_loss: 3.6542 - val_accuracy: 0.6650
#
# Epoch 00059: val_accuracy did not improve from 0.72500
#
# Epoch 00059: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 60/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9971 - val_loss: 3.6545 - val_accuracy: 0.6650
#
# Epoch 00060: val_accuracy did not improve from 0.72500
#
# Epoch 00060: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 61/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0058 - accuracy: 0.9962 - val_loss: 3.7103 - val_accuracy: 0.6675
#
# Epoch 00061: val_accuracy did not improve from 0.72500
#
# Epoch 00061: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 62/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0061 - accuracy: 0.9963 - val_loss: 3.7256 - val_accuracy: 0.6650
#
# Epoch 00062: val_accuracy did not improve from 0.72500
#
# Epoch 00062: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 63/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0056 - accuracy: 0.9963 - val_loss: 3.7669 - val_accuracy: 0.6650
#
# Epoch 00063: val_accuracy did not improve from 0.72500
#
# Epoch 00063: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 64/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0062 - accuracy: 0.9960 - val_loss: 3.7958 - val_accuracy: 0.6675
#
# Epoch 00064: val_accuracy did not improve from 0.72500
#
# Epoch 00064: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 65/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0055 - accuracy: 0.9964 - val_loss: 3.8217 - val_accuracy: 0.6650
#
# Epoch 00065: val_accuracy did not improve from 0.72500
#
# Epoch 00065: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 66/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0057 - accuracy: 0.9964 - val_loss: 3.8634 - val_accuracy: 0.6675
#
# Epoch 00066: val_accuracy did not improve from 0.72500
#
# Epoch 00066: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 67/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0054 - accuracy: 0.9968 - val_loss: 3.8470 - val_accuracy: 0.6725
#
# Epoch 00067: val_accuracy did not improve from 0.72500
#
# Epoch 00067: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 68/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0051 - accuracy: 0.9964 - val_loss: 3.9466 - val_accuracy: 0.6700
#
# Epoch 00068: val_accuracy did not improve from 0.72500
#
# Epoch 00068: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 69/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9961 - val_loss: 3.8325 - val_accuracy: 0.6800
#
# Epoch 00069: val_accuracy did not improve from 0.72500
#
# Epoch 00069: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 70/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0073 - accuracy: 0.9961 - val_loss: 3.7749 - val_accuracy: 0.6775
#
# Epoch 00070: val_accuracy did not improve from 0.72500
#
# Epoch 00070: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 71/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0053 - accuracy: 0.9969 - val_loss: 3.7983 - val_accuracy: 0.6725
#
# Epoch 00071: val_accuracy did not improve from 0.72500
#
# Epoch 00071: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 72/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0056 - accuracy: 0.9964 - val_loss: 3.8317 - val_accuracy: 0.6725
#
# Epoch 00072: val_accuracy did not improve from 0.72500
#
# Epoch 00072: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 73/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0053 - accuracy: 0.9966 - val_loss: 3.8484 - val_accuracy: 0.6725
#
# Epoch 00073: val_accuracy did not improve from 0.72500
#
# Epoch 00073: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 74/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0050 - accuracy: 0.9966 - val_loss: 3.8750 - val_accuracy: 0.6725
#
# Epoch 00074: val_accuracy did not improve from 0.72500
#
# Epoch 00074: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 75/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0058 - accuracy: 0.9960 - val_loss: 3.9063 - val_accuracy: 0.6725
#
# Epoch 00075: val_accuracy did not improve from 0.72500
#
# Epoch 00075: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 76/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9967 - val_loss: 3.9161 - val_accuracy: 0.6725
#
# Epoch 00076: val_accuracy did not improve from 0.72500
#
# Epoch 00076: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 77/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0054 - accuracy: 0.9969 - val_loss: 3.9360 - val_accuracy: 0.6700
#
# Epoch 00077: val_accuracy did not improve from 0.72500
#
# Epoch 00077: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 78/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0047 - accuracy: 0.9969 - val_loss: 3.9406 - val_accuracy: 0.6725
#
# Epoch 00078: val_accuracy did not improve from 0.72500
#
# Epoch 00078: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 79/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0049 - accuracy: 0.9970 - val_loss: 3.9605 - val_accuracy: 0.6750
#
# Epoch 00079: val_accuracy did not improve from 0.72500
#
# Epoch 00079: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 80/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0051 - accuracy: 0.9971 - val_loss: 3.9617 - val_accuracy: 0.6750
#
# Epoch 00080: val_accuracy did not improve from 0.72500
#
# Epoch 00080: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 81/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0049 - accuracy: 0.9969 - val_loss: 3.9791 - val_accuracy: 0.6750
#
# Epoch 00081: val_accuracy did not improve from 0.72500
#
# Epoch 00081: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 82/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 4.0033 - val_accuracy: 0.6725
#
# Epoch 00082: val_accuracy did not improve from 0.72500
#
# Epoch 00082: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 83/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0050 - accuracy: 0.9968 - val_loss: 4.0180 - val_accuracy: 0.6725
#
# Epoch 00083: val_accuracy did not improve from 0.72500
#
# Epoch 00083: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 84/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0055 - accuracy: 0.9964 - val_loss: 4.0072 - val_accuracy: 0.6750
#
# Epoch 00084: val_accuracy did not improve from 0.72500
#
# Epoch 00084: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 85/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0050 - accuracy: 0.9969 - val_loss: 4.0298 - val_accuracy: 0.6750
#
# Epoch 00085: val_accuracy did not improve from 0.72500
#
# Epoch 00085: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 86/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0055 - accuracy: 0.9966 - val_loss: 4.0199 - val_accuracy: 0.6750
#
# Epoch 00086: val_accuracy did not improve from 0.72500
#
# Epoch 00086: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 87/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0049 - accuracy: 0.9969 - val_loss: 3.9177 - val_accuracy: 0.6775
#
# Epoch 00087: val_accuracy did not improve from 0.72500
#
# Epoch 00087: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 88/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9965 - val_loss: 4.0138 - val_accuracy: 0.6800
#
# Epoch 00088: val_accuracy did not improve from 0.72500
#
# Epoch 00088: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 89/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0047 - accuracy: 0.9969 - val_loss: 4.0404 - val_accuracy: 0.6825
#
# Epoch 00089: val_accuracy did not improve from 0.72500
#
# Epoch 00089: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 90/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0058 - accuracy: 0.9958 - val_loss: 4.0610 - val_accuracy: 0.6800
#
# Epoch 00090: val_accuracy did not improve from 0.72500
#
# Epoch 00090: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 91/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0060 - accuracy: 0.9963 - val_loss: 4.0825 - val_accuracy: 0.6800
#
# Epoch 00091: val_accuracy did not improve from 0.72500
#
# Epoch 00091: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 92/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0057 - accuracy: 0.9962 - val_loss: 4.0974 - val_accuracy: 0.6800
#
# Epoch 00092: val_accuracy did not improve from 0.72500
#
# Epoch 00092: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 93/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0054 - accuracy: 0.9967 - val_loss: 4.1049 - val_accuracy: 0.6775
#
# Epoch 00093: val_accuracy did not improve from 0.72500
#
# Epoch 00093: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 94/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0051 - accuracy: 0.9963 - val_loss: 4.1027 - val_accuracy: 0.6800
#
# Epoch 00094: val_accuracy did not improve from 0.72500
#
# Epoch 00094: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 95/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0054 - accuracy: 0.9965 - val_loss: 4.0999 - val_accuracy: 0.6775
#
# Epoch 00095: val_accuracy did not improve from 0.72500
#
# Epoch 00095: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 96/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0051 - accuracy: 0.9963 - val_loss: 4.1181 - val_accuracy: 0.6825
#
# Epoch 00096: val_accuracy did not improve from 0.72500
#
# Epoch 00096: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 97/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0056 - accuracy: 0.9966 - val_loss: 4.1040 - val_accuracy: 0.6850
#
# Epoch 00097: val_accuracy did not improve from 0.72500
#
# Epoch 00097: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 98/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0056 - accuracy: 0.9965 - val_loss: 4.1224 - val_accuracy: 0.6825
#
# Epoch 00098: val_accuracy did not improve from 0.72500
#
# Epoch 00098: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 99/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0056 - accuracy: 0.9961 - val_loss: 4.1469 - val_accuracy: 0.6825
#
# Epoch 00099: val_accuracy did not improve from 0.72500
#
# Epoch 00099: saving model to /kaggle/working/models/ap-model_10_es.h5
# Epoch 100/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0051 - accuracy: 0.9965 - val_loss: 4.1325 - val_accuracy: 0.6800
#
# Epoch 00100: val_accuracy did not improve from 0.72500
#
# Epoch 00100: saving model to /kaggle/working/models/ap-model_10_es.h5

# %%
model_10_en = model10
model_id = 'model_10_en'

model_10_en.fit(x=train_padded_en_20,
                y=y_train_en_20,
                batch_size=128,
                validation_data=(valid_padded_en_20, y_valid_en_20),
                shuffle=True,
                verbose=1,                
                epochs=epochs,
                callbacks=[configure_callbacks(model_id), scheduler_lr])
# Out:
# Epoch 1/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.1200 - accuracy: 0.9541 - val_loss: 1.3604 - val_accuracy: 0.6500
#
# Epoch 00001: val_accuracy improved from -inf to 0.65000, saving model to /kaggle/working/models/ap-model_10_en-0001-0.650000.h5
#
# Epoch 00001: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 2/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0493 - accuracy: 0.9810 - val_loss: 1.7127 - val_accuracy: 0.6750
#
# Epoch 00002: val_accuracy improved from 0.65000 to 0.67500, saving model to /kaggle/working/models/ap-model_10_en-0002-0.675000.h5
#
# Epoch 00002: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 3/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0176 - accuracy: 0.9922 - val_loss: 2.3481 - val_accuracy: 0.6550
#
# Epoch 00003: val_accuracy did not improve from 0.67500
#
# Epoch 00003: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 4/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0125 - accuracy: 0.9938 - val_loss: 2.6951 - val_accuracy: 0.6675
#
# Epoch 00004: val_accuracy did not improve from 0.67500
#
# Epoch 00004: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 5/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0130 - accuracy: 0.9942 - val_loss: 2.1691 - val_accuracy: 0.6675
#
# Epoch 00005: val_accuracy did not improve from 0.67500
#
# Epoch 00005: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 6/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0138 - accuracy: 0.9937 - val_loss: 2.3513 - val_accuracy: 0.6625
#
# Epoch 00006: val_accuracy did not improve from 0.67500
#
# Epoch 00006: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 7/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0121 - accuracy: 0.9947 - val_loss: 2.5515 - val_accuracy: 0.6800
#
# Epoch 00007: val_accuracy improved from 0.67500 to 0.68000, saving model to /kaggle/working/models/ap-model_10_en-0007-0.680000.h5
#
# Epoch 00007: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 8/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0123 - accuracy: 0.9943 - val_loss: 1.9273 - val_accuracy: 0.6900
#
# Epoch 00008: val_accuracy improved from 0.68000 to 0.69000, saving model to /kaggle/working/models/ap-model_10_en-0008-0.690000.h5
#
# Epoch 00008: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 9/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0118 - accuracy: 0.9945 - val_loss: 2.5715 - val_accuracy: 0.6625
#
# Epoch 00009: val_accuracy did not improve from 0.69000
#
# Epoch 00009: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 10/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0130 - accuracy: 0.9937 - val_loss: 2.3068 - val_accuracy: 0.6600
#
# Epoch 00010: val_accuracy did not improve from 0.69000
#
# Epoch 00010: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 11/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0122 - accuracy: 0.9942 - val_loss: 2.3843 - val_accuracy: 0.6625
#
# Epoch 00011: val_accuracy did not improve from 0.69000
#
# Epoch 00011: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 12/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0110 - accuracy: 0.9943 - val_loss: 2.4403 - val_accuracy: 0.6625
#
# Epoch 00012: val_accuracy did not improve from 0.69000
#
# Epoch 00012: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 13/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0106 - accuracy: 0.9945 - val_loss: 2.8521 - val_accuracy: 0.6650
#
# Epoch 00013: val_accuracy did not improve from 0.69000
#
# Epoch 00013: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 14/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0097 - accuracy: 0.9950 - val_loss: 2.7037 - val_accuracy: 0.6400
#
# Epoch 00014: val_accuracy did not improve from 0.69000
#
# Epoch 00014: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 15/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0101 - accuracy: 0.9952 - val_loss: 2.9855 - val_accuracy: 0.6600
#
# Epoch 00015: val_accuracy did not improve from 0.69000
#
# Epoch 00015: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 16/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0116 - accuracy: 0.9941 - val_loss: 2.3978 - val_accuracy: 0.6500
#
# Epoch 00016: val_accuracy did not improve from 0.69000
#
# Epoch 00016: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 17/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0115 - accuracy: 0.9946 - val_loss: 2.5227 - val_accuracy: 0.6675
#
# Epoch 00017: val_accuracy did not improve from 0.69000
#
# Epoch 00017: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 18/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0113 - accuracy: 0.9946 - val_loss: 2.5122 - val_accuracy: 0.6525
#
# Epoch 00018: val_accuracy did not improve from 0.69000
#
# Epoch 00018: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 19/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0115 - accuracy: 0.9945 - val_loss: 2.5045 - val_accuracy: 0.6450
#
# Epoch 00019: val_accuracy did not improve from 0.69000
#
# Epoch 00019: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 20/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0114 - accuracy: 0.9945 - val_loss: 2.3268 - val_accuracy: 0.6475
#
# Epoch 00020: val_accuracy did not improve from 0.69000
#
# Epoch 00020: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 21/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0104 - accuracy: 0.9948 - val_loss: 2.3920 - val_accuracy: 0.6675
#
# Epoch 00021: val_accuracy did not improve from 0.69000
#
# Epoch 00021: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 22/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0103 - accuracy: 0.9947 - val_loss: 2.2774 - val_accuracy: 0.6725
#
# Epoch 00022: val_accuracy did not improve from 0.69000
#
# Epoch 00022: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 23/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0108 - accuracy: 0.9947 - val_loss: 2.8938 - val_accuracy: 0.6725
#
# Epoch 00023: val_accuracy did not improve from 0.69000
#
# Epoch 00023: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 24/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0094 - accuracy: 0.9947 - val_loss: 2.7836 - val_accuracy: 0.6850
#
# Epoch 00024: val_accuracy did not improve from 0.69000
#
# Epoch 00024: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 25/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0096 - accuracy: 0.9953 - val_loss: 2.5257 - val_accuracy: 0.6700
#
# Epoch 00025: val_accuracy did not improve from 0.69000
#
# Epoch 00025: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 26/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0069 - accuracy: 0.9962 - val_loss: 2.8555 - val_accuracy: 0.6700
#
# Epoch 00026: val_accuracy did not improve from 0.69000
#
# Epoch 00026: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 27/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0059 - accuracy: 0.9961 - val_loss: 3.0881 - val_accuracy: 0.6725
#
# Epoch 00027: val_accuracy did not improve from 0.69000
#
# Epoch 00027: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 28/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0060 - accuracy: 0.9961 - val_loss: 3.1585 - val_accuracy: 0.6775
#
# Epoch 00028: val_accuracy did not improve from 0.69000
#
# Epoch 00028: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 29/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0058 - accuracy: 0.9961 - val_loss: 3.2957 - val_accuracy: 0.6775
#
# Epoch 00029: val_accuracy did not improve from 0.69000
#
# Epoch 00029: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 30/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0057 - accuracy: 0.9963 - val_loss: 3.3792 - val_accuracy: 0.6725
#
# Epoch 00030: val_accuracy did not improve from 0.69000
#
# Epoch 00030: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 31/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0057 - accuracy: 0.9963 - val_loss: 3.4053 - val_accuracy: 0.6750
#
# Epoch 00031: val_accuracy did not improve from 0.69000
#
# Epoch 00031: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 32/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0056 - accuracy: 0.9963 - val_loss: 3.5009 - val_accuracy: 0.6750
#
# Epoch 00032: val_accuracy did not improve from 0.69000
#
# Epoch 00032: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 33/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0056 - accuracy: 0.9964 - val_loss: 3.5633 - val_accuracy: 0.6800
#
# Epoch 00033: val_accuracy did not improve from 0.69000
#
# Epoch 00033: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 34/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0056 - accuracy: 0.9962 - val_loss: 3.6172 - val_accuracy: 0.6800
#
# Epoch 00034: val_accuracy did not improve from 0.69000
#
# Epoch 00034: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 35/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0056 - accuracy: 0.9963 - val_loss: 3.5590 - val_accuracy: 0.6800
#
# Epoch 00035: val_accuracy did not improve from 0.69000
#
# Epoch 00035: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 36/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0056 - accuracy: 0.9962 - val_loss: 3.7537 - val_accuracy: 0.6825
#
# Epoch 00036: val_accuracy did not improve from 0.69000
#
# Epoch 00036: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 37/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0057 - accuracy: 0.9964 - val_loss: 3.9454 - val_accuracy: 0.6725
#
# Epoch 00037: val_accuracy did not improve from 0.69000
#
# Epoch 00037: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 38/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0094 - accuracy: 0.9954 - val_loss: 3.0960 - val_accuracy: 0.6675
#
# Epoch 00038: val_accuracy did not improve from 0.69000
#
# Epoch 00038: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 39/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0064 - accuracy: 0.9959 - val_loss: 3.2027 - val_accuracy: 0.6575
#
# Epoch 00039: val_accuracy did not improve from 0.69000
#
# Epoch 00039: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 40/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0072 - accuracy: 0.9956 - val_loss: 3.2240 - val_accuracy: 0.6600
#
# Epoch 00040: val_accuracy did not improve from 0.69000
#
# Epoch 00040: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 41/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0059 - accuracy: 0.9961 - val_loss: 3.1772 - val_accuracy: 0.6650
#
# Epoch 00041: val_accuracy did not improve from 0.69000
#
# Epoch 00041: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 42/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0056 - accuracy: 0.9965 - val_loss: 3.2992 - val_accuracy: 0.6650
#
# Epoch 00042: val_accuracy did not improve from 0.69000
#
# Epoch 00042: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 43/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0055 - accuracy: 0.9965 - val_loss: 3.4466 - val_accuracy: 0.6675
#
# Epoch 00043: val_accuracy did not improve from 0.69000
#
# Epoch 00043: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 44/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0055 - accuracy: 0.9963 - val_loss: 3.5596 - val_accuracy: 0.6650
#
# Epoch 00044: val_accuracy did not improve from 0.69000
#
# Epoch 00044: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 45/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0055 - accuracy: 0.9963 - val_loss: 3.6223 - val_accuracy: 0.6675
#
# Epoch 00045: val_accuracy did not improve from 0.69000
#
# Epoch 00045: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 46/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0055 - accuracy: 0.9962 - val_loss: 3.6515 - val_accuracy: 0.6650
#
# Epoch 00046: val_accuracy did not improve from 0.69000
#
# Epoch 00046: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 47/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0055 - accuracy: 0.9965 - val_loss: 3.7734 - val_accuracy: 0.6700
#
# Epoch 00047: val_accuracy did not improve from 0.69000
#
# Epoch 00047: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 48/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0058 - accuracy: 0.9962 - val_loss: 3.5420 - val_accuracy: 0.6700
#
# Epoch 00048: val_accuracy did not improve from 0.69000
#
# Epoch 00048: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 49/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0055 - accuracy: 0.9962 - val_loss: 3.7188 - val_accuracy: 0.6700
#
# Epoch 00049: val_accuracy did not improve from 0.69000
#
# Epoch 00049: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 50/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0055 - accuracy: 0.9963 - val_loss: 3.8165 - val_accuracy: 0.6675
#
# Epoch 00050: val_accuracy did not improve from 0.69000
#
# Epoch 00050: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 51/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0054 - accuracy: 0.9964 - val_loss: 3.8397 - val_accuracy: 0.6675
#
# Epoch 00051: val_accuracy did not improve from 0.69000
#
# Epoch 00051: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 52/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0054 - accuracy: 0.9963 - val_loss: 3.8683 - val_accuracy: 0.6675
#
# Epoch 00052: val_accuracy did not improve from 0.69000
#
# Epoch 00052: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 53/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0054 - accuracy: 0.9965 - val_loss: 3.8962 - val_accuracy: 0.6675
#
# Epoch 00053: val_accuracy did not improve from 0.69000
#
# Epoch 00053: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 54/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9966 - val_loss: 3.9179 - val_accuracy: 0.6675
#
# Epoch 00054: val_accuracy did not improve from 0.69000
#
# Epoch 00054: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 55/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 3.9279 - val_accuracy: 0.6675
#
# Epoch 00055: val_accuracy did not improve from 0.69000
#
# Epoch 00055: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 56/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9965 - val_loss: 3.9554 - val_accuracy: 0.6675
#
# Epoch 00056: val_accuracy did not improve from 0.69000
#
# Epoch 00056: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 57/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0053 - accuracy: 0.9962 - val_loss: 3.9691 - val_accuracy: 0.6700
#
# Epoch 00057: val_accuracy did not improve from 0.69000
#
# Epoch 00057: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 58/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 3.9929 - val_accuracy: 0.6700
#
# Epoch 00058: val_accuracy did not improve from 0.69000
#
# Epoch 00058: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 59/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0053 - accuracy: 0.9966 - val_loss: 4.0248 - val_accuracy: 0.6700
#
# Epoch 00059: val_accuracy did not improve from 0.69000
#
# Epoch 00059: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 60/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9963 - val_loss: 4.0210 - val_accuracy: 0.6675
#
# Epoch 00060: val_accuracy did not improve from 0.69000
#
# Epoch 00060: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 61/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9966 - val_loss: 4.0261 - val_accuracy: 0.6675
#
# Epoch 00061: val_accuracy did not improve from 0.69000
#
# Epoch 00061: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 62/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 4.0416 - val_accuracy: 0.6700
#
# Epoch 00062: val_accuracy did not improve from 0.69000
#
# Epoch 00062: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 63/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9966 - val_loss: 4.0616 - val_accuracy: 0.6700
#
# Epoch 00063: val_accuracy did not improve from 0.69000
#
# Epoch 00063: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 64/100
# 310/310 [==============================] - 34s 110ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 4.0614 - val_accuracy: 0.6700
#
# Epoch 00064: val_accuracy did not improve from 0.69000
#
# Epoch 00064: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 65/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0053 - accuracy: 0.9965 - val_loss: 4.0869 - val_accuracy: 0.6700
#
# Epoch 00065: val_accuracy did not improve from 0.69000
#
# Epoch 00065: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 66/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0053 - accuracy: 0.9965 - val_loss: 4.1004 - val_accuracy: 0.6675
#
# Epoch 00066: val_accuracy did not improve from 0.69000
#
# Epoch 00066: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 67/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0053 - accuracy: 0.9963 - val_loss: 4.1083 - val_accuracy: 0.6725
#
# Epoch 00067: val_accuracy did not improve from 0.69000
#
# Epoch 00067: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 68/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0053 - accuracy: 0.9962 - val_loss: 4.1317 - val_accuracy: 0.6700
#
# Epoch 00068: val_accuracy did not improve from 0.69000
#
# Epoch 00068: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 69/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 4.1387 - val_accuracy: 0.6750
#
# Epoch 00069: val_accuracy did not improve from 0.69000
#
# Epoch 00069: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 70/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0053 - accuracy: 0.9965 - val_loss: 4.1425 - val_accuracy: 0.6725
#
# Epoch 00070: val_accuracy did not improve from 0.69000
#
# Epoch 00070: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 71/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 4.1072 - val_accuracy: 0.6725
#
# Epoch 00071: val_accuracy did not improve from 0.69000
#
# Epoch 00071: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 72/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 4.0779 - val_accuracy: 0.6700
#
# Epoch 00072: val_accuracy did not improve from 0.69000
#
# Epoch 00072: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 73/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0055 - accuracy: 0.9966 - val_loss: 3.9655 - val_accuracy: 0.6675
#
# Epoch 00073: val_accuracy did not improve from 0.69000
#
# Epoch 00073: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 74/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9966 - val_loss: 3.9871 - val_accuracy: 0.6675
#
# Epoch 00074: val_accuracy did not improve from 0.69000
#
# Epoch 00074: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 75/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0053 - accuracy: 0.9966 - val_loss: 3.9946 - val_accuracy: 0.6650
#
# Epoch 00075: val_accuracy did not improve from 0.69000
#
# Epoch 00075: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 76/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0053 - accuracy: 0.9966 - val_loss: 4.0014 - val_accuracy: 0.6675
#
# Epoch 00076: val_accuracy did not improve from 0.69000
#
# Epoch 00076: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 77/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.0093 - val_accuracy: 0.6675
#
# Epoch 00077: val_accuracy did not improve from 0.69000
#
# Epoch 00077: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 78/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.0141 - val_accuracy: 0.6675
#
# Epoch 00078: val_accuracy did not improve from 0.69000
#
# Epoch 00078: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 79/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.0192 - val_accuracy: 0.6675
#
# Epoch 00079: val_accuracy did not improve from 0.69000
#
# Epoch 00079: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 80/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.0304 - val_accuracy: 0.6675
#
# Epoch 00080: val_accuracy did not improve from 0.69000
#
# Epoch 00080: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 81/100
# 310/310 [==============================] - 33s 107ms/step - loss: 0.0052 - accuracy: 0.9965 - val_loss: 4.0398 - val_accuracy: 0.6675
#
# Epoch 00081: val_accuracy did not improve from 0.69000
#
# Epoch 00081: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 82/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9964 - val_loss: 4.0518 - val_accuracy: 0.6675
#
# Epoch 00082: val_accuracy did not improve from 0.69000
#
# Epoch 00082: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 83/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9967 - val_loss: 4.0645 - val_accuracy: 0.6675
#
# Epoch 00083: val_accuracy did not improve from 0.69000
#
# Epoch 00083: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 84/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.0748 - val_accuracy: 0.6675
#
# Epoch 00084: val_accuracy did not improve from 0.69000
#
# Epoch 00084: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 85/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.0829 - val_accuracy: 0.6675
#
# Epoch 00085: val_accuracy did not improve from 0.69000
#
# Epoch 00085: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 86/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9964 - val_loss: 4.0814 - val_accuracy: 0.6675
#
# Epoch 00086: val_accuracy did not improve from 0.69000
#
# Epoch 00086: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 87/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9965 - val_loss: 4.0840 - val_accuracy: 0.6650
#
# Epoch 00087: val_accuracy did not improve from 0.69000
#
# Epoch 00087: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 88/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.0918 - val_accuracy: 0.6650
#
# Epoch 00088: val_accuracy did not improve from 0.69000
#
# Epoch 00088: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 89/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0052 - accuracy: 0.9965 - val_loss: 4.0995 - val_accuracy: 0.6650
#
# Epoch 00089: val_accuracy did not improve from 0.69000
#
# Epoch 00089: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 90/100
# 310/310 [==============================] - 34s 108ms/step - loss: 0.0052 - accuracy: 0.9965 - val_loss: 4.1055 - val_accuracy: 0.6650
#
# Epoch 00090: val_accuracy did not improve from 0.69000
#
# Epoch 00090: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 91/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9964 - val_loss: 4.1104 - val_accuracy: 0.6650
#
# Epoch 00091: val_accuracy did not improve from 0.69000
#
# Epoch 00091: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 92/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.1146 - val_accuracy: 0.6650
#
# Epoch 00092: val_accuracy did not improve from 0.69000
#
# Epoch 00092: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 93/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9965 - val_loss: 4.1279 - val_accuracy: 0.6650
#
# Epoch 00093: val_accuracy did not improve from 0.69000
#
# Epoch 00093: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 94/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9964 - val_loss: 4.1269 - val_accuracy: 0.6650
#
# Epoch 00094: val_accuracy did not improve from 0.69000
#
# Epoch 00094: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 95/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0052 - accuracy: 0.9964 - val_loss: 4.1251 - val_accuracy: 0.6650
#
# Epoch 00095: val_accuracy did not improve from 0.69000
#
# Epoch 00095: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 96/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.1472 - val_accuracy: 0.6650
#
# Epoch 00096: val_accuracy did not improve from 0.69000
#
# Epoch 00096: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 97/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0052 - accuracy: 0.9965 - val_loss: 4.1363 - val_accuracy: 0.6650
#
# Epoch 00097: val_accuracy did not improve from 0.69000
#
# Epoch 00097: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 98/100
# 310/310 [==============================] - 34s 109ms/step - loss: 0.0052 - accuracy: 0.9965 - val_loss: 4.1398 - val_accuracy: 0.6650
#
# Epoch 00098: val_accuracy did not improve from 0.69000
#
# Epoch 00098: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 99/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9965 - val_loss: 4.1548 - val_accuracy: 0.6650
#
# Epoch 00099: val_accuracy did not improve from 0.69000
#
# Epoch 00099: saving model to /kaggle/working/models/ap-model_10_en.h5
# Epoch 100/100
# 310/310 [==============================] - 33s 108ms/step - loss: 0.0052 - accuracy: 0.9966 - val_loss: 4.1593 - val_accuracy: 0.6650
#
# Epoch 00100: val_accuracy did not improve from 0.69000
#
# Epoch 00100: saving model to /kaggle/working/models/ap-model_10_en.h5

# %%
# !zip -r models_kaggle.zip '/kaggle/working/models/'
# Out:
#   adding: kaggle/working/models/ (stored 0%)
#   adding: kaggle/working/models/ap-model_10_es-0002-0.725000.h5 (deflated 6%)
#   adding: kaggle/working/models/ap-model_10_en-0002-0.675000.h5 (deflated 6%)
#   adding: kaggle/working/models/ap-model_10_es.log (deflated 61%)
#   adding: kaggle/working/models/ap-model_10_en-0008-0.690000.h5 (deflated 6%)
#   adding: kaggle/working/models/ap-model_10_es-0001-0.687500.h5 (deflated 6%)
#   adding: kaggle/working/models/ap-model_10_es.h5 (deflated 6%)
#   adding: kaggle/working/models/ap-model_10_en.h5 (deflated 6%)
#   adding: kaggle/working/models/ap-model_10_en-0001-0.650000.h5 (deflated 6%)
#   adding: kaggle/working/models/ap-model_10_en.log (deflated 65%)
#   adding: kaggle/working/models/ap-model_10_en-0007-0.680000.h5 (deflated 6%)

# %%
pickle_file = open(kaggle_path+'es_indv_bert.pickle', 'rb')
es_indv_bert = pickle.load(pickle_file)

train_padded_es_indv_bert, train_mask_es_indv, y_train_es_indv = es_indv_bert[0], es_indv_bert[1], es_indv_bert[2]
valid_padded_es_indv_bert, valid_mask_es_indv, y_valid_es_indv = es_indv_bert[3], es_indv_bert[4], es_indv_bert[5]
test_padded_es_indv_bert, test_mask_es_indv = es_indv_bert[6], es_indv_bert[7]

# %%
pickle_file = open(kaggle_path+'es_20_bert.pickle', 'rb')
es_20_bert = pickle.load(pickle_file)

train_padded_es_20_bert, train_mask_es_20, y_train_es_20 = es_20_bert[0], es_20_bert[1], es_20_bert[2]
valid_padded_es_20_bert, valid_mask_es_20, y_valid_es_20 = es_20_bert[3], es_20_bert[4], es_20_bert[5]
test_padded_es_20_bert, test_mask_es_20 = es_20_bert[6], es_20_bert[7]

# %%
#  ES individual tweets

bert_model1 = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=1)

bert_model1.compile(loss='binary_crossentropy',
                   optimizer=Adam(learning_rate=2e-5,epsilon=1e-08),
                   metrics=['accuracy'])
bert_model1.summary()

# %%
bert_model1.fit(x=[train_padded_es_indv_bert, train_mask_es_indv],
               y=y_train_es_indv,
               batch_size=128,
               epochs=25,
               validation_data=([valid_padded_es_indv_bert, valid_mask_es_indv], y_valid_es_indv))

# %%
predictions1 = bert_model1.predict([valid_padded_es_indv_bert, valid_mask_es_indv], batch_size=128)
#author_profiling_report(predictions)

# %%
number_authors = 40
n = int(number_authors/2)
a = np.zeros(n)
b = np.ones(n)        
author_profile = np.concatenate([a,b])

p = []
for logit in predictions1.logits:
    p.append(math.exp(logit)/(1+math.exp(logit)))
np.array(p)

# Check author profiling -> 8,000 predictions
# Split into 40 authors -> 200 tweets per author
author_predictions = np.average(np.array_split(p, number_authors), axis=1)
author_predictions = np.array([1 if ap >= 0.5 else 0 for ap in author_predictions])

print(classification_report(author_profile, author_predictions, labels=[0, 1], target_names=['not hate','hate']))

# %%
#  ES individual tweets

bert_model2 = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=1)

bert_model2.compile(loss='binary_crossentropy',
                   optimizer=Adam(learning_rate=6e-5,epsilon=1e-08),
                   metrics=['accuracy'])
bert_model2.summary()

# %%
bert_model2.fit(x=[train_padded_es_indv_bert, train_mask_es_indv],
               y=y_train_es_indv,
               batch_size=128,
               epochs=25,
               validation_data=([valid_padded_es_indv_bert, valid_mask_es_indv], y_valid_es_indv))

predictions = bert_model2.predict([valid_padded_es_indv_bert, valid_mask_es_indv], batch_size=128)

# %%
predictions2 = bert_model2.predict([valid_padded_es_indv_bert, valid_mask_es_indv], batch_size=128)
p = []
for logit in predictions2.logits:
    p.append(math.exp(logit)/(1+math.exp(logit)))
np.array(p)

# Check author profiling -> 8,000 predictions
# Split into 40 authors -> 200 tweets per author
author_predictions = np.average(np.array_split(p, number_authors), axis=1)
author_predictions = np.array([1 if ap >= 0.5 else 0 for ap in author_predictions])

print(classification_report(author_profile, author_predictions, labels=[0, 1], target_names=['not hate','hate']))

# %%
#  ES individual tweets

bert_model3 = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=1)

bert_model3.compile(loss='binary_crossentropy',
                   optimizer=Adam(learning_rate=1e-4,epsilon=1e-08),
                   metrics=['accuracy'])
bert_model3.summary()

# %%
bert_model3.fit(x=[train_padded_es_indv_bert, train_mask_es_indv],
               y=y_train_es_indv,
               batch_size=128,
               epochs=25,
               validation_data=([valid_padded_es_indv_bert, valid_mask_es_indv], y_valid_es_indv))

predictions = bert_model3.predict([valid_padded_es_indv_bert, valid_mask_es_indv], batch_size=128)

# %%
predictions3 = bert_model3.predict([valid_padded_es_indv_bert, valid_mask_es_indv], batch_size=128)
p = []
for logit in predictions3.logits:
    p.append(math.exp(logit)/(1+math.exp(logit)))
np.array(p)

# Check author profiling -> 8,000 predictions
# Split into 40 authors -> 200 tweets per author
author_predictions = np.average(np.array_split(p, number_authors), axis=1)
author_predictions = np.array([1 if ap >= 0.5 else 0 for ap in author_predictions])

print(classification_report(author_profile, author_predictions, labels=[0, 1], target_names=['not hate','hate']))

# %%
# ES joined 20 tweets

bert_model4 = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=1)

bert_model4.compile(loss='binary_crossentropy',
                   optimizer=Adam(learning_rate=2e-5,epsilon=1e-08),
                   metrics=['accuracy'])
bert_model4.summary()

# %%
bert_model4.fit(x=[train_padded_es_20_bert, train_mask_es_20],
               y=y_train_es_20,
               batch_size=16,
               epochs=5,
               validation_data=([valid_padded_es_20_bert, valid_mask_es_20], y_valid_es_20))

# %%
predictions4= bert_model4.predict([test_padded_es_20_bert, test_mask_es_20], batch_size=16)
p = []
for logit in predictions4.logits:
    p.append(math.exp(logit)/(1+math.exp(logit)))
np.array(p)

# Check author profiling -> 8,000 predictions
# Split into 40 authors -> 200 tweets per author
author_predictions = np.average(np.array_split(p, number_authors), axis=1)
author_predictions = np.array([1 if ap >= 0.5 else 0 for ap in author_predictions])

print(classification_report(author_profile, author_predictions, labels=[0, 1], target_names=['not hate','hate']))
