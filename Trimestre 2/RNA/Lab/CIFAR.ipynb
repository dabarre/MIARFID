# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Activation, Reshape, Dropout, Conv2D, MaxPooling2D, Flatten, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization as BN
from keras.layers import GaussianNoise as GN
from keras.optimizers import SGD
from keras.callbacks import CSVLogger, ModelCheckpoint
from keras.callbacks import LearningRateScheduler as LRS
from keras.callbacks import ReduceLROnPlateau as RLRP
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model

# %%
batch_size = 128
epochs = 200
num_classes=10

# %%
def configure_callbacks(model_id, kpi_to_monitor='val_accuracy'):
    # Without log/ or models/ subfolder as not possible to access unexisting folders
    # If possible to train with jupyter revise
    name = "cnn"
    log_filename = '%s-%s.log' % (name, model_id)
    csv_logger = CSVLogger(log_filename)
    
    chk_1_model_filename = '%s-%s-{epoch:04d}-{%s:.6f}.h5' % (name, model_id, kpi_to_monitor)
    chk_2_model_filename = '%s-%s.h5' % (name, model_id)
    
    # Save best model fully not only weights after each epoch (period=1) 
    # with best accuracy value (mode=max, save_best_only=True)
    checkpoint1 = ModelCheckpoint(
        chk_1_model_filename,
        monitor=kpi_to_monitor,
        save_best_only=True,
        save_weights_only=False, 
        verbose=1, mode='max', period=1
    )

    checkpoint2 = ModelCheckpoint(
        chk_2_model_filename, 
        monitor=kpi_to_monitor,
        save_best_only=False,
        save_weights_only=False, 
        verbose=1, mode='auto', period=1
    )

    callbacks = [csv_logger, checkpoint1, checkpoint2]
    return callbacks

# %%
# Define a learning rate scheduler
def scheduler(epoch):
    if epoch < 25:
        return 0.1
    elif epoch < 50:
        return 0.01
    else:
        return 0.001

scheduler_lr = LRS(scheduler)

# %%
# Define a learning rate scheduler
def scheduler_2(epoch):
    if epoch < 75:
        return 0.1
    elif epoch < 125:
        return 0.01
    else:
        return 0.001

scheduler_lr_2 = LRS(scheduler_2)

# %%
# Define a learning rate scheduler
def scheduler_3(epoch):
    if epoch < 50:
        return 0.1
    elif epoch < 75:
        return 0.01
    elif epoch < 150:
        return 0.001
    else:
        return 0.0005

scheduler_lr_3 = LRS(scheduler_3)

# %%
# Define an automatic learning rate scheduler
reduce_lr = RLRP(monitor='val_loss', factor=0.5, cooldown=1,
                 patience=10, min_lr=0.001)

# %%
# Data Augmentation with an ImageGenerator
datagen = ImageDataGenerator(width_shift_range=0.1,
                             height_shift_range=0.1,
                             horizontal_flip=True,
                             vertical_flip=False)

# %%
# Data Augmentation with an ImageGenerator + more variations
datagen_plus = ImageDataGenerator(width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  horizontal_flip=True,
                                  vertical_flip=False,
                                  zoom_range=[1.0,1.1],
                                  rotation_range=10.0,
                                  shear_range=0.1)

# %%
# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('training set', x_train.shape)
print('test set', x_test.shape)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize [0..255]-->[0..1]
x_train /= 255
x_test /= 255

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# training set (50000, 32, 32, 3)
# test set (10000, 32, 32, 3)

# %%
# Optimizer 
sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9)

# %%
def basic_training_and_evaluation(model, model_id, scheduler):
    # Compile Model
    model.compile(loss='categorical_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy'])
    
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                        steps_per_epoch=len(x_train)/batch_size,
                        epochs=epochs,
                        shuffle=True,
                        verbose=1,
                        validation_data=(x_test, y_test),                   
                        callbacks=[configure_callbacks(model_id), scheduler])
    loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', loss)
    print('Test accuracy:', accuracy)
    print('Test error:', (1-accuracy))
    
    return model

# %%
def advanced_training_and_evaluation(model, model_id, scheduler):
    # Compile Model
    model.compile(loss='categorical_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy'])
    
    history = model.fit(datagen_plus.flow(x_train, y_train, batch_size=batch_size),
                        steps_per_epoch=len(x_train)/batch_size,
                        epochs=epochs,
                        shuffle=True,
                        verbose=1,
                        validation_data=(x_test, y_test),                   
                        callbacks=[configure_callbacks(model_id), scheduler])
    loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', loss)
    print('Test accuracy:', accuracy)
    print('Test error:', (1-accuracy))
    
    return model

# %%
## DEF A BLOCK CONV + BN + GN + MAXPOOL
def CBGNM(model, filters, ishape=0):
    if (ishape!=0):
        model.add(Conv2D(filters, (3, 3), padding='same',
                 input_shape=ishape))
    else:
        model.add(Conv2D(filters, (3, 3), padding='same'))

        model.add(BN())
        model.add(GN(0.3))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
  
  
    return model

# %%
def CBGN(model, filters, gaussian_noise, ishape=0):
    if (ishape!=0):
        model.add(Conv2D(filters, (3, 3), padding='same',
                 input_shape=ishape))
    else:
        model.add(Conv2D(filters, (3, 3), padding='same'))

        model.add(BN())
        model.add(GN(gaussian_noise))
        model.add(Activation('relu'))
        #model.add(MaxPooling2D(pool_size=(2, 2)))
  
  
    return model

# %% [markdown]
# ## Extra funcitons

# %%
# Compile Model
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

# %%
history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=len(x_train)/batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=1,
                    validation_data=(x_test, y_test),                   
                    callbacks=[configure_callbacks(model_id), scheduler_lr])

# %%
history = model.fit(datagen_plus.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=len(x_train)/batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=1,
                    validation_data=(x_test, y_test),                   
                    callbacks=[configure_callbacks(model_id), reduce_lr])

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
print('Test error:', (1-accuracy))

# %%
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False)
history = pd.read_csv("model-weights/model.log")
model = load_model("model-weights/model.h5")

# %% [markdown]
# ## Models

# %%
# Model Basic
model = Sequential()

model = CBGNM(model, 32, x_train.shape[1:])
model = CBGNM(model, 64)
model = CBGNM(model, 128)
model = CBGNM(model, 256)
model = CBGNM(model, 512)

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

model_basic = model
model_basic.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 32, 32, 64)        0
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 16, 16, 128)       0
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# gaussian_noise_2 (GaussianNo (None, 8, 8, 256)         0
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# gaussian_noise_3 (GaussianNo (None, 4, 4, 512)         0
# _________________________________________________________________
# activation_3 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 2,626,634
# Trainable params: 2,624,714
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
model = Sequential()

model = CBGN(model, 64, 0.1, x_train.shape[1:])
model = CBGN(model, 128, 0.2)

model.add(MaxPooling2D(pool_size=(2, 2)))

model = CBGN(model, 256, 0.3)

model.add(MaxPooling2D(pool_size=(2, 2)))

model = CBGN(model, 512, 0.3)

model.add(MaxPooling2D(pool_size=(2, 2)))

model = CBGN(model, 512, 0.3)

model.add(GlobalAveragePooling2D())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

model_cnn = model
model_cnn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# gaussian_noise_4 (GaussianNo (None, 32, 32, 128)       0
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# gaussian_noise_5 (GaussianNo (None, 16, 16, 256)       0
# _________________________________________________________________
# activation_7 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# gaussian_noise_6 (GaussianNo (None, 8, 8, 512)         0
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# gaussian_noise_7 (GaussianNo (None, 4, 4, 512)         0
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_10 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_11 (Activation)   (None, 10)                0
# =================================================================
# Total params: 4,050,314
# Trainable params: 4,047,498
# Non-trainable params: 2,816
# _________________________________________________________________

# %%
model = Sequential()

model = CBGN(model, 64, 0.1, x_train.shape[1:])
model = CBGN(model, 64, 0.2)
model = CBGN(model, 64, 0.2)

model.add(MaxPooling2D(pool_size=(2, 2)))

model = CBGN(model, 128, 0.3)
model = CBGN(model, 128, 0.3)
model = CBGN(model, 128, 0.3)

model.add(MaxPooling2D(pool_size=(2, 2)))

model = CBGN(model, 256, 0.3)
model = CBGN(model, 256, 0.3)
model = CBGN(model, 256, 0.3)

model.add(MaxPooling2D(pool_size=(2, 2)))

model = CBGN(model, 512, 0.3)
model = CBGN(model, 512, 0.3)
model = CBGN(model, 512, 0.3)

model.add(MaxPooling2D(pool_size=(2, 2)))

model = CBGN(model, 512, 0.3)
model = CBGN(model, 512, 0.3)
model = CBGN(model, 512, 0.3)

model.add(GlobalAveragePooling2D())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

model_cnn_vgg = model
model_cnn_vgg.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# gaussian_noise_8 (GaussianNo (None, 32, 32, 64)        0
# _________________________________________________________________
# activation_12 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# gaussian_noise_9 (GaussianNo (None, 32, 32, 64)        0
# _________________________________________________________________
# activation_13 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# gaussian_noise_10 (GaussianN (None, 16, 16, 128)       0
# _________________________________________________________________
# activation_14 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# gaussian_noise_11 (GaussianN (None, 16, 16, 128)       0
# _________________________________________________________________
# activation_15 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# gaussian_noise_12 (GaussianN (None, 16, 16, 128)       0
# _________________________________________________________________
# activation_16 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# gaussian_noise_13 (GaussianN (None, 8, 8, 256)         0
# _________________________________________________________________
# activation_17 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# gaussian_noise_14 (GaussianN (None, 8, 8, 256)         0
# _________________________________________________________________
# activation_18 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# gaussian_noise_15 (GaussianN (None, 8, 8, 256)         0
# _________________________________________________________________
# activation_19 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# gaussian_noise_16 (GaussianN (None, 4, 4, 512)         0
# _________________________________________________________________
# activation_20 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# gaussian_noise_17 (GaussianN (None, 4, 4, 512)         0
# _________________________________________________________________
# activation_21 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# gaussian_noise_18 (GaussianN (None, 4, 4, 512)         0
# _________________________________________________________________
# activation_22 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# gaussian_noise_19 (GaussianN (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_23 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# gaussian_noise_20 (GaussianN (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_24 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# gaussian_noise_21 (GaussianN (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_25 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_26 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_27 (Activation)   (None, 10)                0
# =================================================================
# Total params: 15,050,506
# Trainable params: 15,041,802
# Non-trainable params: 8,704
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
# Basic and Basic training
model_1 = model_basic
model_1 = advanced_training_and_evaluation(model=model_1,
                                           model_id='model_1',
                                           scheduler=scheduler_lr_3)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 390/390 [==============================] - 35s 72ms/step - loss: 3.5898 - accuracy: 0.1646 - val_loss: 2.1274 - val_accuracy: 0.1730
#
# Epoch 00001: val_accuracy improved from -inf to 0.17300, saving model to cnn-model_1-0001-0.173000.h5
#
# Epoch 00001: saving model to cnn-model_1.h5
# Epoch 2/200
# 390/390 [==============================] - 27s 70ms/step - loss: 2.0159 - accuracy: 0.2169 - val_loss: 1.9496 - val_accuracy: 0.2459
#
# Epoch 00002: val_accuracy improved from 0.17300 to 0.24590, saving model to cnn-model_1-0002-0.245900.h5
#
# Epoch 00002: saving model to cnn-model_1.h5
# Epoch 3/200
# 390/390 [==============================] - 27s 69ms/step - loss: 1.8765 - accuracy: 0.2520 - val_loss: 1.9627 - val_accuracy: 0.2400
#
# Epoch 00003: val_accuracy did not improve from 0.24590
#
# Epoch 00003: saving model to cnn-model_1.h5
# Epoch 4/200
# 390/390 [==============================] - 27s 70ms/step - loss: 1.7329 - accuracy: 0.3302 - val_loss: 2.6530 - val_accuracy: 0.1919
#
# Epoch 00004: val_accuracy did not improve from 0.24590
#
# Epoch 00004: saving model to cnn-model_1.h5
# Epoch 5/200
# 390/390 [==============================] - 27s 70ms/step - loss: 1.5658 - accuracy: 0.4165 - val_loss: 1.7624 - val_accuracy: 0.3675
#
# Epoch 00005: val_accuracy improved from 0.24590 to 0.36750, saving model to cnn-model_1-0005-0.367500.h5
#
# Epoch 00005: saving model to cnn-model_1.h5
# Epoch 6/200
# 390/390 [==============================] - 27s 69ms/step - loss: 1.4200 - accuracy: 0.4803 - val_loss: 1.7363 - val_accuracy: 0.4224
#
# Epoch 00006: val_accuracy improved from 0.36750 to 0.42240, saving model to cnn-model_1-0006-0.422400.h5
#
# Epoch 00006: saving model to cnn-model_1.h5
# Epoch 7/200
# 390/390 [==============================] - 27s 70ms/step - loss: 1.2548 - accuracy: 0.5427 - val_loss: 1.3856 - val_accuracy: 0.5439
#
# Epoch 00007: val_accuracy improved from 0.42240 to 0.54390, saving model to cnn-model_1-0007-0.543900.h5
#
# Epoch 00007: saving model to cnn-model_1.h5
# Epoch 8/200
# 390/390 [==============================] - 27s 69ms/step - loss: 1.1082 - accuracy: 0.6071 - val_loss: 1.0668 - val_accuracy: 0.6247
#
# Epoch 00008: val_accuracy improved from 0.54390 to 0.62470, saving model to cnn-model_1-0008-0.624700.h5
#
# Epoch 00008: saving model to cnn-model_1.h5
# Epoch 9/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.9972 - accuracy: 0.6460 - val_loss: 1.2576 - val_accuracy: 0.5964
#
# Epoch 00009: val_accuracy did not improve from 0.62470
#
# Epoch 00009: saving model to cnn-model_1.h5
# Epoch 10/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.9205 - accuracy: 0.6756 - val_loss: 1.2178 - val_accuracy: 0.6214
#
# Epoch 00010: val_accuracy did not improve from 0.62470
#
# Epoch 00010: saving model to cnn-model_1.h5
# Epoch 11/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.8585 - accuracy: 0.7005 - val_loss: 0.9307 - val_accuracy: 0.6952
#
# Epoch 00011: val_accuracy improved from 0.62470 to 0.69520, saving model to cnn-model_1-0011-0.695200.h5
#
# Epoch 00011: saving model to cnn-model_1.h5
# Epoch 12/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.8113 - accuracy: 0.7199 - val_loss: 0.9866 - val_accuracy: 0.6712
#
# Epoch 00012: val_accuracy did not improve from 0.69520
#
# Epoch 00012: saving model to cnn-model_1.h5
# Epoch 13/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.7588 - accuracy: 0.7358 - val_loss: 0.9138 - val_accuracy: 0.7089
#
# Epoch 00013: val_accuracy improved from 0.69520 to 0.70890, saving model to cnn-model_1-0013-0.708900.h5
#
# Epoch 00013: saving model to cnn-model_1.h5
# Epoch 14/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.7243 - accuracy: 0.7483 - val_loss: 1.0811 - val_accuracy: 0.6754
#
# Epoch 00014: val_accuracy did not improve from 0.70890
#
# Epoch 00014: saving model to cnn-model_1.h5
# Epoch 15/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.6909 - accuracy: 0.7589 - val_loss: 0.9489 - val_accuracy: 0.6954
#
# Epoch 00015: val_accuracy did not improve from 0.70890
#
# Epoch 00015: saving model to cnn-model_1.h5
# Epoch 16/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.6546 - accuracy: 0.7738 - val_loss: 0.7741 - val_accuracy: 0.7413
#
# Epoch 00016: val_accuracy improved from 0.70890 to 0.74130, saving model to cnn-model_1-0016-0.741300.h5
#
# Epoch 00016: saving model to cnn-model_1.h5
# Epoch 17/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.6442 - accuracy: 0.7777 - val_loss: 0.7871 - val_accuracy: 0.7469
#
# Epoch 00017: val_accuracy improved from 0.74130 to 0.74690, saving model to cnn-model_1-0017-0.746900.h5
#
# Epoch 00017: saving model to cnn-model_1.h5
# Epoch 18/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.6197 - accuracy: 0.7847 - val_loss: 0.7362 - val_accuracy: 0.7712
#
# Epoch 00018: val_accuracy improved from 0.74690 to 0.77120, saving model to cnn-model_1-0018-0.771200.h5
#
# Epoch 00018: saving model to cnn-model_1.h5
# Epoch 19/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.5987 - accuracy: 0.7942 - val_loss: 0.8480 - val_accuracy: 0.7293
#
# Epoch 00019: val_accuracy did not improve from 0.77120
#
# Epoch 00019: saving model to cnn-model_1.h5
# Epoch 20/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.5924 - accuracy: 0.7950 - val_loss: 0.7388 - val_accuracy: 0.7685
#
# Epoch 00020: val_accuracy did not improve from 0.77120
#
# Epoch 00020: saving model to cnn-model_1.h5
# Epoch 21/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.5683 - accuracy: 0.8044 - val_loss: 0.7659 - val_accuracy: 0.7600
#
# Epoch 00021: val_accuracy did not improve from 0.77120
#
# Epoch 00021: saving model to cnn-model_1.h5
# Epoch 22/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.5546 - accuracy: 0.8098 - val_loss: 0.7674 - val_accuracy: 0.7562
#
# Epoch 00022: val_accuracy did not improve from 0.77120
#
# Epoch 00022: saving model to cnn-model_1.h5
# Epoch 23/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.5375 - accuracy: 0.8149 - val_loss: 0.7269 - val_accuracy: 0.7573
#
# Epoch 00023: val_accuracy did not improve from 0.77120
#
# Epoch 00023: saving model to cnn-model_1.h5
# Epoch 24/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.5208 - accuracy: 0.8203 - val_loss: 0.9471 - val_accuracy: 0.7140
#
# Epoch 00024: val_accuracy did not improve from 0.77120
#
# Epoch 00024: saving model to cnn-model_1.h5
# Epoch 25/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.5070 - accuracy: 0.8256 - val_loss: 0.7041 - val_accuracy: 0.7811
#
# Epoch 00025: val_accuracy improved from 0.77120 to 0.78110, saving model to cnn-model_1-0025-0.781100.h5
#
# Epoch 00025: saving model to cnn-model_1.h5
# Epoch 26/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4998 - accuracy: 0.8273 - val_loss: 0.7415 - val_accuracy: 0.7754
#
# Epoch 00026: val_accuracy did not improve from 0.78110
#
# Epoch 00026: saving model to cnn-model_1.h5
# Epoch 27/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4750 - accuracy: 0.8369 - val_loss: 0.6488 - val_accuracy: 0.7972
#
# Epoch 00027: val_accuracy improved from 0.78110 to 0.79720, saving model to cnn-model_1-0027-0.797200.h5
#
# Epoch 00027: saving model to cnn-model_1.h5
# Epoch 28/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.4735 - accuracy: 0.8355 - val_loss: 0.5604 - val_accuracy: 0.8200
#
# Epoch 00028: val_accuracy improved from 0.79720 to 0.82000, saving model to cnn-model_1-0028-0.820000.h5
#
# Epoch 00028: saving model to cnn-model_1.h5
# Epoch 29/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4598 - accuracy: 0.8398 - val_loss: 0.6561 - val_accuracy: 0.8022
#
# Epoch 00029: val_accuracy did not improve from 0.82000
#
# Epoch 00029: saving model to cnn-model_1.h5
# Epoch 30/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4449 - accuracy: 0.8471 - val_loss: 0.5955 - val_accuracy: 0.8091
#
# Epoch 00030: val_accuracy did not improve from 0.82000
#
# Epoch 00030: saving model to cnn-model_1.h5
# Epoch 31/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4368 - accuracy: 0.8484 - val_loss: 0.7740 - val_accuracy: 0.7753
#
# Epoch 00031: val_accuracy did not improve from 0.82000
#
# Epoch 00031: saving model to cnn-model_1.h5
# Epoch 32/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.4357 - accuracy: 0.8513 - val_loss: 0.6366 - val_accuracy: 0.8093
#
# Epoch 00032: val_accuracy did not improve from 0.82000
#
# Epoch 00032: saving model to cnn-model_1.h5
# Epoch 33/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.4207 - accuracy: 0.8548 - val_loss: 0.5677 - val_accuracy: 0.8161
#
# Epoch 00033: val_accuracy did not improve from 0.82000
#
# Epoch 00033: saving model to cnn-model_1.h5
# Epoch 34/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.4085 - accuracy: 0.8599 - val_loss: 0.6369 - val_accuracy: 0.8067
#
# Epoch 00034: val_accuracy did not improve from 0.82000
#
# Epoch 00034: saving model to cnn-model_1.h5
# Epoch 35/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.4122 - accuracy: 0.8586 - val_loss: 0.6943 - val_accuracy: 0.7969
#
# Epoch 00035: val_accuracy did not improve from 0.82000
#
# Epoch 00035: saving model to cnn-model_1.h5
# Epoch 36/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.3966 - accuracy: 0.8612 - val_loss: 0.5404 - val_accuracy: 0.8382
#
# Epoch 00036: val_accuracy improved from 0.82000 to 0.83820, saving model to cnn-model_1-0036-0.838200.h5
#
# Epoch 00036: saving model to cnn-model_1.h5
# Epoch 37/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3844 - accuracy: 0.8690 - val_loss: 0.6051 - val_accuracy: 0.8232
#
# Epoch 00037: val_accuracy did not improve from 0.83820
#
# Epoch 00037: saving model to cnn-model_1.h5
# Epoch 38/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3850 - accuracy: 0.8675 - val_loss: 0.6566 - val_accuracy: 0.8086
#
# Epoch 00038: val_accuracy did not improve from 0.83820
#
# Epoch 00038: saving model to cnn-model_1.h5
# Epoch 39/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3744 - accuracy: 0.8738 - val_loss: 0.6156 - val_accuracy: 0.8189
#
# Epoch 00039: val_accuracy did not improve from 0.83820
#
# Epoch 00039: saving model to cnn-model_1.h5
# Epoch 40/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3731 - accuracy: 0.8713 - val_loss: 0.4926 - val_accuracy: 0.8466
#
# Epoch 00040: val_accuracy improved from 0.83820 to 0.84660, saving model to cnn-model_1-0040-0.846600.h5
#
# Epoch 00040: saving model to cnn-model_1.h5
# Epoch 41/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.3655 - accuracy: 0.8732 - val_loss: 0.5151 - val_accuracy: 0.8439
#
# Epoch 00041: val_accuracy did not improve from 0.84660
#
# Epoch 00041: saving model to cnn-model_1.h5
# Epoch 42/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.3540 - accuracy: 0.8760 - val_loss: 0.6388 - val_accuracy: 0.8204
#
# Epoch 00042: val_accuracy did not improve from 0.84660
#
# Epoch 00042: saving model to cnn-model_1.h5
# Epoch 43/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3470 - accuracy: 0.8800 - val_loss: 0.6019 - val_accuracy: 0.8245
#
# Epoch 00043: val_accuracy did not improve from 0.84660
#
# Epoch 00043: saving model to cnn-model_1.h5
# Epoch 44/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.3486 - accuracy: 0.8813 - val_loss: 0.5603 - val_accuracy: 0.8275
#
# Epoch 00044: val_accuracy did not improve from 0.84660
#
# Epoch 00044: saving model to cnn-model_1.h5
# Epoch 45/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.3442 - accuracy: 0.8810 - val_loss: 0.6306 - val_accuracy: 0.8186
#
# Epoch 00045: val_accuracy did not improve from 0.84660
#
# Epoch 00045: saving model to cnn-model_1.h5
# Epoch 46/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.3268 - accuracy: 0.8882 - val_loss: 0.5186 - val_accuracy: 0.8471
#
# Epoch 00046: val_accuracy improved from 0.84660 to 0.84710, saving model to cnn-model_1-0046-0.847100.h5
#
# Epoch 00046: saving model to cnn-model_1.h5
# Epoch 47/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.3275 - accuracy: 0.8866 - val_loss: 0.6126 - val_accuracy: 0.8217
#
# Epoch 00047: val_accuracy did not improve from 0.84710
#
# Epoch 00047: saving model to cnn-model_1.h5
# Epoch 48/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.3189 - accuracy: 0.8901 - val_loss: 0.5825 - val_accuracy: 0.8295
#
# Epoch 00048: val_accuracy did not improve from 0.84710
#
# Epoch 00048: saving model to cnn-model_1.h5
# Epoch 49/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.3115 - accuracy: 0.8920 - val_loss: 0.5776 - val_accuracy: 0.8397
#
# Epoch 00049: val_accuracy did not improve from 0.84710
#
# Epoch 00049: saving model to cnn-model_1.h5
# Epoch 50/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.3158 - accuracy: 0.8923 - val_loss: 0.6051 - val_accuracy: 0.8237
#
# Epoch 00050: val_accuracy did not improve from 0.84710
#
# Epoch 00050: saving model to cnn-model_1.h5
# Epoch 51/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.2957 - accuracy: 0.8978 - val_loss: 0.4462 - val_accuracy: 0.8664
#
# Epoch 00051: val_accuracy improved from 0.84710 to 0.86640, saving model to cnn-model_1-0051-0.866400.h5
#
# Epoch 00051: saving model to cnn-model_1.h5
# Epoch 52/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.2321 - accuracy: 0.9184 - val_loss: 0.4515 - val_accuracy: 0.8683
#
# Epoch 00052: val_accuracy improved from 0.86640 to 0.86830, saving model to cnn-model_1-0052-0.868300.h5
#
# Epoch 00052: saving model to cnn-model_1.h5
# Epoch 53/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.2306 - accuracy: 0.9183 - val_loss: 0.4441 - val_accuracy: 0.8680
#
# Epoch 00053: val_accuracy did not improve from 0.86830
#
# Epoch 00053: saving model to cnn-model_1.h5
# Epoch 54/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.2243 - accuracy: 0.9219 - val_loss: 0.4373 - val_accuracy: 0.8717
#
# Epoch 00054: val_accuracy improved from 0.86830 to 0.87170, saving model to cnn-model_1-0054-0.871700.h5
#
# Epoch 00054: saving model to cnn-model_1.h5
# Epoch 55/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.2175 - accuracy: 0.9228 - val_loss: 0.4374 - val_accuracy: 0.8726
#
# Epoch 00055: val_accuracy improved from 0.87170 to 0.87260, saving model to cnn-model_1-0055-0.872600.h5
#
# Epoch 00055: saving model to cnn-model_1.h5
# Epoch 56/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.2101 - accuracy: 0.9274 - val_loss: 0.4342 - val_accuracy: 0.8759
#
# Epoch 00056: val_accuracy improved from 0.87260 to 0.87590, saving model to cnn-model_1-0056-0.875900.h5
#
# Epoch 00056: saving model to cnn-model_1.h5
# Epoch 57/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.2086 - accuracy: 0.9269 - val_loss: 0.4592 - val_accuracy: 0.8683
#
# Epoch 00057: val_accuracy did not improve from 0.87590
#
# Epoch 00057: saving model to cnn-model_1.h5
# Epoch 58/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.2075 - accuracy: 0.9259 - val_loss: 0.4443 - val_accuracy: 0.8709
#
# Epoch 00058: val_accuracy did not improve from 0.87590
#
# Epoch 00058: saving model to cnn-model_1.h5
# Epoch 59/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.2012 - accuracy: 0.9276 - val_loss: 0.4530 - val_accuracy: 0.8711
#
# Epoch 00059: val_accuracy did not improve from 0.87590
#
# Epoch 00059: saving model to cnn-model_1.h5
# Epoch 60/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.2060 - accuracy: 0.9271 - val_loss: 0.4423 - val_accuracy: 0.8735
#
# Epoch 00060: val_accuracy did not improve from 0.87590
#
# Epoch 00060: saving model to cnn-model_1.h5
# Epoch 61/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1915 - accuracy: 0.9327 - val_loss: 0.4339 - val_accuracy: 0.8744
#
# Epoch 00061: val_accuracy did not improve from 0.87590
#
# Epoch 00061: saving model to cnn-model_1.h5
# Epoch 62/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1915 - accuracy: 0.9306 - val_loss: 0.4460 - val_accuracy: 0.8737
#
# Epoch 00062: val_accuracy did not improve from 0.87590
#
# Epoch 00062: saving model to cnn-model_1.h5
# Epoch 63/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1899 - accuracy: 0.9328 - val_loss: 0.4534 - val_accuracy: 0.8738
#
# Epoch 00063: val_accuracy did not improve from 0.87590
#
# Epoch 00063: saving model to cnn-model_1.h5
# Epoch 64/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1923 - accuracy: 0.9327 - val_loss: 0.4389 - val_accuracy: 0.8723
#
# Epoch 00064: val_accuracy did not improve from 0.87590
#
# Epoch 00064: saving model to cnn-model_1.h5
# Epoch 65/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1820 - accuracy: 0.9354 - val_loss: 0.4512 - val_accuracy: 0.8745
#
# Epoch 00065: val_accuracy did not improve from 0.87590
#
# Epoch 00065: saving model to cnn-model_1.h5
# Epoch 66/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1818 - accuracy: 0.9369 - val_loss: 0.4423 - val_accuracy: 0.8735
#
# Epoch 00066: val_accuracy did not improve from 0.87590
#
# Epoch 00066: saving model to cnn-model_1.h5
# Epoch 67/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1821 - accuracy: 0.9356 - val_loss: 0.4596 - val_accuracy: 0.8739
#
# Epoch 00067: val_accuracy did not improve from 0.87590
#
# Epoch 00067: saving model to cnn-model_1.h5
# Epoch 68/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1836 - accuracy: 0.9344 - val_loss: 0.4483 - val_accuracy: 0.8739
#
# Epoch 00068: val_accuracy did not improve from 0.87590
#
# Epoch 00068: saving model to cnn-model_1.h5
# Epoch 69/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1816 - accuracy: 0.9348 - val_loss: 0.4670 - val_accuracy: 0.8716
#
# Epoch 00069: val_accuracy did not improve from 0.87590
#
# Epoch 00069: saving model to cnn-model_1.h5
# Epoch 70/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1775 - accuracy: 0.9366 - val_loss: 0.4570 - val_accuracy: 0.8746
#
# Epoch 00070: val_accuracy did not improve from 0.87590
#
# Epoch 00070: saving model to cnn-model_1.h5
# Epoch 71/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1714 - accuracy: 0.9389 - val_loss: 0.4684 - val_accuracy: 0.8722
#
# Epoch 00071: val_accuracy did not improve from 0.87590
#
# Epoch 00071: saving model to cnn-model_1.h5
# Epoch 72/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1758 - accuracy: 0.9371 - val_loss: 0.4565 - val_accuracy: 0.8735
#
# Epoch 00072: val_accuracy did not improve from 0.87590
#
# Epoch 00072: saving model to cnn-model_1.h5
# Epoch 73/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1790 - accuracy: 0.9377 - val_loss: 0.4598 - val_accuracy: 0.8728
#
# Epoch 00073: val_accuracy did not improve from 0.87590
#
# Epoch 00073: saving model to cnn-model_1.h5
# Epoch 74/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1724 - accuracy: 0.9384 - val_loss: 0.4485 - val_accuracy: 0.8733
#
# Epoch 00074: val_accuracy did not improve from 0.87590
#
# Epoch 00074: saving model to cnn-model_1.h5
# Epoch 75/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1665 - accuracy: 0.9412 - val_loss: 0.4619 - val_accuracy: 0.8732
#
# Epoch 00075: val_accuracy did not improve from 0.87590
#
# Epoch 00075: saving model to cnn-model_1.h5
# Epoch 76/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1694 - accuracy: 0.9402 - val_loss: 0.4551 - val_accuracy: 0.8750
#
# Epoch 00076: val_accuracy did not improve from 0.87590
#
# Epoch 00076: saving model to cnn-model_1.h5
# Epoch 77/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1723 - accuracy: 0.9397 - val_loss: 0.4513 - val_accuracy: 0.8748
#
# Epoch 00077: val_accuracy did not improve from 0.87590
#
# Epoch 00077: saving model to cnn-model_1.h5
# Epoch 78/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1668 - accuracy: 0.9406 - val_loss: 0.4540 - val_accuracy: 0.8746
#
# Epoch 00078: val_accuracy did not improve from 0.87590
#
# Epoch 00078: saving model to cnn-model_1.h5
# Epoch 79/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1645 - accuracy: 0.9412 - val_loss: 0.4540 - val_accuracy: 0.8759
#
# Epoch 00079: val_accuracy did not improve from 0.87590
#
# Epoch 00079: saving model to cnn-model_1.h5
# Epoch 80/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1658 - accuracy: 0.9402 - val_loss: 0.4523 - val_accuracy: 0.8744
#
# Epoch 00080: val_accuracy did not improve from 0.87590
#
# Epoch 00080: saving model to cnn-model_1.h5
# Epoch 81/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1638 - accuracy: 0.9416 - val_loss: 0.4501 - val_accuracy: 0.8745
#
# Epoch 00081: val_accuracy did not improve from 0.87590
#
# Epoch 00081: saving model to cnn-model_1.h5
# Epoch 82/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1624 - accuracy: 0.9419 - val_loss: 0.4481 - val_accuracy: 0.8749
#
# Epoch 00082: val_accuracy did not improve from 0.87590
#
# Epoch 00082: saving model to cnn-model_1.h5
# Epoch 83/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1630 - accuracy: 0.9434 - val_loss: 0.4505 - val_accuracy: 0.8753
#
# Epoch 00083: val_accuracy did not improve from 0.87590
#
# Epoch 00083: saving model to cnn-model_1.h5
# Epoch 84/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1674 - accuracy: 0.9420 - val_loss: 0.4528 - val_accuracy: 0.8733
#
# Epoch 00084: val_accuracy did not improve from 0.87590
#
# Epoch 00084: saving model to cnn-model_1.h5
# Epoch 85/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1636 - accuracy: 0.9412 - val_loss: 0.4520 - val_accuracy: 0.8749
#
# Epoch 00085: val_accuracy did not improve from 0.87590
#
# Epoch 00085: saving model to cnn-model_1.h5
# Epoch 86/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1632 - accuracy: 0.9428 - val_loss: 0.4508 - val_accuracy: 0.8748
#
# Epoch 00086: val_accuracy did not improve from 0.87590
#
# Epoch 00086: saving model to cnn-model_1.h5
# Epoch 87/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1650 - accuracy: 0.9420 - val_loss: 0.4525 - val_accuracy: 0.8737
#
# Epoch 00087: val_accuracy did not improve from 0.87590
#
# Epoch 00087: saving model to cnn-model_1.h5
# Epoch 88/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1639 - accuracy: 0.9410 - val_loss: 0.4556 - val_accuracy: 0.8744
#
# Epoch 00088: val_accuracy did not improve from 0.87590
#
# Epoch 00088: saving model to cnn-model_1.h5
# Epoch 89/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1656 - accuracy: 0.9400 - val_loss: 0.4522 - val_accuracy: 0.8741
#
# Epoch 00089: val_accuracy did not improve from 0.87590
#
# Epoch 00089: saving model to cnn-model_1.h5
# Epoch 90/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1607 - accuracy: 0.9426 - val_loss: 0.4507 - val_accuracy: 0.8743
#
# Epoch 00090: val_accuracy did not improve from 0.87590
#
# Epoch 00090: saving model to cnn-model_1.h5
# Epoch 91/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1615 - accuracy: 0.9433 - val_loss: 0.4503 - val_accuracy: 0.8753
#
# Epoch 00091: val_accuracy did not improve from 0.87590
#
# Epoch 00091: saving model to cnn-model_1.h5
# Epoch 92/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1613 - accuracy: 0.9418 - val_loss: 0.4518 - val_accuracy: 0.8747
#
# Epoch 00092: val_accuracy did not improve from 0.87590
#
# Epoch 00092: saving model to cnn-model_1.h5
# Epoch 93/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1627 - accuracy: 0.9410 - val_loss: 0.4497 - val_accuracy: 0.8751
#
# Epoch 00093: val_accuracy did not improve from 0.87590
#
# Epoch 00093: saving model to cnn-model_1.h5
# Epoch 94/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1613 - accuracy: 0.9430 - val_loss: 0.4527 - val_accuracy: 0.8750
#
# Epoch 00094: val_accuracy did not improve from 0.87590
#
# Epoch 00094: saving model to cnn-model_1.h5
# Epoch 95/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1606 - accuracy: 0.9420 - val_loss: 0.4502 - val_accuracy: 0.8749
#
# Epoch 00095: val_accuracy did not improve from 0.87590
#
# Epoch 00095: saving model to cnn-model_1.h5
# Epoch 96/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1595 - accuracy: 0.9430 - val_loss: 0.4528 - val_accuracy: 0.8760
#
# Epoch 00096: val_accuracy improved from 0.87590 to 0.87600, saving model to cnn-model_1-0096-0.876000.h5
#
# Epoch 00096: saving model to cnn-model_1.h5
# Epoch 97/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1618 - accuracy: 0.9439 - val_loss: 0.4516 - val_accuracy: 0.8745
#
# Epoch 00097: val_accuracy did not improve from 0.87600
#
# Epoch 00097: saving model to cnn-model_1.h5
# Epoch 98/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1598 - accuracy: 0.9419 - val_loss: 0.4511 - val_accuracy: 0.8748
#
# Epoch 00098: val_accuracy did not improve from 0.87600
#
# Epoch 00098: saving model to cnn-model_1.h5
# Epoch 99/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1627 - accuracy: 0.9417 - val_loss: 0.4479 - val_accuracy: 0.8755
#
# Epoch 00099: val_accuracy did not improve from 0.87600
#
# Epoch 00099: saving model to cnn-model_1.h5
# Epoch 100/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1625 - accuracy: 0.9396 - val_loss: 0.4528 - val_accuracy: 0.8750
#
# Epoch 00100: val_accuracy did not improve from 0.87600
#
# Epoch 00100: saving model to cnn-model_1.h5
# Epoch 101/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1549 - accuracy: 0.9454 - val_loss: 0.4528 - val_accuracy: 0.8752
#
# Epoch 00101: val_accuracy did not improve from 0.87600
#
# Epoch 00101: saving model to cnn-model_1.h5
# Epoch 102/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1626 - accuracy: 0.9421 - val_loss: 0.4525 - val_accuracy: 0.8742
#
# Epoch 00102: val_accuracy did not improve from 0.87600
#
# Epoch 00102: saving model to cnn-model_1.h5
# Epoch 103/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1588 - accuracy: 0.9446 - val_loss: 0.4504 - val_accuracy: 0.8751
#
# Epoch 00103: val_accuracy did not improve from 0.87600
#
# Epoch 00103: saving model to cnn-model_1.h5
# Epoch 104/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1609 - accuracy: 0.9415 - val_loss: 0.4506 - val_accuracy: 0.8745
#
# Epoch 00104: val_accuracy did not improve from 0.87600
#
# Epoch 00104: saving model to cnn-model_1.h5
# Epoch 105/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1556 - accuracy: 0.9457 - val_loss: 0.4497 - val_accuracy: 0.8761
#
# Epoch 00105: val_accuracy improved from 0.87600 to 0.87610, saving model to cnn-model_1-0105-0.876100.h5
#
# Epoch 00105: saving model to cnn-model_1.h5
# Epoch 106/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1554 - accuracy: 0.9443 - val_loss: 0.4538 - val_accuracy: 0.8744
#
# Epoch 00106: val_accuracy did not improve from 0.87610
#
# Epoch 00106: saving model to cnn-model_1.h5
# Epoch 107/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1560 - accuracy: 0.9453 - val_loss: 0.4502 - val_accuracy: 0.8754
#
# Epoch 00107: val_accuracy did not improve from 0.87610
#
# Epoch 00107: saving model to cnn-model_1.h5
# Epoch 108/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1635 - accuracy: 0.9419 - val_loss: 0.4518 - val_accuracy: 0.8750
#
# Epoch 00108: val_accuracy did not improve from 0.87610
#
# Epoch 00108: saving model to cnn-model_1.h5
# Epoch 109/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1650 - accuracy: 0.9409 - val_loss: 0.4503 - val_accuracy: 0.8753
#
# Epoch 00109: val_accuracy did not improve from 0.87610
#
# Epoch 00109: saving model to cnn-model_1.h5
# Epoch 110/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1584 - accuracy: 0.9436 - val_loss: 0.4485 - val_accuracy: 0.8758
#
# Epoch 00110: val_accuracy did not improve from 0.87610
#
# Epoch 00110: saving model to cnn-model_1.h5
# Epoch 111/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1599 - accuracy: 0.9430 - val_loss: 0.4522 - val_accuracy: 0.8750
#
# Epoch 00111: val_accuracy did not improve from 0.87610
#
# Epoch 00111: saving model to cnn-model_1.h5
# Epoch 112/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1586 - accuracy: 0.9430 - val_loss: 0.4518 - val_accuracy: 0.8756
#
# Epoch 00112: val_accuracy did not improve from 0.87610
#
# Epoch 00112: saving model to cnn-model_1.h5
# Epoch 113/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1564 - accuracy: 0.9453 - val_loss: 0.4512 - val_accuracy: 0.8759
#
# Epoch 00113: val_accuracy did not improve from 0.87610
#
# Epoch 00113: saving model to cnn-model_1.h5
# Epoch 114/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1596 - accuracy: 0.9434 - val_loss: 0.4489 - val_accuracy: 0.8758
#
# Epoch 00114: val_accuracy did not improve from 0.87610
#
# Epoch 00114: saving model to cnn-model_1.h5
# Epoch 115/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1622 - accuracy: 0.9420 - val_loss: 0.4508 - val_accuracy: 0.8753
#
# Epoch 00115: val_accuracy did not improve from 0.87610
#
# Epoch 00115: saving model to cnn-model_1.h5
# Epoch 116/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1581 - accuracy: 0.9434 - val_loss: 0.4543 - val_accuracy: 0.8750
#
# Epoch 00116: val_accuracy did not improve from 0.87610
#
# Epoch 00116: saving model to cnn-model_1.h5
# Epoch 117/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1578 - accuracy: 0.9440 - val_loss: 0.4525 - val_accuracy: 0.8752
#
# Epoch 00117: val_accuracy did not improve from 0.87610
#
# Epoch 00117: saving model to cnn-model_1.h5
# Epoch 118/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1588 - accuracy: 0.9440 - val_loss: 0.4527 - val_accuracy: 0.8749
#
# Epoch 00118: val_accuracy did not improve from 0.87610
#
# Epoch 00118: saving model to cnn-model_1.h5
# Epoch 119/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1557 - accuracy: 0.9453 - val_loss: 0.4512 - val_accuracy: 0.8766
#
# Epoch 00119: val_accuracy improved from 0.87610 to 0.87660, saving model to cnn-model_1-0119-0.876600.h5
#
# Epoch 00119: saving model to cnn-model_1.h5
# Epoch 120/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1557 - accuracy: 0.9444 - val_loss: 0.4506 - val_accuracy: 0.8762
#
# Epoch 00120: val_accuracy did not improve from 0.87660
#
# Epoch 00120: saving model to cnn-model_1.h5
# Epoch 121/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1534 - accuracy: 0.9445 - val_loss: 0.4519 - val_accuracy: 0.8759
#
# Epoch 00121: val_accuracy did not improve from 0.87660
#
# Epoch 00121: saving model to cnn-model_1.h5
# Epoch 122/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1534 - accuracy: 0.9454 - val_loss: 0.4528 - val_accuracy: 0.8758
#
# Epoch 00122: val_accuracy did not improve from 0.87660
#
# Epoch 00122: saving model to cnn-model_1.h5
# Epoch 123/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1523 - accuracy: 0.9457 - val_loss: 0.4517 - val_accuracy: 0.8763
#
# Epoch 00123: val_accuracy did not improve from 0.87660
#
# Epoch 00123: saving model to cnn-model_1.h5
# Epoch 124/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1592 - accuracy: 0.9432 - val_loss: 0.4521 - val_accuracy: 0.8766
#
# Epoch 00124: val_accuracy did not improve from 0.87660
#
# Epoch 00124: saving model to cnn-model_1.h5
# Epoch 125/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1537 - accuracy: 0.9456 - val_loss: 0.4528 - val_accuracy: 0.8757
#
# Epoch 00125: val_accuracy did not improve from 0.87660
#
# Epoch 00125: saving model to cnn-model_1.h5
# Epoch 126/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1614 - accuracy: 0.9430 - val_loss: 0.4537 - val_accuracy: 0.8759
#
# Epoch 00126: val_accuracy did not improve from 0.87660
#
# Epoch 00126: saving model to cnn-model_1.h5
# Epoch 127/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1542 - accuracy: 0.9449 - val_loss: 0.4550 - val_accuracy: 0.8753
#
# Epoch 00127: val_accuracy did not improve from 0.87660
#
# Epoch 00127: saving model to cnn-model_1.h5
# Epoch 128/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1554 - accuracy: 0.9454 - val_loss: 0.4553 - val_accuracy: 0.8746
#
# Epoch 00128: val_accuracy did not improve from 0.87660
#
# Epoch 00128: saving model to cnn-model_1.h5
# Epoch 129/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1615 - accuracy: 0.9452 - val_loss: 0.4535 - val_accuracy: 0.8753
#
# Epoch 00129: val_accuracy did not improve from 0.87660
#
# Epoch 00129: saving model to cnn-model_1.h5
# Epoch 130/200
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1548 - accuracy: 0.9447 - val_loss: 0.4535 - val_accuracy: 0.8759
#
# Epoch 00130: val_accuracy did not improve from 0.87660
#
# Epoch 00130: saving model to cnn-model_1.h5
# Epoch 131/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1530 - accuracy: 0.9446 - val_loss: 0.4574 - val_accuracy: 0.8754
#
# Epoch 00131: val_accuracy did not improve from 0.87660
#
# Epoch 00131: saving model to cnn-model_1.h5
# Epoch 132/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1560 - accuracy: 0.9453 - val_loss: 0.4542 - val_accuracy: 0.8752
#
# Epoch 00132: val_accuracy did not improve from 0.87660
#
# Epoch 00132: saving model to cnn-model_1.h5
# Epoch 133/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1593 - accuracy: 0.9420 - val_loss: 0.4540 - val_accuracy: 0.8759
#
# Epoch 00133: val_accuracy did not improve from 0.87660
#
# Epoch 00133: saving model to cnn-model_1.h5
# Epoch 134/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1552 - accuracy: 0.9442 - val_loss: 0.4514 - val_accuracy: 0.8757
#
# Epoch 00134: val_accuracy did not improve from 0.87660
#
# Epoch 00134: saving model to cnn-model_1.h5
# Epoch 135/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1567 - accuracy: 0.9428 - val_loss: 0.4534 - val_accuracy: 0.8761
#
# Epoch 00135: val_accuracy did not improve from 0.87660
#
# Epoch 00135: saving model to cnn-model_1.h5
# Epoch 136/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1490 - accuracy: 0.9471 - val_loss: 0.4524 - val_accuracy: 0.8749
#
# Epoch 00136: val_accuracy did not improve from 0.87660
#
# Epoch 00136: saving model to cnn-model_1.h5
# Epoch 137/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1529 - accuracy: 0.9452 - val_loss: 0.4509 - val_accuracy: 0.8768
#
# Epoch 00137: val_accuracy improved from 0.87660 to 0.87680, saving model to cnn-model_1-0137-0.876800.h5
#
# Epoch 00137: saving model to cnn-model_1.h5
# Epoch 138/200
# 390/390 [==============================] - 28s 72ms/step - loss: 0.1524 - accuracy: 0.9457 - val_loss: 0.4546 - val_accuracy: 0.8760
#
# Epoch 00138: val_accuracy did not improve from 0.87680
#
# Epoch 00138: saving model to cnn-model_1.h5
# Epoch 139/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1505 - accuracy: 0.9459 - val_loss: 0.4528 - val_accuracy: 0.8757
#
# Epoch 00139: val_accuracy did not improve from 0.87680
#
# Epoch 00139: saving model to cnn-model_1.h5
# Epoch 140/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1544 - accuracy: 0.9446 - val_loss: 0.4551 - val_accuracy: 0.8755
#
# Epoch 00140: val_accuracy did not improve from 0.87680
#
# Epoch 00140: saving model to cnn-model_1.h5
# Epoch 141/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1546 - accuracy: 0.9449 - val_loss: 0.4521 - val_accuracy: 0.8774
#
# Epoch 00141: val_accuracy improved from 0.87680 to 0.87740, saving model to cnn-model_1-0141-0.877400.h5
#
# Epoch 00141: saving model to cnn-model_1.h5
# Epoch 142/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1552 - accuracy: 0.9446 - val_loss: 0.4548 - val_accuracy: 0.8754
#
# Epoch 00142: val_accuracy did not improve from 0.87740
#
# Epoch 00142: saving model to cnn-model_1.h5
# Epoch 143/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1530 - accuracy: 0.9470 - val_loss: 0.4578 - val_accuracy: 0.8751
#
# Epoch 00143: val_accuracy did not improve from 0.87740
#
# Epoch 00143: saving model to cnn-model_1.h5
# Epoch 144/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1502 - accuracy: 0.9467 - val_loss: 0.4551 - val_accuracy: 0.8757
#
# Epoch 00144: val_accuracy did not improve from 0.87740
#
# Epoch 00144: saving model to cnn-model_1.h5
# Epoch 145/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1574 - accuracy: 0.9419 - val_loss: 0.4541 - val_accuracy: 0.8757
#
# Epoch 00145: val_accuracy did not improve from 0.87740
#
# Epoch 00145: saving model to cnn-model_1.h5
# Epoch 146/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1567 - accuracy: 0.9452 - val_loss: 0.4545 - val_accuracy: 0.8763
#
# Epoch 00146: val_accuracy did not improve from 0.87740
#
# Epoch 00146: saving model to cnn-model_1.h5
# Epoch 147/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1507 - accuracy: 0.9463 - val_loss: 0.4547 - val_accuracy: 0.8751
#
# Epoch 00147: val_accuracy did not improve from 0.87740
#
# Epoch 00147: saving model to cnn-model_1.h5
# Epoch 148/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1495 - accuracy: 0.9462 - val_loss: 0.4553 - val_accuracy: 0.8761
#
# Epoch 00148: val_accuracy did not improve from 0.87740
#
# Epoch 00148: saving model to cnn-model_1.h5
# Epoch 149/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1468 - accuracy: 0.9475 - val_loss: 0.4539 - val_accuracy: 0.8768
#
# Epoch 00149: val_accuracy did not improve from 0.87740
#
# Epoch 00149: saving model to cnn-model_1.h5
# Epoch 150/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1478 - accuracy: 0.9483 - val_loss: 0.4525 - val_accuracy: 0.8757
#
# Epoch 00150: val_accuracy did not improve from 0.87740
#
# Epoch 00150: saving model to cnn-model_1.h5
# Epoch 151/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1551 - accuracy: 0.9463 - val_loss: 0.4556 - val_accuracy: 0.8762
#
# Epoch 00151: val_accuracy did not improve from 0.87740
#
# Epoch 00151: saving model to cnn-model_1.h5
# Epoch 152/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1519 - accuracy: 0.9449 - val_loss: 0.4551 - val_accuracy: 0.8757
#
# Epoch 00152: val_accuracy did not improve from 0.87740
#
# Epoch 00152: saving model to cnn-model_1.h5
# Epoch 153/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1503 - accuracy: 0.9466 - val_loss: 0.4563 - val_accuracy: 0.8759
#
# Epoch 00153: val_accuracy did not improve from 0.87740
#
# Epoch 00153: saving model to cnn-model_1.h5
# Epoch 154/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1509 - accuracy: 0.9450 - val_loss: 0.4541 - val_accuracy: 0.8765
#
# Epoch 00154: val_accuracy did not improve from 0.87740
#
# Epoch 00154: saving model to cnn-model_1.h5
# Epoch 155/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1489 - accuracy: 0.9478 - val_loss: 0.4551 - val_accuracy: 0.8767
#
# Epoch 00155: val_accuracy did not improve from 0.87740
#
# Epoch 00155: saving model to cnn-model_1.h5
# Epoch 156/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1504 - accuracy: 0.9472 - val_loss: 0.4561 - val_accuracy: 0.8757
#
# Epoch 00156: val_accuracy did not improve from 0.87740
#
# Epoch 00156: saving model to cnn-model_1.h5
# Epoch 157/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1539 - accuracy: 0.9453 - val_loss: 0.4556 - val_accuracy: 0.8754
#
# Epoch 00157: val_accuracy did not improve from 0.87740
#
# Epoch 00157: saving model to cnn-model_1.h5
# Epoch 158/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.1522 - accuracy: 0.9464 - val_loss: 0.4558 - val_accuracy: 0.8748
#
# Epoch 00158: val_accuracy did not improve from 0.87740
#
# Epoch 00158: saving model to cnn-model_1.h5
# Epoch 159/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1477 - accuracy: 0.9472 - val_loss: 0.4555 - val_accuracy: 0.8758
#
# Epoch 00159: val_accuracy did not improve from 0.87740
#
# Epoch 00159: saving model to cnn-model_1.h5
# Epoch 160/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1455 - accuracy: 0.9479 - val_loss: 0.4543 - val_accuracy: 0.8757
#
# Epoch 00160: val_accuracy did not improve from 0.87740
#
# Epoch 00160: saving model to cnn-model_1.h5
# Epoch 161/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1504 - accuracy: 0.9463 - val_loss: 0.4546 - val_accuracy: 0.8758
#
# Epoch 00161: val_accuracy did not improve from 0.87740
#
# Epoch 00161: saving model to cnn-model_1.h5
# Epoch 162/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1520 - accuracy: 0.9459 - val_loss: 0.4558 - val_accuracy: 0.8760
#
# Epoch 00162: val_accuracy did not improve from 0.87740
#
# Epoch 00162: saving model to cnn-model_1.h5
# Epoch 163/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1449 - accuracy: 0.9481 - val_loss: 0.4551 - val_accuracy: 0.8757
#
# Epoch 00163: val_accuracy did not improve from 0.87740
#
# Epoch 00163: saving model to cnn-model_1.h5
# Epoch 164/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.1479 - accuracy: 0.9474 - val_loss: 0.4557 - val_accuracy: 0.8756
#
# Epoch 00164: val_accuracy did not improve from 0.87740
#
# Epoch 00164: saving model to cnn-model_1.h5
# Epoch 165/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1498 - accuracy: 0.9474 - val_loss: 0.4570 - val_accuracy: 0.8758
#
# Epoch 00165: val_accuracy did not improve from 0.87740
#
# Epoch 00165: saving model to cnn-model_1.h5
# Epoch 166/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1502 - accuracy: 0.9466 - val_loss: 0.4575 - val_accuracy: 0.8754
#
# Epoch 00166: val_accuracy did not improve from 0.87740
#
# Epoch 00166: saving model to cnn-model_1.h5
# Epoch 167/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.1521 - accuracy: 0.9448 - val_loss: 0.4561 - val_accuracy: 0.8754
#
# Epoch 00167: val_accuracy did not improve from 0.87740
#
# Epoch 00167: saving model to cnn-model_1.h5
# Epoch 168/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1495 - accuracy: 0.9455 - val_loss: 0.4556 - val_accuracy: 0.8760
#
# Epoch 00168: val_accuracy did not improve from 0.87740
#
# Epoch 00168: saving model to cnn-model_1.h5
# Epoch 169/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1445 - accuracy: 0.9474 - val_loss: 0.4575 - val_accuracy: 0.8752
#
# Epoch 00169: val_accuracy did not improve from 0.87740
#
# Epoch 00169: saving model to cnn-model_1.h5
# Epoch 170/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1515 - accuracy: 0.9458 - val_loss: 0.4573 - val_accuracy: 0.8755
#
# Epoch 00170: val_accuracy did not improve from 0.87740
#
# Epoch 00170: saving model to cnn-model_1.h5
# Epoch 171/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1504 - accuracy: 0.9459 - val_loss: 0.4560 - val_accuracy: 0.8761
#
# Epoch 00171: val_accuracy did not improve from 0.87740
#
# Epoch 00171: saving model to cnn-model_1.h5
# Epoch 172/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1483 - accuracy: 0.9464 - val_loss: 0.4577 - val_accuracy: 0.8755
#
# Epoch 00172: val_accuracy did not improve from 0.87740
#
# Epoch 00172: saving model to cnn-model_1.h5
# Epoch 173/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1519 - accuracy: 0.9467 - val_loss: 0.4579 - val_accuracy: 0.8760
#
# Epoch 00173: val_accuracy did not improve from 0.87740
#
# Epoch 00173: saving model to cnn-model_1.h5
# Epoch 174/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1514 - accuracy: 0.9494 - val_loss: 0.4598 - val_accuracy: 0.8756
#
# Epoch 00174: val_accuracy did not improve from 0.87740
#
# Epoch 00174: saving model to cnn-model_1.h5
# Epoch 175/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.1545 - accuracy: 0.9447 - val_loss: 0.4589 - val_accuracy: 0.8758
#
# Epoch 00175: val_accuracy did not improve from 0.87740
#
# Epoch 00175: saving model to cnn-model_1.h5
# Epoch 176/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1498 - accuracy: 0.9478 - val_loss: 0.4578 - val_accuracy: 0.8752
#
# Epoch 00176: val_accuracy did not improve from 0.87740
#
# Epoch 00176: saving model to cnn-model_1.h5
# Epoch 177/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1502 - accuracy: 0.9454 - val_loss: 0.4580 - val_accuracy: 0.8757
#
# Epoch 00177: val_accuracy did not improve from 0.87740
#
# Epoch 00177: saving model to cnn-model_1.h5
# Epoch 178/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1540 - accuracy: 0.9443 - val_loss: 0.4572 - val_accuracy: 0.8757
#
# Epoch 00178: val_accuracy did not improve from 0.87740
#
# Epoch 00178: saving model to cnn-model_1.h5
# Epoch 179/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1473 - accuracy: 0.9469 - val_loss: 0.4582 - val_accuracy: 0.8763
#
# Epoch 00179: val_accuracy did not improve from 0.87740
#
# Epoch 00179: saving model to cnn-model_1.h5
# Epoch 180/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1488 - accuracy: 0.9474 - val_loss: 0.4588 - val_accuracy: 0.8756
#
# Epoch 00180: val_accuracy did not improve from 0.87740
#
# Epoch 00180: saving model to cnn-model_1.h5
# Epoch 181/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1491 - accuracy: 0.9466 - val_loss: 0.4567 - val_accuracy: 0.8758
#
# Epoch 00181: val_accuracy did not improve from 0.87740
#
# Epoch 00181: saving model to cnn-model_1.h5
# Epoch 182/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1512 - accuracy: 0.9481 - val_loss: 0.4556 - val_accuracy: 0.8767
#
# Epoch 00182: val_accuracy did not improve from 0.87740
#
# Epoch 00182: saving model to cnn-model_1.h5
# Epoch 183/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1458 - accuracy: 0.9467 - val_loss: 0.4565 - val_accuracy: 0.8768
#
# Epoch 00183: val_accuracy did not improve from 0.87740
#
# Epoch 00183: saving model to cnn-model_1.h5
# Epoch 184/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1533 - accuracy: 0.9473 - val_loss: 0.4567 - val_accuracy: 0.8766
#
# Epoch 00184: val_accuracy did not improve from 0.87740
#
# Epoch 00184: saving model to cnn-model_1.h5
# Epoch 185/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1454 - accuracy: 0.9476 - val_loss: 0.4585 - val_accuracy: 0.8767
#
# Epoch 00185: val_accuracy did not improve from 0.87740
#
# Epoch 00185: saving model to cnn-model_1.h5
# Epoch 186/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.1454 - accuracy: 0.9481 - val_loss: 0.4578 - val_accuracy: 0.8760
#
# Epoch 00186: val_accuracy did not improve from 0.87740
#
# Epoch 00186: saving model to cnn-model_1.h5
# Epoch 187/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1516 - accuracy: 0.9456 - val_loss: 0.4555 - val_accuracy: 0.8760
#
# Epoch 00187: val_accuracy did not improve from 0.87740
#
# Epoch 00187: saving model to cnn-model_1.h5
# Epoch 188/200
# 390/390 [==============================] - 27s 69ms/step - loss: 0.1468 - accuracy: 0.9479 - val_loss: 0.4585 - val_accuracy: 0.8759
#
# Epoch 00188: val_accuracy did not improve from 0.87740
#
# Epoch 00188: saving model to cnn-model_1.h5
# Epoch 189/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1502 - accuracy: 0.9463 - val_loss: 0.4573 - val_accuracy: 0.8765
#
# Epoch 00189: val_accuracy did not improve from 0.87740
#
# Epoch 00189: saving model to cnn-model_1.h5
# Epoch 190/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1484 - accuracy: 0.9473 - val_loss: 0.4580 - val_accuracy: 0.8756
#
# Epoch 00190: val_accuracy did not improve from 0.87740
#
# Epoch 00190: saving model to cnn-model_1.h5
# Epoch 191/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1512 - accuracy: 0.9465 - val_loss: 0.4566 - val_accuracy: 0.8769
#
# Epoch 00191: val_accuracy did not improve from 0.87740
#
# Epoch 00191: saving model to cnn-model_1.h5
# Epoch 192/200
# 390/390 [==============================] - 27s 68ms/step - loss: 0.1443 - accuracy: 0.9470 - val_loss: 0.4590 - val_accuracy: 0.8759
#
# Epoch 00192: val_accuracy did not improve from 0.87740
#
# Epoch 00192: saving model to cnn-model_1.h5
# Epoch 193/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1529 - accuracy: 0.9465 - val_loss: 0.4580 - val_accuracy: 0.8767
#
# Epoch 00193: val_accuracy did not improve from 0.87740
#
# Epoch 00193: saving model to cnn-model_1.h5
# Epoch 194/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.1445 - accuracy: 0.9486 - val_loss: 0.4553 - val_accuracy: 0.8768
#
# Epoch 00194: val_accuracy did not improve from 0.87740
#
# Epoch 00194: saving model to cnn-model_1.h5
# Epoch 195/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1500 - accuracy: 0.9456 - val_loss: 0.4583 - val_accuracy: 0.8760
#
# Epoch 00195: val_accuracy did not improve from 0.87740
#
# Epoch 00195: saving model to cnn-model_1.h5
# Epoch 196/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1496 - accuracy: 0.9465 - val_loss: 0.4580 - val_accuracy: 0.8769
#
# Epoch 00196: val_accuracy did not improve from 0.87740
#
# Epoch 00196: saving model to cnn-model_1.h5
# Epoch 197/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.1537 - accuracy: 0.9444 - val_loss: 0.4563 - val_accuracy: 0.8774
#
# Epoch 00197: val_accuracy did not improve from 0.87740
#
# Epoch 00197: saving model to cnn-model_1.h5
# Epoch 198/200
# 390/390 [==============================] - 26s 68ms/step - loss: 0.1493 - accuracy: 0.9472 - val_loss: 0.4569 - val_accuracy: 0.8778
#
# Epoch 00198: val_accuracy improved from 0.87740 to 0.87780, saving model to cnn-model_1-0198-0.877800.h5
#
# Epoch 00198: saving model to cnn-model_1.h5
# Epoch 199/200
# 390/390 [==============================] - 26s 67ms/step - loss: 0.1488 - accuracy: 0.9462 - val_loss: 0.4547 - val_accuracy: 0.8776
#
# Epoch 00199: val_accuracy did not improve from 0.87780
#
# Epoch 00199: saving model to cnn-model_1.h5
# Epoch 200/200
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1473 - accuracy: 0.9489 - val_loss: 0.4583 - val_accuracy: 0.8764
#
# Epoch 00200: val_accuracy did not improve from 0.87780
#
# Epoch 00200: saving model to cnn-model_1.h5
# Test loss: 0.45834437012672424
# Test accuracy: 0.8763999938964844
# Test error: 0.12360000610351562

# %%
model_2 = model_cnn
model_2 = advanced_training_and_evaluation(model=model_2,
                                           model_id='model_2',
                                           scheduler=scheduler_lr_3)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 390/390 [==============================] - 32s 79ms/step - loss: 1.6692 - accuracy: 0.3830 - val_loss: 2.1341 - val_accuracy: 0.4339
#
# Epoch 00001: val_accuracy improved from -inf to 0.43390, saving model to cnn-model_2-0001-0.433900.h5
#
# Epoch 00001: saving model to cnn-model_2.h5
# Epoch 2/200
# 390/390 [==============================] - 30s 76ms/step - loss: 1.1682 - accuracy: 0.5843 - val_loss: 3.0741 - val_accuracy: 0.4101
#
# Epoch 00002: val_accuracy did not improve from 0.43390
#
# Epoch 00002: saving model to cnn-model_2.h5
# Epoch 3/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.9469 - accuracy: 0.6648 - val_loss: 1.0245 - val_accuracy: 0.6654
#
# Epoch 00003: val_accuracy improved from 0.43390 to 0.66540, saving model to cnn-model_2-0003-0.665400.h5
#
# Epoch 00003: saving model to cnn-model_2.h5
# Epoch 4/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.8250 - accuracy: 0.7122 - val_loss: 1.6188 - val_accuracy: 0.5863
#
# Epoch 00004: val_accuracy did not improve from 0.66540
#
# Epoch 00004: saving model to cnn-model_2.h5
# Epoch 5/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7398 - accuracy: 0.7451 - val_loss: 1.2548 - val_accuracy: 0.6214
#
# Epoch 00005: val_accuracy did not improve from 0.66540
#
# Epoch 00005: saving model to cnn-model_2.h5
# Epoch 6/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.6634 - accuracy: 0.7655 - val_loss: 1.2086 - val_accuracy: 0.6568
#
# Epoch 00006: val_accuracy did not improve from 0.66540
#
# Epoch 00006: saving model to cnn-model_2.h5
# Epoch 7/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.6138 - accuracy: 0.7874 - val_loss: 1.1357 - val_accuracy: 0.6719
#
# Epoch 00007: val_accuracy improved from 0.66540 to 0.67190, saving model to cnn-model_2-0007-0.671900.h5
#
# Epoch 00007: saving model to cnn-model_2.h5
# Epoch 8/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.5676 - accuracy: 0.8009 - val_loss: 1.0016 - val_accuracy: 0.6973
#
# Epoch 00008: val_accuracy improved from 0.67190 to 0.69730, saving model to cnn-model_2-0008-0.697300.h5
#
# Epoch 00008: saving model to cnn-model_2.h5
# Epoch 9/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.5269 - accuracy: 0.8159 - val_loss: 0.9205 - val_accuracy: 0.7147
#
# Epoch 00009: val_accuracy improved from 0.69730 to 0.71470, saving model to cnn-model_2-0009-0.714700.h5
#
# Epoch 00009: saving model to cnn-model_2.h5
# Epoch 10/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4981 - accuracy: 0.8250 - val_loss: 0.9562 - val_accuracy: 0.7184
#
# Epoch 00010: val_accuracy improved from 0.71470 to 0.71840, saving model to cnn-model_2-0010-0.718400.h5
#
# Epoch 00010: saving model to cnn-model_2.h5
# Epoch 11/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4684 - accuracy: 0.8378 - val_loss: 0.6434 - val_accuracy: 0.8046
#
# Epoch 00011: val_accuracy improved from 0.71840 to 0.80460, saving model to cnn-model_2-0011-0.804600.h5
#
# Epoch 00011: saving model to cnn-model_2.h5
# Epoch 12/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4298 - accuracy: 0.8500 - val_loss: 0.6912 - val_accuracy: 0.7822
#
# Epoch 00012: val_accuracy did not improve from 0.80460
#
# Epoch 00012: saving model to cnn-model_2.h5
# Epoch 13/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.4164 - accuracy: 0.8530 - val_loss: 0.6972 - val_accuracy: 0.7783
#
# Epoch 00013: val_accuracy did not improve from 0.80460
#
# Epoch 00013: saving model to cnn-model_2.h5
# Epoch 14/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3864 - accuracy: 0.8633 - val_loss: 0.7329 - val_accuracy: 0.7817
#
# Epoch 00014: val_accuracy did not improve from 0.80460
#
# Epoch 00014: saving model to cnn-model_2.h5
# Epoch 15/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.3739 - accuracy: 0.8695 - val_loss: 0.5922 - val_accuracy: 0.8134
#
# Epoch 00015: val_accuracy improved from 0.80460 to 0.81340, saving model to cnn-model_2-0015-0.813400.h5
#
# Epoch 00015: saving model to cnn-model_2.h5
# Epoch 16/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.3483 - accuracy: 0.8775 - val_loss: 0.8264 - val_accuracy: 0.7549
#
# Epoch 00016: val_accuracy did not improve from 0.81340
#
# Epoch 00016: saving model to cnn-model_2.h5
# Epoch 17/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3353 - accuracy: 0.8822 - val_loss: 0.7320 - val_accuracy: 0.7963
#
# Epoch 00017: val_accuracy did not improve from 0.81340
#
# Epoch 00017: saving model to cnn-model_2.h5
# Epoch 18/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.3122 - accuracy: 0.8904 - val_loss: 0.9643 - val_accuracy: 0.7437
#
# Epoch 00018: val_accuracy did not improve from 0.81340
#
# Epoch 00018: saving model to cnn-model_2.h5
# Epoch 19/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.2982 - accuracy: 0.8942 - val_loss: 0.6431 - val_accuracy: 0.8038
#
# Epoch 00019: val_accuracy did not improve from 0.81340
#
# Epoch 00019: saving model to cnn-model_2.h5
# Epoch 20/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.2838 - accuracy: 0.9003 - val_loss: 0.6296 - val_accuracy: 0.8206
#
# Epoch 00020: val_accuracy improved from 0.81340 to 0.82060, saving model to cnn-model_2-0020-0.820600.h5
#
# Epoch 00020: saving model to cnn-model_2.h5
# Epoch 21/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.2795 - accuracy: 0.9023 - val_loss: 0.6972 - val_accuracy: 0.8001
#
# Epoch 00021: val_accuracy did not improve from 0.82060
#
# Epoch 00021: saving model to cnn-model_2.h5
# Epoch 22/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.2578 - accuracy: 0.9080 - val_loss: 0.5264 - val_accuracy: 0.8459
#
# Epoch 00022: val_accuracy improved from 0.82060 to 0.84590, saving model to cnn-model_2-0022-0.845900.h5
#
# Epoch 00022: saving model to cnn-model_2.h5
# Epoch 23/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.2472 - accuracy: 0.9120 - val_loss: 0.6792 - val_accuracy: 0.8141
#
# Epoch 00023: val_accuracy did not improve from 0.84590
#
# Epoch 00023: saving model to cnn-model_2.h5
# Epoch 24/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2399 - accuracy: 0.9156 - val_loss: 0.7919 - val_accuracy: 0.7907
#
# Epoch 00024: val_accuracy did not improve from 0.84590
#
# Epoch 00024: saving model to cnn-model_2.h5
# Epoch 25/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2338 - accuracy: 0.9174 - val_loss: 0.6099 - val_accuracy: 0.8243
#
# Epoch 00025: val_accuracy did not improve from 0.84590
#
# Epoch 00025: saving model to cnn-model_2.h5
# Epoch 26/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2160 - accuracy: 0.9236 - val_loss: 0.6815 - val_accuracy: 0.8008
#
# Epoch 00026: val_accuracy did not improve from 0.84590
#
# Epoch 00026: saving model to cnn-model_2.h5
# Epoch 27/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.2125 - accuracy: 0.9238 - val_loss: 0.4792 - val_accuracy: 0.8613
#
# Epoch 00027: val_accuracy improved from 0.84590 to 0.86130, saving model to cnn-model_2-0027-0.861300.h5
#
# Epoch 00027: saving model to cnn-model_2.h5
# Epoch 28/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.1988 - accuracy: 0.9305 - val_loss: 0.8142 - val_accuracy: 0.8008
#
# Epoch 00028: val_accuracy did not improve from 0.86130
#
# Epoch 00028: saving model to cnn-model_2.h5
# Epoch 29/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.2004 - accuracy: 0.9298 - val_loss: 0.5786 - val_accuracy: 0.8318
#
# Epoch 00029: val_accuracy did not improve from 0.86130
#
# Epoch 00029: saving model to cnn-model_2.h5
# Epoch 30/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1784 - accuracy: 0.9356 - val_loss: 0.5358 - val_accuracy: 0.8491
#
# Epoch 00030: val_accuracy did not improve from 0.86130
#
# Epoch 00030: saving model to cnn-model_2.h5
# Epoch 31/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1833 - accuracy: 0.9346 - val_loss: 0.6218 - val_accuracy: 0.8350
#
# Epoch 00031: val_accuracy did not improve from 0.86130
#
# Epoch 00031: saving model to cnn-model_2.h5
# Epoch 32/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1695 - accuracy: 0.9402 - val_loss: 0.5195 - val_accuracy: 0.8614
#
# Epoch 00032: val_accuracy improved from 0.86130 to 0.86140, saving model to cnn-model_2-0032-0.861400.h5
#
# Epoch 00032: saving model to cnn-model_2.h5
# Epoch 33/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1594 - accuracy: 0.9417 - val_loss: 0.6209 - val_accuracy: 0.8359
#
# Epoch 00033: val_accuracy did not improve from 0.86140
#
# Epoch 00033: saving model to cnn-model_2.h5
# Epoch 34/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1524 - accuracy: 0.9473 - val_loss: 0.4994 - val_accuracy: 0.8665
#
# Epoch 00034: val_accuracy improved from 0.86140 to 0.86650, saving model to cnn-model_2-0034-0.866500.h5
#
# Epoch 00034: saving model to cnn-model_2.h5
# Epoch 35/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1503 - accuracy: 0.9477 - val_loss: 0.5237 - val_accuracy: 0.8616
#
# Epoch 00035: val_accuracy did not improve from 0.86650
#
# Epoch 00035: saving model to cnn-model_2.h5
# Epoch 36/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1496 - accuracy: 0.9473 - val_loss: 0.4355 - val_accuracy: 0.8759
#
# Epoch 00036: val_accuracy improved from 0.86650 to 0.87590, saving model to cnn-model_2-0036-0.875900.h5
#
# Epoch 00036: saving model to cnn-model_2.h5
# Epoch 37/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1352 - accuracy: 0.9527 - val_loss: 0.6711 - val_accuracy: 0.8379
#
# Epoch 00037: val_accuracy did not improve from 0.87590
#
# Epoch 00037: saving model to cnn-model_2.h5
# Epoch 38/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.1319 - accuracy: 0.9526 - val_loss: 0.5336 - val_accuracy: 0.8513
#
# Epoch 00038: val_accuracy did not improve from 0.87590
#
# Epoch 00038: saving model to cnn-model_2.h5
# Epoch 39/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1243 - accuracy: 0.9570 - val_loss: 0.5691 - val_accuracy: 0.8639
#
# Epoch 00039: val_accuracy did not improve from 0.87590
#
# Epoch 00039: saving model to cnn-model_2.h5
# Epoch 40/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1259 - accuracy: 0.9543 - val_loss: 0.7616 - val_accuracy: 0.8366
#
# Epoch 00040: val_accuracy did not improve from 0.87590
#
# Epoch 00040: saving model to cnn-model_2.h5
# Epoch 41/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1211 - accuracy: 0.9570 - val_loss: 0.7353 - val_accuracy: 0.8308
#
# Epoch 00041: val_accuracy did not improve from 0.87590
#
# Epoch 00041: saving model to cnn-model_2.h5
# Epoch 42/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1138 - accuracy: 0.9595 - val_loss: 0.5294 - val_accuracy: 0.8712
#
# Epoch 00042: val_accuracy did not improve from 0.87590
#
# Epoch 00042: saving model to cnn-model_2.h5
# Epoch 43/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1099 - accuracy: 0.9618 - val_loss: 0.5685 - val_accuracy: 0.8461
#
# Epoch 00043: val_accuracy did not improve from 0.87590
#
# Epoch 00043: saving model to cnn-model_2.h5
# Epoch 44/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1093 - accuracy: 0.9598 - val_loss: 0.6307 - val_accuracy: 0.8473
#
# Epoch 00044: val_accuracy did not improve from 0.87590
#
# Epoch 00044: saving model to cnn-model_2.h5
# Epoch 45/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1019 - accuracy: 0.9629 - val_loss: 0.5374 - val_accuracy: 0.8676
#
# Epoch 00045: val_accuracy did not improve from 0.87590
#
# Epoch 00045: saving model to cnn-model_2.h5
# Epoch 46/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.1013 - accuracy: 0.9646 - val_loss: 0.6600 - val_accuracy: 0.8428
#
# Epoch 00046: val_accuracy did not improve from 0.87590
#
# Epoch 00046: saving model to cnn-model_2.h5
# Epoch 47/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0923 - accuracy: 0.9680 - val_loss: 0.6012 - val_accuracy: 0.8596
#
# Epoch 00047: val_accuracy did not improve from 0.87590
#
# Epoch 00047: saving model to cnn-model_2.h5
# Epoch 48/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0952 - accuracy: 0.9656 - val_loss: 0.6832 - val_accuracy: 0.8503
#
# Epoch 00048: val_accuracy did not improve from 0.87590
#
# Epoch 00048: saving model to cnn-model_2.h5
# Epoch 49/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0934 - accuracy: 0.9664 - val_loss: 1.1777 - val_accuracy: 0.7915
#
# Epoch 00049: val_accuracy did not improve from 0.87590
#
# Epoch 00049: saving model to cnn-model_2.h5
# Epoch 50/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0818 - accuracy: 0.9703 - val_loss: 0.5486 - val_accuracy: 0.8621
#
# Epoch 00050: val_accuracy did not improve from 0.87590
#
# Epoch 00050: saving model to cnn-model_2.h5
# Epoch 51/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0841 - accuracy: 0.9702 - val_loss: 0.4155 - val_accuracy: 0.8949
#
# Epoch 00051: val_accuracy improved from 0.87590 to 0.89490, saving model to cnn-model_2-0051-0.894900.h5
#
# Epoch 00051: saving model to cnn-model_2.h5
# Epoch 52/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0503 - accuracy: 0.9826 - val_loss: 0.4259 - val_accuracy: 0.8945
#
# Epoch 00052: val_accuracy did not improve from 0.89490
#
# Epoch 00052: saving model to cnn-model_2.h5
# Epoch 53/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0444 - accuracy: 0.9849 - val_loss: 0.4213 - val_accuracy: 0.8980
#
# Epoch 00053: val_accuracy improved from 0.89490 to 0.89800, saving model to cnn-model_2-0053-0.898000.h5
#
# Epoch 00053: saving model to cnn-model_2.h5
# Epoch 54/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0429 - accuracy: 0.9860 - val_loss: 0.4056 - val_accuracy: 0.9015
#
# Epoch 00054: val_accuracy improved from 0.89800 to 0.90150, saving model to cnn-model_2-0054-0.901500.h5
#
# Epoch 00054: saving model to cnn-model_2.h5
# Epoch 55/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 0.4282 - val_accuracy: 0.9000
#
# Epoch 00055: val_accuracy did not improve from 0.90150
#
# Epoch 00055: saving model to cnn-model_2.h5
# Epoch 56/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.4242 - val_accuracy: 0.9005
#
# Epoch 00056: val_accuracy did not improve from 0.90150
#
# Epoch 00056: saving model to cnn-model_2.h5
# Epoch 57/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0331 - accuracy: 0.9887 - val_loss: 0.4157 - val_accuracy: 0.9026
#
# Epoch 00057: val_accuracy improved from 0.90150 to 0.90260, saving model to cnn-model_2-0057-0.902600.h5
#
# Epoch 00057: saving model to cnn-model_2.h5
# Epoch 58/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0373 - accuracy: 0.9876 - val_loss: 0.4226 - val_accuracy: 0.9024
#
# Epoch 00058: val_accuracy did not improve from 0.90260
#
# Epoch 00058: saving model to cnn-model_2.h5
# Epoch 59/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0343 - accuracy: 0.9886 - val_loss: 0.4155 - val_accuracy: 0.9052
#
# Epoch 00059: val_accuracy improved from 0.90260 to 0.90520, saving model to cnn-model_2-0059-0.905200.h5
#
# Epoch 00059: saving model to cnn-model_2.h5
# Epoch 60/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0363 - accuracy: 0.9876 - val_loss: 0.4404 - val_accuracy: 0.9024
#
# Epoch 00060: val_accuracy did not improve from 0.90520
#
# Epoch 00060: saving model to cnn-model_2.h5
# Epoch 61/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0319 - accuracy: 0.9894 - val_loss: 0.4371 - val_accuracy: 0.9019
#
# Epoch 00061: val_accuracy did not improve from 0.90520
#
# Epoch 00061: saving model to cnn-model_2.h5
# Epoch 62/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0328 - accuracy: 0.9887 - val_loss: 0.4404 - val_accuracy: 0.8999
#
# Epoch 00062: val_accuracy did not improve from 0.90520
#
# Epoch 00062: saving model to cnn-model_2.h5
# Epoch 63/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0310 - accuracy: 0.9894 - val_loss: 0.4356 - val_accuracy: 0.9035
#
# Epoch 00063: val_accuracy did not improve from 0.90520
#
# Epoch 00063: saving model to cnn-model_2.h5
# Epoch 64/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0306 - accuracy: 0.9893 - val_loss: 0.4443 - val_accuracy: 0.9013
#
# Epoch 00064: val_accuracy did not improve from 0.90520
#
# Epoch 00064: saving model to cnn-model_2.h5
# Epoch 65/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0300 - accuracy: 0.9895 - val_loss: 0.4279 - val_accuracy: 0.9059
#
# Epoch 00065: val_accuracy improved from 0.90520 to 0.90590, saving model to cnn-model_2-0065-0.905900.h5
#
# Epoch 00065: saving model to cnn-model_2.h5
# Epoch 66/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.4487 - val_accuracy: 0.9016
#
# Epoch 00066: val_accuracy did not improve from 0.90590
#
# Epoch 00066: saving model to cnn-model_2.h5
# Epoch 67/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.4452 - val_accuracy: 0.9041
#
# Epoch 00067: val_accuracy did not improve from 0.90590
#
# Epoch 00067: saving model to cnn-model_2.h5
# Epoch 68/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0261 - accuracy: 0.9916 - val_loss: 0.4529 - val_accuracy: 0.9037
#
# Epoch 00068: val_accuracy did not improve from 0.90590
#
# Epoch 00068: saving model to cnn-model_2.h5
# Epoch 69/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0264 - accuracy: 0.9907 - val_loss: 0.4431 - val_accuracy: 0.9022
#
# Epoch 00069: val_accuracy did not improve from 0.90590
#
# Epoch 00069: saving model to cnn-model_2.h5
# Epoch 70/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0256 - accuracy: 0.9914 - val_loss: 0.4514 - val_accuracy: 0.9024
#
# Epoch 00070: val_accuracy did not improve from 0.90590
#
# Epoch 00070: saving model to cnn-model_2.h5
# Epoch 71/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.4592 - val_accuracy: 0.9026
#
# Epoch 00071: val_accuracy did not improve from 0.90590
#
# Epoch 00071: saving model to cnn-model_2.h5
# Epoch 72/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0260 - accuracy: 0.9916 - val_loss: 0.4486 - val_accuracy: 0.9033
#
# Epoch 00072: val_accuracy did not improve from 0.90590
#
# Epoch 00072: saving model to cnn-model_2.h5
# Epoch 73/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0275 - accuracy: 0.9912 - val_loss: 0.4557 - val_accuracy: 0.9029
#
# Epoch 00073: val_accuracy did not improve from 0.90590
#
# Epoch 00073: saving model to cnn-model_2.h5
# Epoch 74/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0231 - accuracy: 0.9927 - val_loss: 0.4633 - val_accuracy: 0.9031
#
# Epoch 00074: val_accuracy did not improve from 0.90590
#
# Epoch 00074: saving model to cnn-model_2.h5
# Epoch 75/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 0.4618 - val_accuracy: 0.9024
#
# Epoch 00075: val_accuracy did not improve from 0.90590
#
# Epoch 00075: saving model to cnn-model_2.h5
# Epoch 76/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0218 - accuracy: 0.9931 - val_loss: 0.4576 - val_accuracy: 0.9027
#
# Epoch 00076: val_accuracy did not improve from 0.90590
#
# Epoch 00076: saving model to cnn-model_2.h5
# Epoch 77/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 0.4634 - val_accuracy: 0.9017
#
# Epoch 00077: val_accuracy did not improve from 0.90590
#
# Epoch 00077: saving model to cnn-model_2.h5
# Epoch 78/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0235 - accuracy: 0.9925 - val_loss: 0.4638 - val_accuracy: 0.9017
#
# Epoch 00078: val_accuracy did not improve from 0.90590
#
# Epoch 00078: saving model to cnn-model_2.h5
# Epoch 79/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.4624 - val_accuracy: 0.9031
#
# Epoch 00079: val_accuracy did not improve from 0.90590
#
# Epoch 00079: saving model to cnn-model_2.h5
# Epoch 80/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0223 - accuracy: 0.9928 - val_loss: 0.4599 - val_accuracy: 0.9022
#
# Epoch 00080: val_accuracy did not improve from 0.90590
#
# Epoch 00080: saving model to cnn-model_2.h5
# Epoch 81/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 0.4592 - val_accuracy: 0.9024
#
# Epoch 00081: val_accuracy did not improve from 0.90590
#
# Epoch 00081: saving model to cnn-model_2.h5
# Epoch 82/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.4563 - val_accuracy: 0.9024
#
# Epoch 00082: val_accuracy did not improve from 0.90590
#
# Epoch 00082: saving model to cnn-model_2.h5
# Epoch 83/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0205 - accuracy: 0.9936 - val_loss: 0.4599 - val_accuracy: 0.9030
#
# Epoch 00083: val_accuracy did not improve from 0.90590
#
# Epoch 00083: saving model to cnn-model_2.h5
# Epoch 84/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0204 - accuracy: 0.9934 - val_loss: 0.4555 - val_accuracy: 0.9033
#
# Epoch 00084: val_accuracy did not improve from 0.90590
#
# Epoch 00084: saving model to cnn-model_2.h5
# Epoch 85/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0228 - accuracy: 0.9919 - val_loss: 0.4613 - val_accuracy: 0.9020
#
# Epoch 00085: val_accuracy did not improve from 0.90590
#
# Epoch 00085: saving model to cnn-model_2.h5
# Epoch 86/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.4620 - val_accuracy: 0.9025
#
# Epoch 00086: val_accuracy did not improve from 0.90590
#
# Epoch 00086: saving model to cnn-model_2.h5
# Epoch 87/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0243 - accuracy: 0.9921 - val_loss: 0.4555 - val_accuracy: 0.9040
#
# Epoch 00087: val_accuracy did not improve from 0.90590
#
# Epoch 00087: saving model to cnn-model_2.h5
# Epoch 88/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0200 - accuracy: 0.9936 - val_loss: 0.4527 - val_accuracy: 0.9038
#
# Epoch 00088: val_accuracy did not improve from 0.90590
#
# Epoch 00088: saving model to cnn-model_2.h5
# Epoch 89/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0231 - accuracy: 0.9922 - val_loss: 0.4551 - val_accuracy: 0.9034
#
# Epoch 00089: val_accuracy did not improve from 0.90590
#
# Epoch 00089: saving model to cnn-model_2.h5
# Epoch 90/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.4613 - val_accuracy: 0.9025
#
# Epoch 00090: val_accuracy did not improve from 0.90590
#
# Epoch 00090: saving model to cnn-model_2.h5
# Epoch 91/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.4540 - val_accuracy: 0.9039
#
# Epoch 00091: val_accuracy did not improve from 0.90590
#
# Epoch 00091: saving model to cnn-model_2.h5
# Epoch 92/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 0.4542 - val_accuracy: 0.9031
#
# Epoch 00092: val_accuracy did not improve from 0.90590
#
# Epoch 00092: saving model to cnn-model_2.h5
# Epoch 93/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.4558 - val_accuracy: 0.9033
#
# Epoch 00093: val_accuracy did not improve from 0.90590
#
# Epoch 00093: saving model to cnn-model_2.h5
# Epoch 94/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0214 - accuracy: 0.9931 - val_loss: 0.4588 - val_accuracy: 0.9037
#
# Epoch 00094: val_accuracy did not improve from 0.90590
#
# Epoch 00094: saving model to cnn-model_2.h5
# Epoch 95/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.4537 - val_accuracy: 0.9045
#
# Epoch 00095: val_accuracy did not improve from 0.90590
#
# Epoch 00095: saving model to cnn-model_2.h5
# Epoch 96/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0211 - accuracy: 0.9935 - val_loss: 0.4547 - val_accuracy: 0.9036
#
# Epoch 00096: val_accuracy did not improve from 0.90590
#
# Epoch 00096: saving model to cnn-model_2.h5
# Epoch 97/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0210 - accuracy: 0.9936 - val_loss: 0.4554 - val_accuracy: 0.9036
#
# Epoch 00097: val_accuracy did not improve from 0.90590
#
# Epoch 00097: saving model to cnn-model_2.h5
# Epoch 98/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0197 - accuracy: 0.9939 - val_loss: 0.4587 - val_accuracy: 0.9036
#
# Epoch 00098: val_accuracy did not improve from 0.90590
#
# Epoch 00098: saving model to cnn-model_2.h5
# Epoch 99/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 0.4605 - val_accuracy: 0.9029
#
# Epoch 00099: val_accuracy did not improve from 0.90590
#
# Epoch 00099: saving model to cnn-model_2.h5
# Epoch 100/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.4592 - val_accuracy: 0.9033
#
# Epoch 00100: val_accuracy did not improve from 0.90590
#
# Epoch 00100: saving model to cnn-model_2.h5
# Epoch 101/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0233 - accuracy: 0.9921 - val_loss: 0.4584 - val_accuracy: 0.9038
#
# Epoch 00101: val_accuracy did not improve from 0.90590
#
# Epoch 00101: saving model to cnn-model_2.h5
# Epoch 102/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0212 - accuracy: 0.9918 - val_loss: 0.4598 - val_accuracy: 0.9022
#
# Epoch 00102: val_accuracy did not improve from 0.90590
#
# Epoch 00102: saving model to cnn-model_2.h5
# Epoch 103/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0215 - accuracy: 0.9927 - val_loss: 0.4592 - val_accuracy: 0.9037
#
# Epoch 00103: val_accuracy did not improve from 0.90590
#
# Epoch 00103: saving model to cnn-model_2.h5
# Epoch 104/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0196 - accuracy: 0.9934 - val_loss: 0.4586 - val_accuracy: 0.9039
#
# Epoch 00104: val_accuracy did not improve from 0.90590
#
# Epoch 00104: saving model to cnn-model_2.h5
# Epoch 105/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0196 - accuracy: 0.9929 - val_loss: 0.4609 - val_accuracy: 0.9020
#
# Epoch 00105: val_accuracy did not improve from 0.90590
#
# Epoch 00105: saving model to cnn-model_2.h5
# Epoch 106/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0202 - accuracy: 0.9928 - val_loss: 0.4612 - val_accuracy: 0.9031
#
# Epoch 00106: val_accuracy did not improve from 0.90590
#
# Epoch 00106: saving model to cnn-model_2.h5
# Epoch 107/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 0.4600 - val_accuracy: 0.9028
#
# Epoch 00107: val_accuracy did not improve from 0.90590
#
# Epoch 00107: saving model to cnn-model_2.h5
# Epoch 108/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 0.4627 - val_accuracy: 0.9029
#
# Epoch 00108: val_accuracy did not improve from 0.90590
#
# Epoch 00108: saving model to cnn-model_2.h5
# Epoch 109/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.4617 - val_accuracy: 0.9029
#
# Epoch 00109: val_accuracy did not improve from 0.90590
#
# Epoch 00109: saving model to cnn-model_2.h5
# Epoch 110/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0203 - accuracy: 0.9931 - val_loss: 0.4611 - val_accuracy: 0.9033
#
# Epoch 00110: val_accuracy did not improve from 0.90590
#
# Epoch 00110: saving model to cnn-model_2.h5
# Epoch 111/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0208 - accuracy: 0.9934 - val_loss: 0.4606 - val_accuracy: 0.9033
#
# Epoch 00111: val_accuracy did not improve from 0.90590
#
# Epoch 00111: saving model to cnn-model_2.h5
# Epoch 112/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.4596 - val_accuracy: 0.9033
#
# Epoch 00112: val_accuracy did not improve from 0.90590
#
# Epoch 00112: saving model to cnn-model_2.h5
# Epoch 113/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.4555 - val_accuracy: 0.9036
#
# Epoch 00113: val_accuracy did not improve from 0.90590
#
# Epoch 00113: saving model to cnn-model_2.h5
# Epoch 114/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0196 - accuracy: 0.9935 - val_loss: 0.4589 - val_accuracy: 0.9034
#
# Epoch 00114: val_accuracy did not improve from 0.90590
#
# Epoch 00114: saving model to cnn-model_2.h5
# Epoch 115/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0188 - accuracy: 0.9939 - val_loss: 0.4604 - val_accuracy: 0.9036
#
# Epoch 00115: val_accuracy did not improve from 0.90590
#
# Epoch 00115: saving model to cnn-model_2.h5
# Epoch 116/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.4622 - val_accuracy: 0.9034
#
# Epoch 00116: val_accuracy did not improve from 0.90590
#
# Epoch 00116: saving model to cnn-model_2.h5
# Epoch 117/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.4595 - val_accuracy: 0.9030
#
# Epoch 00117: val_accuracy did not improve from 0.90590
#
# Epoch 00117: saving model to cnn-model_2.h5
# Epoch 118/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.4608 - val_accuracy: 0.9035
#
# Epoch 00118: val_accuracy did not improve from 0.90590
#
# Epoch 00118: saving model to cnn-model_2.h5
# Epoch 119/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.4649 - val_accuracy: 0.9040
#
# Epoch 00119: val_accuracy did not improve from 0.90590
#
# Epoch 00119: saving model to cnn-model_2.h5
# Epoch 120/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.4635 - val_accuracy: 0.9031
#
# Epoch 00120: val_accuracy did not improve from 0.90590
#
# Epoch 00120: saving model to cnn-model_2.h5
# Epoch 121/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.4672 - val_accuracy: 0.9029
#
# Epoch 00121: val_accuracy did not improve from 0.90590
#
# Epoch 00121: saving model to cnn-model_2.h5
# Epoch 122/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.4640 - val_accuracy: 0.9033
#
# Epoch 00122: val_accuracy did not improve from 0.90590
#
# Epoch 00122: saving model to cnn-model_2.h5
# Epoch 123/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0199 - accuracy: 0.9930 - val_loss: 0.4665 - val_accuracy: 0.9029
#
# Epoch 00123: val_accuracy did not improve from 0.90590
#
# Epoch 00123: saving model to cnn-model_2.h5
# Epoch 124/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0198 - accuracy: 0.9938 - val_loss: 0.4702 - val_accuracy: 0.9030
#
# Epoch 00124: val_accuracy did not improve from 0.90590
#
# Epoch 00124: saving model to cnn-model_2.h5
# Epoch 125/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0211 - accuracy: 0.9926 - val_loss: 0.4650 - val_accuracy: 0.9027
#
# Epoch 00125: val_accuracy did not improve from 0.90590
#
# Epoch 00125: saving model to cnn-model_2.h5
# Epoch 126/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.4624 - val_accuracy: 0.9033
#
# Epoch 00126: val_accuracy did not improve from 0.90590
#
# Epoch 00126: saving model to cnn-model_2.h5
# Epoch 127/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0204 - accuracy: 0.9933 - val_loss: 0.4623 - val_accuracy: 0.9032
#
# Epoch 00127: val_accuracy did not improve from 0.90590
#
# Epoch 00127: saving model to cnn-model_2.h5
# Epoch 128/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.4602 - val_accuracy: 0.9031
#
# Epoch 00128: val_accuracy did not improve from 0.90590
#
# Epoch 00128: saving model to cnn-model_2.h5
# Epoch 129/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0218 - accuracy: 0.9926 - val_loss: 0.4621 - val_accuracy: 0.9029
#
# Epoch 00129: val_accuracy did not improve from 0.90590
#
# Epoch 00129: saving model to cnn-model_2.h5
# Epoch 130/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0210 - accuracy: 0.9928 - val_loss: 0.4643 - val_accuracy: 0.9027
#
# Epoch 00130: val_accuracy did not improve from 0.90590
#
# Epoch 00130: saving model to cnn-model_2.h5
# Epoch 131/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 0.4643 - val_accuracy: 0.9030
#
# Epoch 00131: val_accuracy did not improve from 0.90590
#
# Epoch 00131: saving model to cnn-model_2.h5
# Epoch 132/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.4596 - val_accuracy: 0.9034
#
# Epoch 00132: val_accuracy did not improve from 0.90590
#
# Epoch 00132: saving model to cnn-model_2.h5
# Epoch 133/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0194 - accuracy: 0.9938 - val_loss: 0.4612 - val_accuracy: 0.9041
#
# Epoch 00133: val_accuracy did not improve from 0.90590
#
# Epoch 00133: saving model to cnn-model_2.h5
# Epoch 134/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0190 - accuracy: 0.9939 - val_loss: 0.4634 - val_accuracy: 0.9038
#
# Epoch 00134: val_accuracy did not improve from 0.90590
#
# Epoch 00134: saving model to cnn-model_2.h5
# Epoch 135/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0193 - accuracy: 0.9940 - val_loss: 0.4621 - val_accuracy: 0.9033
#
# Epoch 00135: val_accuracy did not improve from 0.90590
#
# Epoch 00135: saving model to cnn-model_2.h5
# Epoch 136/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0206 - accuracy: 0.9930 - val_loss: 0.4653 - val_accuracy: 0.9033
#
# Epoch 00136: val_accuracy did not improve from 0.90590
#
# Epoch 00136: saving model to cnn-model_2.h5
# Epoch 137/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0203 - accuracy: 0.9933 - val_loss: 0.4638 - val_accuracy: 0.9030
#
# Epoch 00137: val_accuracy did not improve from 0.90590
#
# Epoch 00137: saving model to cnn-model_2.h5
# Epoch 138/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 0.4615 - val_accuracy: 0.9038
#
# Epoch 00138: val_accuracy did not improve from 0.90590
#
# Epoch 00138: saving model to cnn-model_2.h5
# Epoch 139/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0216 - accuracy: 0.9927 - val_loss: 0.4653 - val_accuracy: 0.9042
#
# Epoch 00139: val_accuracy did not improve from 0.90590
#
# Epoch 00139: saving model to cnn-model_2.h5
# Epoch 140/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.4600 - val_accuracy: 0.9041
#
# Epoch 00140: val_accuracy did not improve from 0.90590
#
# Epoch 00140: saving model to cnn-model_2.h5
# Epoch 141/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0188 - accuracy: 0.9938 - val_loss: 0.4677 - val_accuracy: 0.9033
#
# Epoch 00141: val_accuracy did not improve from 0.90590
#
# Epoch 00141: saving model to cnn-model_2.h5
# Epoch 142/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0204 - accuracy: 0.9934 - val_loss: 0.4698 - val_accuracy: 0.9028
#
# Epoch 00142: val_accuracy did not improve from 0.90590
#
# Epoch 00142: saving model to cnn-model_2.h5
# Epoch 143/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0203 - accuracy: 0.9934 - val_loss: 0.4681 - val_accuracy: 0.9031
#
# Epoch 00143: val_accuracy did not improve from 0.90590
#
# Epoch 00143: saving model to cnn-model_2.h5
# Epoch 144/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0192 - accuracy: 0.9936 - val_loss: 0.4679 - val_accuracy: 0.9034
#
# Epoch 00144: val_accuracy did not improve from 0.90590
#
# Epoch 00144: saving model to cnn-model_2.h5
# Epoch 145/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.4676 - val_accuracy: 0.9037
#
# Epoch 00145: val_accuracy did not improve from 0.90590
#
# Epoch 00145: saving model to cnn-model_2.h5
# Epoch 146/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.4674 - val_accuracy: 0.9042
#
# Epoch 00146: val_accuracy did not improve from 0.90590
#
# Epoch 00146: saving model to cnn-model_2.h5
# Epoch 147/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0184 - accuracy: 0.9940 - val_loss: 0.4651 - val_accuracy: 0.9035
#
# Epoch 00147: val_accuracy did not improve from 0.90590
#
# Epoch 00147: saving model to cnn-model_2.h5
# Epoch 148/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 0.4683 - val_accuracy: 0.9036
#
# Epoch 00148: val_accuracy did not improve from 0.90590
#
# Epoch 00148: saving model to cnn-model_2.h5
# Epoch 149/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0192 - accuracy: 0.9941 - val_loss: 0.4701 - val_accuracy: 0.9029
#
# Epoch 00149: val_accuracy did not improve from 0.90590
#
# Epoch 00149: saving model to cnn-model_2.h5
# Epoch 150/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.4718 - val_accuracy: 0.9037
#
# Epoch 00150: val_accuracy did not improve from 0.90590
#
# Epoch 00150: saving model to cnn-model_2.h5
# Epoch 151/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.4687 - val_accuracy: 0.9039
#
# Epoch 00151: val_accuracy did not improve from 0.90590
#
# Epoch 00151: saving model to cnn-model_2.h5
# Epoch 152/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0193 - accuracy: 0.9942 - val_loss: 0.4680 - val_accuracy: 0.9031
#
# Epoch 00152: val_accuracy did not improve from 0.90590
#
# Epoch 00152: saving model to cnn-model_2.h5
# Epoch 153/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0200 - accuracy: 0.9935 - val_loss: 0.4678 - val_accuracy: 0.9036
#
# Epoch 00153: val_accuracy did not improve from 0.90590
#
# Epoch 00153: saving model to cnn-model_2.h5
# Epoch 154/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0184 - accuracy: 0.9944 - val_loss: 0.4689 - val_accuracy: 0.9031
#
# Epoch 00154: val_accuracy did not improve from 0.90590
#
# Epoch 00154: saving model to cnn-model_2.h5
# Epoch 155/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 0.4664 - val_accuracy: 0.9033
#
# Epoch 00155: val_accuracy did not improve from 0.90590
#
# Epoch 00155: saving model to cnn-model_2.h5
# Epoch 156/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0182 - accuracy: 0.9939 - val_loss: 0.4671 - val_accuracy: 0.9030
#
# Epoch 00156: val_accuracy did not improve from 0.90590
#
# Epoch 00156: saving model to cnn-model_2.h5
# Epoch 157/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.4652 - val_accuracy: 0.9038
#
# Epoch 00157: val_accuracy did not improve from 0.90590
#
# Epoch 00157: saving model to cnn-model_2.h5
# Epoch 158/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 0.4681 - val_accuracy: 0.9029
#
# Epoch 00158: val_accuracy did not improve from 0.90590
#
# Epoch 00158: saving model to cnn-model_2.h5
# Epoch 159/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0186 - accuracy: 0.9942 - val_loss: 0.4673 - val_accuracy: 0.9032
#
# Epoch 00159: val_accuracy did not improve from 0.90590
#
# Epoch 00159: saving model to cnn-model_2.h5
# Epoch 160/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0200 - accuracy: 0.9931 - val_loss: 0.4680 - val_accuracy: 0.9036
#
# Epoch 00160: val_accuracy did not improve from 0.90590
#
# Epoch 00160: saving model to cnn-model_2.h5
# Epoch 161/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.4656 - val_accuracy: 0.9037
#
# Epoch 00161: val_accuracy did not improve from 0.90590
#
# Epoch 00161: saving model to cnn-model_2.h5
# Epoch 162/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0192 - accuracy: 0.9941 - val_loss: 0.4646 - val_accuracy: 0.9042
#
# Epoch 00162: val_accuracy did not improve from 0.90590
#
# Epoch 00162: saving model to cnn-model_2.h5
# Epoch 163/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.4659 - val_accuracy: 0.9035
#
# Epoch 00163: val_accuracy did not improve from 0.90590
#
# Epoch 00163: saving model to cnn-model_2.h5
# Epoch 164/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.4653 - val_accuracy: 0.9035
#
# Epoch 00164: val_accuracy did not improve from 0.90590
#
# Epoch 00164: saving model to cnn-model_2.h5
# Epoch 165/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.4659 - val_accuracy: 0.9029
#
# Epoch 00165: val_accuracy did not improve from 0.90590
#
# Epoch 00165: saving model to cnn-model_2.h5
# Epoch 166/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 0.4676 - val_accuracy: 0.9037
#
# Epoch 00166: val_accuracy did not improve from 0.90590
#
# Epoch 00166: saving model to cnn-model_2.h5
# Epoch 167/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0193 - accuracy: 0.9940 - val_loss: 0.4649 - val_accuracy: 0.9037
#
# Epoch 00167: val_accuracy did not improve from 0.90590
#
# Epoch 00167: saving model to cnn-model_2.h5
# Epoch 168/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0201 - accuracy: 0.9938 - val_loss: 0.4676 - val_accuracy: 0.9033
#
# Epoch 00168: val_accuracy did not improve from 0.90590
#
# Epoch 00168: saving model to cnn-model_2.h5
# Epoch 169/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.4656 - val_accuracy: 0.9040
#
# Epoch 00169: val_accuracy did not improve from 0.90590
#
# Epoch 00169: saving model to cnn-model_2.h5
# Epoch 170/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.4672 - val_accuracy: 0.9032
#
# Epoch 00170: val_accuracy did not improve from 0.90590
#
# Epoch 00170: saving model to cnn-model_2.h5
# Epoch 171/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0189 - accuracy: 0.9940 - val_loss: 0.4685 - val_accuracy: 0.9032
#
# Epoch 00171: val_accuracy did not improve from 0.90590
#
# Epoch 00171: saving model to cnn-model_2.h5
# Epoch 172/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.4690 - val_accuracy: 0.9031
#
# Epoch 00172: val_accuracy did not improve from 0.90590
#
# Epoch 00172: saving model to cnn-model_2.h5
# Epoch 173/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0180 - accuracy: 0.9938 - val_loss: 0.4676 - val_accuracy: 0.9038
#
# Epoch 00173: val_accuracy did not improve from 0.90590
#
# Epoch 00173: saving model to cnn-model_2.h5
# Epoch 174/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.4669 - val_accuracy: 0.9037
#
# Epoch 00174: val_accuracy did not improve from 0.90590
#
# Epoch 00174: saving model to cnn-model_2.h5
# Epoch 175/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0183 - accuracy: 0.9938 - val_loss: 0.4701 - val_accuracy: 0.9029
#
# Epoch 00175: val_accuracy did not improve from 0.90590
#
# Epoch 00175: saving model to cnn-model_2.h5
# Epoch 176/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0192 - accuracy: 0.9934 - val_loss: 0.4702 - val_accuracy: 0.9036
#
# Epoch 00176: val_accuracy did not improve from 0.90590
#
# Epoch 00176: saving model to cnn-model_2.h5
# Epoch 177/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0191 - accuracy: 0.9942 - val_loss: 0.4681 - val_accuracy: 0.9037
#
# Epoch 00177: val_accuracy did not improve from 0.90590
#
# Epoch 00177: saving model to cnn-model_2.h5
# Epoch 178/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.4705 - val_accuracy: 0.9035
#
# Epoch 00178: val_accuracy did not improve from 0.90590
#
# Epoch 00178: saving model to cnn-model_2.h5
# Epoch 179/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.4683 - val_accuracy: 0.9041
#
# Epoch 00179: val_accuracy did not improve from 0.90590
#
# Epoch 00179: saving model to cnn-model_2.h5
# Epoch 180/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 0.4708 - val_accuracy: 0.9037
#
# Epoch 00180: val_accuracy did not improve from 0.90590
#
# Epoch 00180: saving model to cnn-model_2.h5
# Epoch 181/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.4690 - val_accuracy: 0.9043
#
# Epoch 00181: val_accuracy did not improve from 0.90590
#
# Epoch 00181: saving model to cnn-model_2.h5
# Epoch 182/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.4698 - val_accuracy: 0.9033
#
# Epoch 00182: val_accuracy did not improve from 0.90590
#
# Epoch 00182: saving model to cnn-model_2.h5
# Epoch 183/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.4705 - val_accuracy: 0.9037
#
# Epoch 00183: val_accuracy did not improve from 0.90590
#
# Epoch 00183: saving model to cnn-model_2.h5
# Epoch 184/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.4724 - val_accuracy: 0.9033
#
# Epoch 00184: val_accuracy did not improve from 0.90590
#
# Epoch 00184: saving model to cnn-model_2.h5
# Epoch 185/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0200 - accuracy: 0.9929 - val_loss: 0.4737 - val_accuracy: 0.9026
#
# Epoch 00185: val_accuracy did not improve from 0.90590
#
# Epoch 00185: saving model to cnn-model_2.h5
# Epoch 186/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0189 - accuracy: 0.9941 - val_loss: 0.4732 - val_accuracy: 0.9034
#
# Epoch 00186: val_accuracy did not improve from 0.90590
#
# Epoch 00186: saving model to cnn-model_2.h5
# Epoch 187/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 0.4723 - val_accuracy: 0.9033
#
# Epoch 00187: val_accuracy did not improve from 0.90590
#
# Epoch 00187: saving model to cnn-model_2.h5
# Epoch 188/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0189 - accuracy: 0.9941 - val_loss: 0.4722 - val_accuracy: 0.9030
#
# Epoch 00188: val_accuracy did not improve from 0.90590
#
# Epoch 00188: saving model to cnn-model_2.h5
# Epoch 189/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0181 - accuracy: 0.9938 - val_loss: 0.4729 - val_accuracy: 0.9036
#
# Epoch 00189: val_accuracy did not improve from 0.90590
#
# Epoch 00189: saving model to cnn-model_2.h5
# Epoch 190/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0187 - accuracy: 0.9934 - val_loss: 0.4728 - val_accuracy: 0.9025
#
# Epoch 00190: val_accuracy did not improve from 0.90590
#
# Epoch 00190: saving model to cnn-model_2.h5
# Epoch 191/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.4730 - val_accuracy: 0.9025
#
# Epoch 00191: val_accuracy did not improve from 0.90590
#
# Epoch 00191: saving model to cnn-model_2.h5
# Epoch 192/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0193 - accuracy: 0.9932 - val_loss: 0.4696 - val_accuracy: 0.9032
#
# Epoch 00192: val_accuracy did not improve from 0.90590
#
# Epoch 00192: saving model to cnn-model_2.h5
# Epoch 193/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.4732 - val_accuracy: 0.9024
#
# Epoch 00193: val_accuracy did not improve from 0.90590
#
# Epoch 00193: saving model to cnn-model_2.h5
# Epoch 194/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0187 - accuracy: 0.9939 - val_loss: 0.4711 - val_accuracy: 0.9026
#
# Epoch 00194: val_accuracy did not improve from 0.90590
#
# Epoch 00194: saving model to cnn-model_2.h5
# Epoch 195/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.4706 - val_accuracy: 0.9029
#
# Epoch 00195: val_accuracy did not improve from 0.90590
#
# Epoch 00195: saving model to cnn-model_2.h5
# Epoch 196/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.4722 - val_accuracy: 0.9028
#
# Epoch 00196: val_accuracy did not improve from 0.90590
#
# Epoch 00196: saving model to cnn-model_2.h5
# Epoch 197/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 0.4736 - val_accuracy: 0.9027
#
# Epoch 00197: val_accuracy did not improve from 0.90590
#
# Epoch 00197: saving model to cnn-model_2.h5
# Epoch 198/200
# 390/390 [==============================] - 30s 76ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.4730 - val_accuracy: 0.9029
#
# Epoch 00198: val_accuracy did not improve from 0.90590
#
# Epoch 00198: saving model to cnn-model_2.h5
# Epoch 199/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.4716 - val_accuracy: 0.9026
#
# Epoch 00199: val_accuracy did not improve from 0.90590
#
# Epoch 00199: saving model to cnn-model_2.h5
# Epoch 200/200
# 390/390 [==============================] - 30s 77ms/step - loss: 0.0194 - accuracy: 0.9938 - val_loss: 0.4731 - val_accuracy: 0.9024
#
# Epoch 00200: val_accuracy did not improve from 0.90590
#
# Epoch 00200: saving model to cnn-model_2.h5
# Test loss: 0.4730978012084961
# Test accuracy: 0.902400016784668
# Test error: 0.09759998321533203

# %%
model_3 = model_cnn_vgg
model_3 = advanced_training_and_evaluation(model=model_3,
                                           model_id='model_3',
                                           scheduler=scheduler_lr_3)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 390/390 [==============================] - 38s 94ms/step - loss: 1.9025 - accuracy: 0.2662 - val_loss: 3.5055 - val_accuracy: 0.3316
#
# Epoch 00001: val_accuracy improved from -inf to 0.33160, saving model to cnn-model_3-0001-0.331600.h5
#
# Epoch 00001: saving model to cnn-model_3.h5
# Epoch 2/200
# 390/390 [==============================] - 36s 93ms/step - loss: 1.3749 - accuracy: 0.4934 - val_loss: 1.4696 - val_accuracy: 0.5375
#
# Epoch 00002: val_accuracy improved from 0.33160 to 0.53750, saving model to cnn-model_3-0002-0.537500.h5
#
# Epoch 00002: saving model to cnn-model_3.h5
# Epoch 3/200
# 390/390 [==============================] - 36s 93ms/step - loss: 1.0811 - accuracy: 0.6136 - val_loss: 1.6047 - val_accuracy: 0.5417
#
# Epoch 00003: val_accuracy improved from 0.53750 to 0.54170, saving model to cnn-model_3-0003-0.541700.h5
#
# Epoch 00003: saving model to cnn-model_3.h5
# Epoch 4/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.8986 - accuracy: 0.6880 - val_loss: 1.9860 - val_accuracy: 0.5655
#
# Epoch 00004: val_accuracy improved from 0.54170 to 0.56550, saving model to cnn-model_3-0004-0.565500.h5
#
# Epoch 00004: saving model to cnn-model_3.h5
# Epoch 5/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.8068 - accuracy: 0.7264 - val_loss: 0.8723 - val_accuracy: 0.7213
#
# Epoch 00005: val_accuracy improved from 0.56550 to 0.72130, saving model to cnn-model_3-0005-0.721300.h5
#
# Epoch 00005: saving model to cnn-model_3.h5
# Epoch 6/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.7096 - accuracy: 0.7624 - val_loss: 1.3500 - val_accuracy: 0.6408
#
# Epoch 00006: val_accuracy did not improve from 0.72130
#
# Epoch 00006: saving model to cnn-model_3.h5
# Epoch 7/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.6477 - accuracy: 0.7832 - val_loss: 1.0938 - val_accuracy: 0.7128
#
# Epoch 00007: val_accuracy did not improve from 0.72130
#
# Epoch 00007: saving model to cnn-model_3.h5
# Epoch 8/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.5918 - accuracy: 0.8011 - val_loss: 0.7988 - val_accuracy: 0.7626
#
# Epoch 00008: val_accuracy improved from 0.72130 to 0.76260, saving model to cnn-model_3-0008-0.762600.h5
#
# Epoch 00008: saving model to cnn-model_3.h5
# Epoch 9/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.5563 - accuracy: 0.8158 - val_loss: 0.6272 - val_accuracy: 0.8036
#
# Epoch 00009: val_accuracy improved from 0.76260 to 0.80360, saving model to cnn-model_3-0009-0.803600.h5
#
# Epoch 00009: saving model to cnn-model_3.h5
# Epoch 10/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.5071 - accuracy: 0.8327 - val_loss: 0.9133 - val_accuracy: 0.7442
#
# Epoch 00010: val_accuracy did not improve from 0.80360
#
# Epoch 00010: saving model to cnn-model_3.h5
# Epoch 11/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.4870 - accuracy: 0.8350 - val_loss: 0.6365 - val_accuracy: 0.8025
#
# Epoch 00011: val_accuracy did not improve from 0.80360
#
# Epoch 00011: saving model to cnn-model_3.h5
# Epoch 12/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4503 - accuracy: 0.8494 - val_loss: 0.6165 - val_accuracy: 0.8046
#
# Epoch 00012: val_accuracy improved from 0.80360 to 0.80460, saving model to cnn-model_3-0012-0.804600.h5
#
# Epoch 00012: saving model to cnn-model_3.h5
# Epoch 13/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4224 - accuracy: 0.8594 - val_loss: 0.6816 - val_accuracy: 0.8073
#
# Epoch 00013: val_accuracy improved from 0.80460 to 0.80730, saving model to cnn-model_3-0013-0.807300.h5
#
# Epoch 00013: saving model to cnn-model_3.h5
# Epoch 14/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.3934 - accuracy: 0.8703 - val_loss: 0.5416 - val_accuracy: 0.8376
#
# Epoch 00014: val_accuracy improved from 0.80730 to 0.83760, saving model to cnn-model_3-0014-0.837600.h5
#
# Epoch 00014: saving model to cnn-model_3.h5
# Epoch 15/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.3810 - accuracy: 0.8716 - val_loss: 0.5649 - val_accuracy: 0.8229
#
# Epoch 00015: val_accuracy did not improve from 0.83760
#
# Epoch 00015: saving model to cnn-model_3.h5
# Epoch 16/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.3622 - accuracy: 0.8778 - val_loss: 0.5461 - val_accuracy: 0.8367
#
# Epoch 00016: val_accuracy did not improve from 0.83760
#
# Epoch 00016: saving model to cnn-model_3.h5
# Epoch 17/200
# 390/390 [==============================] - 38s 98ms/step - loss: 0.3457 - accuracy: 0.8836 - val_loss: 0.6762 - val_accuracy: 0.7976
#
# Epoch 00017: val_accuracy did not improve from 0.83760
#
# Epoch 00017: saving model to cnn-model_3.h5
# Epoch 18/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.3313 - accuracy: 0.8877 - val_loss: 0.7021 - val_accuracy: 0.8001
#
# Epoch 00018: val_accuracy did not improve from 0.83760
#
# Epoch 00018: saving model to cnn-model_3.h5
# Epoch 19/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.3136 - accuracy: 0.8927 - val_loss: 0.4972 - val_accuracy: 0.8526
#
# Epoch 00019: val_accuracy improved from 0.83760 to 0.85260, saving model to cnn-model_3-0019-0.852600.h5
#
# Epoch 00019: saving model to cnn-model_3.h5
# Epoch 20/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.2951 - accuracy: 0.9011 - val_loss: 0.5091 - val_accuracy: 0.8506
#
# Epoch 00020: val_accuracy did not improve from 0.85260
#
# Epoch 00020: saving model to cnn-model_3.h5
# Epoch 21/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.2860 - accuracy: 0.9047 - val_loss: 0.4511 - val_accuracy: 0.8653
#
# Epoch 00021: val_accuracy improved from 0.85260 to 0.86530, saving model to cnn-model_3-0021-0.865300.h5
#
# Epoch 00021: saving model to cnn-model_3.h5
# Epoch 22/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.2684 - accuracy: 0.9093 - val_loss: 0.4004 - val_accuracy: 0.8769
#
# Epoch 00022: val_accuracy improved from 0.86530 to 0.87690, saving model to cnn-model_3-0022-0.876900.h5
#
# Epoch 00022: saving model to cnn-model_3.h5
# Epoch 23/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.2564 - accuracy: 0.9124 - val_loss: 0.5427 - val_accuracy: 0.8481
#
# Epoch 00023: val_accuracy did not improve from 0.87690
#
# Epoch 00023: saving model to cnn-model_3.h5
# Epoch 24/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.2490 - accuracy: 0.9141 - val_loss: 0.7839 - val_accuracy: 0.7873
#
# Epoch 00024: val_accuracy did not improve from 0.87690
#
# Epoch 00024: saving model to cnn-model_3.h5
# Epoch 25/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.2406 - accuracy: 0.9201 - val_loss: 0.5228 - val_accuracy: 0.8525
#
# Epoch 00025: val_accuracy did not improve from 0.87690
#
# Epoch 00025: saving model to cnn-model_3.h5
# Epoch 26/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.2312 - accuracy: 0.9214 - val_loss: 0.4000 - val_accuracy: 0.8767
#
# Epoch 00026: val_accuracy did not improve from 0.87690
#
# Epoch 00026: saving model to cnn-model_3.h5
# Epoch 27/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.2129 - accuracy: 0.9271 - val_loss: 0.4482 - val_accuracy: 0.8675
#
# Epoch 00027: val_accuracy did not improve from 0.87690
#
# Epoch 00027: saving model to cnn-model_3.h5
# Epoch 28/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.2101 - accuracy: 0.9287 - val_loss: 0.3934 - val_accuracy: 0.8814
#
# Epoch 00028: val_accuracy improved from 0.87690 to 0.88140, saving model to cnn-model_3-0028-0.881400.h5
#
# Epoch 00028: saving model to cnn-model_3.h5
# Epoch 29/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.1949 - accuracy: 0.9324 - val_loss: 0.4332 - val_accuracy: 0.8693
#
# Epoch 00029: val_accuracy did not improve from 0.88140
#
# Epoch 00029: saving model to cnn-model_3.h5
# Epoch 30/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.1944 - accuracy: 0.9335 - val_loss: 0.4452 - val_accuracy: 0.8737
#
# Epoch 00030: val_accuracy did not improve from 0.88140
#
# Epoch 00030: saving model to cnn-model_3.h5
# Epoch 31/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1898 - accuracy: 0.9352 - val_loss: 0.3902 - val_accuracy: 0.8910
#
# Epoch 00031: val_accuracy improved from 0.88140 to 0.89100, saving model to cnn-model_3-0031-0.891000.h5
#
# Epoch 00031: saving model to cnn-model_3.h5
# Epoch 32/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1806 - accuracy: 0.9385 - val_loss: 0.4803 - val_accuracy: 0.8675
#
# Epoch 00032: val_accuracy did not improve from 0.89100
#
# Epoch 00032: saving model to cnn-model_3.h5
# Epoch 33/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1739 - accuracy: 0.9402 - val_loss: 0.4029 - val_accuracy: 0.8874
#
# Epoch 00033: val_accuracy did not improve from 0.89100
#
# Epoch 00033: saving model to cnn-model_3.h5
# Epoch 34/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1640 - accuracy: 0.9432 - val_loss: 0.3442 - val_accuracy: 0.8985
#
# Epoch 00034: val_accuracy improved from 0.89100 to 0.89850, saving model to cnn-model_3-0034-0.898500.h5
#
# Epoch 00034: saving model to cnn-model_3.h5
# Epoch 35/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1523 - accuracy: 0.9476 - val_loss: 0.3600 - val_accuracy: 0.8922
#
# Epoch 00035: val_accuracy did not improve from 0.89850
#
# Epoch 00035: saving model to cnn-model_3.h5
# Epoch 36/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1560 - accuracy: 0.9465 - val_loss: 0.4415 - val_accuracy: 0.8790
#
# Epoch 00036: val_accuracy did not improve from 0.89850
#
# Epoch 00036: saving model to cnn-model_3.h5
# Epoch 37/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1482 - accuracy: 0.9483 - val_loss: 0.3822 - val_accuracy: 0.8950
#
# Epoch 00037: val_accuracy did not improve from 0.89850
#
# Epoch 00037: saving model to cnn-model_3.h5
# Epoch 38/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1437 - accuracy: 0.9493 - val_loss: 0.4464 - val_accuracy: 0.8783
#
# Epoch 00038: val_accuracy did not improve from 0.89850
#
# Epoch 00038: saving model to cnn-model_3.h5
# Epoch 39/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1381 - accuracy: 0.9515 - val_loss: 0.3872 - val_accuracy: 0.8967
#
# Epoch 00039: val_accuracy did not improve from 0.89850
#
# Epoch 00039: saving model to cnn-model_3.h5
# Epoch 40/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1331 - accuracy: 0.9546 - val_loss: 0.3535 - val_accuracy: 0.9050
#
# Epoch 00040: val_accuracy improved from 0.89850 to 0.90500, saving model to cnn-model_3-0040-0.905000.h5
#
# Epoch 00040: saving model to cnn-model_3.h5
# Epoch 41/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1343 - accuracy: 0.9539 - val_loss: 0.4130 - val_accuracy: 0.8933
#
# Epoch 00041: val_accuracy did not improve from 0.90500
#
# Epoch 00041: saving model to cnn-model_3.h5
# Epoch 42/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1276 - accuracy: 0.9565 - val_loss: 0.5608 - val_accuracy: 0.8589
#
# Epoch 00042: val_accuracy did not improve from 0.90500
#
# Epoch 00042: saving model to cnn-model_3.h5
# Epoch 43/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1185 - accuracy: 0.9581 - val_loss: 0.3615 - val_accuracy: 0.8990
#
# Epoch 00043: val_accuracy did not improve from 0.90500
#
# Epoch 00043: saving model to cnn-model_3.h5
# Epoch 44/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1164 - accuracy: 0.9604 - val_loss: 0.3533 - val_accuracy: 0.9044
#
# Epoch 00044: val_accuracy did not improve from 0.90500
#
# Epoch 00044: saving model to cnn-model_3.h5
# Epoch 45/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1099 - accuracy: 0.9632 - val_loss: 0.3921 - val_accuracy: 0.8969
#
# Epoch 00045: val_accuracy did not improve from 0.90500
#
# Epoch 00045: saving model to cnn-model_3.h5
# Epoch 46/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1136 - accuracy: 0.9605 - val_loss: 0.4143 - val_accuracy: 0.8893
#
# Epoch 00046: val_accuracy did not improve from 0.90500
#
# Epoch 00046: saving model to cnn-model_3.h5
# Epoch 47/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.1064 - accuracy: 0.9641 - val_loss: 0.4668 - val_accuracy: 0.8820
#
# Epoch 00047: val_accuracy did not improve from 0.90500
#
# Epoch 00047: saving model to cnn-model_3.h5
# Epoch 48/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1061 - accuracy: 0.9636 - val_loss: 0.4688 - val_accuracy: 0.8849
#
# Epoch 00048: val_accuracy did not improve from 0.90500
#
# Epoch 00048: saving model to cnn-model_3.h5
# Epoch 49/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.1007 - accuracy: 0.9660 - val_loss: 0.3942 - val_accuracy: 0.8964
#
# Epoch 00049: val_accuracy did not improve from 0.90500
#
# Epoch 00049: saving model to cnn-model_3.h5
# Epoch 50/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0912 - accuracy: 0.9684 - val_loss: 0.5112 - val_accuracy: 0.8782
#
# Epoch 00050: val_accuracy did not improve from 0.90500
#
# Epoch 00050: saving model to cnn-model_3.h5
# Epoch 51/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0921 - accuracy: 0.9687 - val_loss: 0.3150 - val_accuracy: 0.9186
#
# Epoch 00051: val_accuracy improved from 0.90500 to 0.91860, saving model to cnn-model_3-0051-0.918600.h5
#
# Epoch 00051: saving model to cnn-model_3.h5
# Epoch 52/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0536 - accuracy: 0.9817 - val_loss: 0.3155 - val_accuracy: 0.9194
#
# Epoch 00052: val_accuracy improved from 0.91860 to 0.91940, saving model to cnn-model_3-0052-0.919400.h5
#
# Epoch 00052: saving model to cnn-model_3.h5
# Epoch 53/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0458 - accuracy: 0.9846 - val_loss: 0.3178 - val_accuracy: 0.9209
#
# Epoch 00053: val_accuracy improved from 0.91940 to 0.92090, saving model to cnn-model_3-0053-0.920900.h5
#
# Epoch 00053: saving model to cnn-model_3.h5
# Epoch 54/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0464 - accuracy: 0.9835 - val_loss: 0.3308 - val_accuracy: 0.9210
#
# Epoch 00054: val_accuracy improved from 0.92090 to 0.92100, saving model to cnn-model_3-0054-0.921000.h5
#
# Epoch 00054: saving model to cnn-model_3.h5
# Epoch 55/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0460 - accuracy: 0.9840 - val_loss: 0.3509 - val_accuracy: 0.9178
#
# Epoch 00055: val_accuracy did not improve from 0.92100
#
# Epoch 00055: saving model to cnn-model_3.h5
# Epoch 56/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0408 - accuracy: 0.9858 - val_loss: 0.3403 - val_accuracy: 0.9204
#
# Epoch 00056: val_accuracy did not improve from 0.92100
#
# Epoch 00056: saving model to cnn-model_3.h5
# Epoch 57/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0374 - accuracy: 0.9876 - val_loss: 0.3435 - val_accuracy: 0.9215
#
# Epoch 00057: val_accuracy improved from 0.92100 to 0.92150, saving model to cnn-model_3-0057-0.921500.h5
#
# Epoch 00057: saving model to cnn-model_3.h5
# Epoch 58/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0383 - accuracy: 0.9869 - val_loss: 0.3478 - val_accuracy: 0.9210
#
# Epoch 00058: val_accuracy did not improve from 0.92150
#
# Epoch 00058: saving model to cnn-model_3.h5
# Epoch 59/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0371 - accuracy: 0.9875 - val_loss: 0.3490 - val_accuracy: 0.9217
#
# Epoch 00059: val_accuracy improved from 0.92150 to 0.92170, saving model to cnn-model_3-0059-0.921700.h5
#
# Epoch 00059: saving model to cnn-model_3.h5
# Epoch 60/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0326 - accuracy: 0.9884 - val_loss: 0.3359 - val_accuracy: 0.9241
#
# Epoch 00060: val_accuracy improved from 0.92170 to 0.92410, saving model to cnn-model_3-0060-0.924100.h5
#
# Epoch 00060: saving model to cnn-model_3.h5
# Epoch 61/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0353 - accuracy: 0.9876 - val_loss: 0.3473 - val_accuracy: 0.9226
#
# Epoch 00061: val_accuracy did not improve from 0.92410
#
# Epoch 00061: saving model to cnn-model_3.h5
# Epoch 62/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0308 - accuracy: 0.9896 - val_loss: 0.3483 - val_accuracy: 0.9225
#
# Epoch 00062: val_accuracy did not improve from 0.92410
#
# Epoch 00062: saving model to cnn-model_3.h5
# Epoch 63/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0304 - accuracy: 0.9892 - val_loss: 0.3650 - val_accuracy: 0.9211
#
# Epoch 00063: val_accuracy did not improve from 0.92410
#
# Epoch 00063: saving model to cnn-model_3.h5
# Epoch 64/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0309 - accuracy: 0.9889 - val_loss: 0.3592 - val_accuracy: 0.9225
#
# Epoch 00064: val_accuracy did not improve from 0.92410
#
# Epoch 00064: saving model to cnn-model_3.h5
# Epoch 65/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0321 - accuracy: 0.9893 - val_loss: 0.3498 - val_accuracy: 0.9243
#
# Epoch 00065: val_accuracy improved from 0.92410 to 0.92430, saving model to cnn-model_3-0065-0.924300.h5
#
# Epoch 00065: saving model to cnn-model_3.h5
# Epoch 66/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0307 - accuracy: 0.9894 - val_loss: 0.3599 - val_accuracy: 0.9235
#
# Epoch 00066: val_accuracy did not improve from 0.92430
#
# Epoch 00066: saving model to cnn-model_3.h5
# Epoch 67/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0307 - accuracy: 0.9887 - val_loss: 0.3542 - val_accuracy: 0.9250
#
# Epoch 00067: val_accuracy improved from 0.92430 to 0.92500, saving model to cnn-model_3-0067-0.925000.h5
#
# Epoch 00067: saving model to cnn-model_3.h5
# Epoch 68/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0308 - accuracy: 0.9893 - val_loss: 0.3655 - val_accuracy: 0.9225
#
# Epoch 00068: val_accuracy did not improve from 0.92500
#
# Epoch 00068: saving model to cnn-model_3.h5
# Epoch 69/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0306 - accuracy: 0.9899 - val_loss: 0.3632 - val_accuracy: 0.9215
#
# Epoch 00069: val_accuracy did not improve from 0.92500
#
# Epoch 00069: saving model to cnn-model_3.h5
# Epoch 70/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0296 - accuracy: 0.9896 - val_loss: 0.3705 - val_accuracy: 0.9238
#
# Epoch 00070: val_accuracy did not improve from 0.92500
#
# Epoch 00070: saving model to cnn-model_3.h5
# Epoch 71/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0288 - accuracy: 0.9902 - val_loss: 0.3746 - val_accuracy: 0.9221
#
# Epoch 00071: val_accuracy did not improve from 0.92500
#
# Epoch 00071: saving model to cnn-model_3.h5
# Epoch 72/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0249 - accuracy: 0.9912 - val_loss: 0.3712 - val_accuracy: 0.9215
#
# Epoch 00072: val_accuracy did not improve from 0.92500
#
# Epoch 00072: saving model to cnn-model_3.h5
# Epoch 73/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0267 - accuracy: 0.9905 - val_loss: 0.3591 - val_accuracy: 0.9246
#
# Epoch 00073: val_accuracy did not improve from 0.92500
#
# Epoch 00073: saving model to cnn-model_3.h5
# Epoch 74/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0225 - accuracy: 0.9923 - val_loss: 0.3861 - val_accuracy: 0.9215
#
# Epoch 00074: val_accuracy did not improve from 0.92500
#
# Epoch 00074: saving model to cnn-model_3.h5
# Epoch 75/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0248 - accuracy: 0.9912 - val_loss: 0.3707 - val_accuracy: 0.9250
#
# Epoch 00075: val_accuracy did not improve from 0.92500
#
# Epoch 00075: saving model to cnn-model_3.h5
# Epoch 76/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0249 - accuracy: 0.9917 - val_loss: 0.3686 - val_accuracy: 0.9240
#
# Epoch 00076: val_accuracy did not improve from 0.92500
#
# Epoch 00076: saving model to cnn-model_3.h5
# Epoch 77/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.3678 - val_accuracy: 0.9246
#
# Epoch 00077: val_accuracy did not improve from 0.92500
#
# Epoch 00077: saving model to cnn-model_3.h5
# Epoch 78/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.3710 - val_accuracy: 0.9247
#
# Epoch 00078: val_accuracy did not improve from 0.92500
#
# Epoch 00078: saving model to cnn-model_3.h5
# Epoch 79/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.3668 - val_accuracy: 0.9257
#
# Epoch 00079: val_accuracy improved from 0.92500 to 0.92570, saving model to cnn-model_3-0079-0.925700.h5
#
# Epoch 00079: saving model to cnn-model_3.h5
# Epoch 80/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0277 - accuracy: 0.9908 - val_loss: 0.3672 - val_accuracy: 0.9252
#
# Epoch 00080: val_accuracy did not improve from 0.92570
#
# Epoch 00080: saving model to cnn-model_3.h5
# Epoch 81/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0227 - accuracy: 0.9922 - val_loss: 0.3692 - val_accuracy: 0.9252
#
# Epoch 00081: val_accuracy did not improve from 0.92570
#
# Epoch 00081: saving model to cnn-model_3.h5
# Epoch 82/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0243 - accuracy: 0.9920 - val_loss: 0.3680 - val_accuracy: 0.9258
#
# Epoch 00082: val_accuracy improved from 0.92570 to 0.92580, saving model to cnn-model_3-0082-0.925800.h5
#
# Epoch 00082: saving model to cnn-model_3.h5
# Epoch 83/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 0.3687 - val_accuracy: 0.9253
#
# Epoch 00083: val_accuracy did not improve from 0.92580
#
# Epoch 00083: saving model to cnn-model_3.h5
# Epoch 84/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0217 - accuracy: 0.9925 - val_loss: 0.3665 - val_accuracy: 0.9253
#
# Epoch 00084: val_accuracy did not improve from 0.92580
#
# Epoch 00084: saving model to cnn-model_3.h5
# Epoch 85/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0208 - accuracy: 0.9927 - val_loss: 0.3659 - val_accuracy: 0.9253
#
# Epoch 00085: val_accuracy did not improve from 0.92580
#
# Epoch 00085: saving model to cnn-model_3.h5
# Epoch 86/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0241 - accuracy: 0.9914 - val_loss: 0.3665 - val_accuracy: 0.9254
#
# Epoch 00086: val_accuracy did not improve from 0.92580
#
# Epoch 00086: saving model to cnn-model_3.h5
# Epoch 87/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0230 - accuracy: 0.9924 - val_loss: 0.3694 - val_accuracy: 0.9250
#
# Epoch 00087: val_accuracy did not improve from 0.92580
#
# Epoch 00087: saving model to cnn-model_3.h5
# Epoch 88/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.3637 - val_accuracy: 0.9257
#
# Epoch 00088: val_accuracy did not improve from 0.92580
#
# Epoch 00088: saving model to cnn-model_3.h5
# Epoch 89/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0217 - accuracy: 0.9922 - val_loss: 0.3673 - val_accuracy: 0.9246
#
# Epoch 00089: val_accuracy did not improve from 0.92580
#
# Epoch 00089: saving model to cnn-model_3.h5
# Epoch 90/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0235 - accuracy: 0.9916 - val_loss: 0.3691 - val_accuracy: 0.9245
#
# Epoch 00090: val_accuracy did not improve from 0.92580
#
# Epoch 00090: saving model to cnn-model_3.h5
# Epoch 91/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0214 - accuracy: 0.9924 - val_loss: 0.3675 - val_accuracy: 0.9255
#
# Epoch 00091: val_accuracy did not improve from 0.92580
#
# Epoch 00091: saving model to cnn-model_3.h5
# Epoch 92/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.3675 - val_accuracy: 0.9249
#
# Epoch 00092: val_accuracy did not improve from 0.92580
#
# Epoch 00092: saving model to cnn-model_3.h5
# Epoch 93/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0217 - accuracy: 0.9925 - val_loss: 0.3693 - val_accuracy: 0.9252
#
# Epoch 00093: val_accuracy did not improve from 0.92580
#
# Epoch 00093: saving model to cnn-model_3.h5
# Epoch 94/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0218 - accuracy: 0.9920 - val_loss: 0.3683 - val_accuracy: 0.9256
#
# Epoch 00094: val_accuracy did not improve from 0.92580
#
# Epoch 00094: saving model to cnn-model_3.h5
# Epoch 95/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0200 - accuracy: 0.9931 - val_loss: 0.3700 - val_accuracy: 0.9250
#
# Epoch 00095: val_accuracy did not improve from 0.92580
#
# Epoch 00095: saving model to cnn-model_3.h5
# Epoch 96/200
# 390/390 [==============================] - 38s 98ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.3744 - val_accuracy: 0.9247
#
# Epoch 00096: val_accuracy did not improve from 0.92580
#
# Epoch 00096: saving model to cnn-model_3.h5
# Epoch 97/200
# 390/390 [==============================] - 38s 96ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 0.3727 - val_accuracy: 0.9246
#
# Epoch 00097: val_accuracy did not improve from 0.92580
#
# Epoch 00097: saving model to cnn-model_3.h5
# Epoch 98/200
# 390/390 [==============================] - 38s 96ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.3722 - val_accuracy: 0.9250
#
# Epoch 00098: val_accuracy did not improve from 0.92580
#
# Epoch 00098: saving model to cnn-model_3.h5
# Epoch 99/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0218 - accuracy: 0.9924 - val_loss: 0.3731 - val_accuracy: 0.9250
#
# Epoch 00099: val_accuracy did not improve from 0.92580
#
# Epoch 00099: saving model to cnn-model_3.h5
# Epoch 100/200
# 390/390 [==============================] - 38s 96ms/step - loss: 0.0234 - accuracy: 0.9917 - val_loss: 0.3719 - val_accuracy: 0.9250
#
# Epoch 00100: val_accuracy did not improve from 0.92580
#
# Epoch 00100: saving model to cnn-model_3.h5
# Epoch 101/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0208 - accuracy: 0.9926 - val_loss: 0.3727 - val_accuracy: 0.9252
#
# Epoch 00101: val_accuracy did not improve from 0.92580
#
# Epoch 00101: saving model to cnn-model_3.h5
# Epoch 102/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.3754 - val_accuracy: 0.9244
#
# Epoch 00102: val_accuracy did not improve from 0.92580
#
# Epoch 00102: saving model to cnn-model_3.h5
# Epoch 103/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0206 - accuracy: 0.9927 - val_loss: 0.3725 - val_accuracy: 0.9258
#
# Epoch 00103: val_accuracy did not improve from 0.92580
#
# Epoch 00103: saving model to cnn-model_3.h5
# Epoch 104/200
# 390/390 [==============================] - 38s 96ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.3718 - val_accuracy: 0.9260
#
# Epoch 00104: val_accuracy improved from 0.92580 to 0.92600, saving model to cnn-model_3-0104-0.926000.h5
#
# Epoch 00104: saving model to cnn-model_3.h5
# Epoch 105/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0215 - accuracy: 0.9928 - val_loss: 0.3753 - val_accuracy: 0.9244
#
# Epoch 00105: val_accuracy did not improve from 0.92600
#
# Epoch 00105: saving model to cnn-model_3.h5
# Epoch 106/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.3773 - val_accuracy: 0.9249
#
# Epoch 00106: val_accuracy did not improve from 0.92600
#
# Epoch 00106: saving model to cnn-model_3.h5
# Epoch 107/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0199 - accuracy: 0.9929 - val_loss: 0.3744 - val_accuracy: 0.9249
#
# Epoch 00107: val_accuracy did not improve from 0.92600
#
# Epoch 00107: saving model to cnn-model_3.h5
# Epoch 108/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0213 - accuracy: 0.9922 - val_loss: 0.3730 - val_accuracy: 0.9258
#
# Epoch 00108: val_accuracy did not improve from 0.92600
#
# Epoch 00108: saving model to cnn-model_3.h5
# Epoch 109/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0188 - accuracy: 0.9936 - val_loss: 0.3721 - val_accuracy: 0.9248
#
# Epoch 00109: val_accuracy did not improve from 0.92600
#
# Epoch 00109: saving model to cnn-model_3.h5
# Epoch 110/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.3765 - val_accuracy: 0.9251
#
# Epoch 00110: val_accuracy did not improve from 0.92600
#
# Epoch 00110: saving model to cnn-model_3.h5
# Epoch 111/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 0.3792 - val_accuracy: 0.9251
#
# Epoch 00111: val_accuracy did not improve from 0.92600
#
# Epoch 00111: saving model to cnn-model_3.h5
# Epoch 112/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0219 - accuracy: 0.9927 - val_loss: 0.3772 - val_accuracy: 0.9257
#
# Epoch 00112: val_accuracy did not improve from 0.92600
#
# Epoch 00112: saving model to cnn-model_3.h5
# Epoch 113/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 0.3796 - val_accuracy: 0.9249
#
# Epoch 00113: val_accuracy did not improve from 0.92600
#
# Epoch 00113: saving model to cnn-model_3.h5
# Epoch 114/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0217 - accuracy: 0.9927 - val_loss: 0.3792 - val_accuracy: 0.9251
#
# Epoch 00114: val_accuracy did not improve from 0.92600
#
# Epoch 00114: saving model to cnn-model_3.h5
# Epoch 115/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0204 - accuracy: 0.9926 - val_loss: 0.3784 - val_accuracy: 0.9250
#
# Epoch 00115: val_accuracy did not improve from 0.92600
#
# Epoch 00115: saving model to cnn-model_3.h5
# Epoch 116/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.3764 - val_accuracy: 0.9252
#
# Epoch 00116: val_accuracy did not improve from 0.92600
#
# Epoch 00116: saving model to cnn-model_3.h5
# Epoch 117/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0216 - accuracy: 0.9922 - val_loss: 0.3767 - val_accuracy: 0.9257
#
# Epoch 00117: val_accuracy did not improve from 0.92600
#
# Epoch 00117: saving model to cnn-model_3.h5
# Epoch 118/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0214 - accuracy: 0.9927 - val_loss: 0.3766 - val_accuracy: 0.9254
#
# Epoch 00118: val_accuracy did not improve from 0.92600
#
# Epoch 00118: saving model to cnn-model_3.h5
# Epoch 119/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0204 - accuracy: 0.9927 - val_loss: 0.3755 - val_accuracy: 0.9251
#
# Epoch 00119: val_accuracy did not improve from 0.92600
#
# Epoch 00119: saving model to cnn-model_3.h5
# Epoch 120/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.3737 - val_accuracy: 0.9254
#
# Epoch 00120: val_accuracy did not improve from 0.92600
#
# Epoch 00120: saving model to cnn-model_3.h5
# Epoch 121/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.3753 - val_accuracy: 0.9253
#
# Epoch 00121: val_accuracy did not improve from 0.92600
#
# Epoch 00121: saving model to cnn-model_3.h5
# Epoch 122/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0216 - accuracy: 0.9926 - val_loss: 0.3739 - val_accuracy: 0.9259
#
# Epoch 00122: val_accuracy did not improve from 0.92600
#
# Epoch 00122: saving model to cnn-model_3.h5
# Epoch 123/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0225 - accuracy: 0.9929 - val_loss: 0.3784 - val_accuracy: 0.9250
#
# Epoch 00123: val_accuracy did not improve from 0.92600
#
# Epoch 00123: saving model to cnn-model_3.h5
# Epoch 124/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0217 - accuracy: 0.9923 - val_loss: 0.3773 - val_accuracy: 0.9255
#
# Epoch 00124: val_accuracy did not improve from 0.92600
#
# Epoch 00124: saving model to cnn-model_3.h5
# Epoch 125/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.3805 - val_accuracy: 0.9256
#
# Epoch 00125: val_accuracy did not improve from 0.92600
#
# Epoch 00125: saving model to cnn-model_3.h5
# Epoch 126/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.3756 - val_accuracy: 0.9255
#
# Epoch 00126: val_accuracy did not improve from 0.92600
#
# Epoch 00126: saving model to cnn-model_3.h5
# Epoch 127/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.3783 - val_accuracy: 0.9254
#
# Epoch 00127: val_accuracy did not improve from 0.92600
#
# Epoch 00127: saving model to cnn-model_3.h5
# Epoch 128/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.3785 - val_accuracy: 0.9255
#
# Epoch 00128: val_accuracy did not improve from 0.92600
#
# Epoch 00128: saving model to cnn-model_3.h5
# Epoch 129/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0187 - accuracy: 0.9936 - val_loss: 0.3787 - val_accuracy: 0.9259
#
# Epoch 00129: val_accuracy did not improve from 0.92600
#
# Epoch 00129: saving model to cnn-model_3.h5
# Epoch 130/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.3801 - val_accuracy: 0.9256
#
# Epoch 00130: val_accuracy did not improve from 0.92600
#
# Epoch 00130: saving model to cnn-model_3.h5
# Epoch 131/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0202 - accuracy: 0.9933 - val_loss: 0.3814 - val_accuracy: 0.9257
#
# Epoch 00131: val_accuracy did not improve from 0.92600
#
# Epoch 00131: saving model to cnn-model_3.h5
# Epoch 132/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.3808 - val_accuracy: 0.9254
#
# Epoch 00132: val_accuracy did not improve from 0.92600
#
# Epoch 00132: saving model to cnn-model_3.h5
# Epoch 133/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0210 - accuracy: 0.9932 - val_loss: 0.3817 - val_accuracy: 0.9252
#
# Epoch 00133: val_accuracy did not improve from 0.92600
#
# Epoch 00133: saving model to cnn-model_3.h5
# Epoch 134/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0183 - accuracy: 0.9933 - val_loss: 0.3798 - val_accuracy: 0.9256
#
# Epoch 00134: val_accuracy did not improve from 0.92600
#
# Epoch 00134: saving model to cnn-model_3.h5
# Epoch 135/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0201 - accuracy: 0.9932 - val_loss: 0.3781 - val_accuracy: 0.9257
#
# Epoch 00135: val_accuracy did not improve from 0.92600
#
# Epoch 00135: saving model to cnn-model_3.h5
# Epoch 136/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.0213 - accuracy: 0.9925 - val_loss: 0.3813 - val_accuracy: 0.9258
#
# Epoch 00136: val_accuracy did not improve from 0.92600
#
# Epoch 00136: saving model to cnn-model_3.h5
# Epoch 137/200
# 390/390 [==============================] - 37s 96ms/step - loss: 0.0200 - accuracy: 0.9931 - val_loss: 0.3798 - val_accuracy: 0.9257
#
# Epoch 00137: val_accuracy did not improve from 0.92600
#
# Epoch 00137: saving model to cnn-model_3.h5
# Epoch 138/200
# 390/390 [==============================] - 38s 96ms/step - loss: 0.0195 - accuracy: 0.9932 - val_loss: 0.3792 - val_accuracy: 0.9260
#
# Epoch 00138: val_accuracy did not improve from 0.92600
#
# Epoch 00138: saving model to cnn-model_3.h5
# Epoch 139/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0206 - accuracy: 0.9933 - val_loss: 0.3787 - val_accuracy: 0.9258
#
# Epoch 00139: val_accuracy did not improve from 0.92600
#
# Epoch 00139: saving model to cnn-model_3.h5
# Epoch 140/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.0203 - accuracy: 0.9923 - val_loss: 0.3803 - val_accuracy: 0.9252
#
# Epoch 00140: val_accuracy did not improve from 0.92600
#
# Epoch 00140: saving model to cnn-model_3.h5
# Epoch 141/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.3793 - val_accuracy: 0.9256
#
# Epoch 00141: val_accuracy did not improve from 0.92600
#
# Epoch 00141: saving model to cnn-model_3.h5
# Epoch 142/200
# 390/390 [==============================] - 38s 98ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.3808 - val_accuracy: 0.9253
#
# Epoch 00142: val_accuracy did not improve from 0.92600
#
# Epoch 00142: saving model to cnn-model_3.h5
# Epoch 143/200
# 390/390 [==============================] - 38s 98ms/step - loss: 0.0197 - accuracy: 0.9936 - val_loss: 0.3803 - val_accuracy: 0.9258
#
# Epoch 00143: val_accuracy did not improve from 0.92600
#
# Epoch 00143: saving model to cnn-model_3.h5
# Epoch 144/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.0190 - accuracy: 0.9934 - val_loss: 0.3814 - val_accuracy: 0.9258
#
# Epoch 00144: val_accuracy did not improve from 0.92600
#
# Epoch 00144: saving model to cnn-model_3.h5
# Epoch 145/200
# 390/390 [==============================] - 38s 98ms/step - loss: 0.0211 - accuracy: 0.9927 - val_loss: 0.3793 - val_accuracy: 0.9256
#
# Epoch 00145: val_accuracy did not improve from 0.92600
#
# Epoch 00145: saving model to cnn-model_3.h5
# Epoch 146/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.0200 - accuracy: 0.9930 - val_loss: 0.3823 - val_accuracy: 0.9255
#
# Epoch 00146: val_accuracy did not improve from 0.92600
#
# Epoch 00146: saving model to cnn-model_3.h5
# Epoch 147/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.3824 - val_accuracy: 0.9253
#
# Epoch 00147: val_accuracy did not improve from 0.92600
#
# Epoch 00147: saving model to cnn-model_3.h5
# Epoch 148/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.3848 - val_accuracy: 0.9255
#
# Epoch 00148: val_accuracy did not improve from 0.92600
#
# Epoch 00148: saving model to cnn-model_3.h5
# Epoch 149/200
# 390/390 [==============================] - 38s 97ms/step - loss: 0.0204 - accuracy: 0.9933 - val_loss: 0.3851 - val_accuracy: 0.9251
#
# Epoch 00149: val_accuracy did not improve from 0.92600
#
# Epoch 00149: saving model to cnn-model_3.h5
# Epoch 150/200
# 390/390 [==============================] - 37s 95ms/step - loss: 0.0162 - accuracy: 0.9941 - val_loss: 0.3844 - val_accuracy: 0.9253
#
# Epoch 00150: val_accuracy did not improve from 0.92600
#
# Epoch 00150: saving model to cnn-model_3.h5
# Epoch 151/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0194 - accuracy: 0.9934 - val_loss: 0.3820 - val_accuracy: 0.9257
#
# Epoch 00151: val_accuracy did not improve from 0.92600
#
# Epoch 00151: saving model to cnn-model_3.h5
# Epoch 152/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0196 - accuracy: 0.9931 - val_loss: 0.3829 - val_accuracy: 0.9255
#
# Epoch 00152: val_accuracy did not improve from 0.92600
#
# Epoch 00152: saving model to cnn-model_3.h5
# Epoch 153/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0177 - accuracy: 0.9940 - val_loss: 0.3835 - val_accuracy: 0.9260
#
# Epoch 00153: val_accuracy did not improve from 0.92600
#
# Epoch 00153: saving model to cnn-model_3.h5
# Epoch 154/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0175 - accuracy: 0.9936 - val_loss: 0.3845 - val_accuracy: 0.9263
#
# Epoch 00154: val_accuracy improved from 0.92600 to 0.92630, saving model to cnn-model_3-0154-0.926300.h5
#
# Epoch 00154: saving model to cnn-model_3.h5
# Epoch 155/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.3826 - val_accuracy: 0.9261
#
# Epoch 00155: val_accuracy did not improve from 0.92630
#
# Epoch 00155: saving model to cnn-model_3.h5
# Epoch 156/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0212 - accuracy: 0.9923 - val_loss: 0.3817 - val_accuracy: 0.9265
#
# Epoch 00156: val_accuracy improved from 0.92630 to 0.92650, saving model to cnn-model_3-0156-0.926500.h5
#
# Epoch 00156: saving model to cnn-model_3.h5
# Epoch 157/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.3821 - val_accuracy: 0.9261
#
# Epoch 00157: val_accuracy did not improve from 0.92650
#
# Epoch 00157: saving model to cnn-model_3.h5
# Epoch 158/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0202 - accuracy: 0.9933 - val_loss: 0.3813 - val_accuracy: 0.9262
#
# Epoch 00158: val_accuracy did not improve from 0.92650
#
# Epoch 00158: saving model to cnn-model_3.h5
# Epoch 159/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.3825 - val_accuracy: 0.9263
#
# Epoch 00159: val_accuracy did not improve from 0.92650
#
# Epoch 00159: saving model to cnn-model_3.h5
# Epoch 160/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0178 - accuracy: 0.9934 - val_loss: 0.3816 - val_accuracy: 0.9265
#
# Epoch 00160: val_accuracy did not improve from 0.92650
#
# Epoch 00160: saving model to cnn-model_3.h5
# Epoch 161/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0202 - accuracy: 0.9927 - val_loss: 0.3840 - val_accuracy: 0.9264
#
# Epoch 00161: val_accuracy did not improve from 0.92650
#
# Epoch 00161: saving model to cnn-model_3.h5
# Epoch 162/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.3816 - val_accuracy: 0.9267
#
# Epoch 00162: val_accuracy improved from 0.92650 to 0.92670, saving model to cnn-model_3-0162-0.926700.h5
#
# Epoch 00162: saving model to cnn-model_3.h5
# Epoch 163/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.3838 - val_accuracy: 0.9262
#
# Epoch 00163: val_accuracy did not improve from 0.92670
#
# Epoch 00163: saving model to cnn-model_3.h5
# Epoch 164/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.3836 - val_accuracy: 0.9264
#
# Epoch 00164: val_accuracy did not improve from 0.92670
#
# Epoch 00164: saving model to cnn-model_3.h5
# Epoch 165/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.3838 - val_accuracy: 0.9264
#
# Epoch 00165: val_accuracy did not improve from 0.92670
#
# Epoch 00165: saving model to cnn-model_3.h5
# Epoch 166/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0182 - accuracy: 0.9935 - val_loss: 0.3870 - val_accuracy: 0.9257
#
# Epoch 00166: val_accuracy did not improve from 0.92670
#
# Epoch 00166: saving model to cnn-model_3.h5
# Epoch 167/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0186 - accuracy: 0.9936 - val_loss: 0.3852 - val_accuracy: 0.9260
#
# Epoch 00167: val_accuracy did not improve from 0.92670
#
# Epoch 00167: saving model to cnn-model_3.h5
# Epoch 168/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0179 - accuracy: 0.9932 - val_loss: 0.3852 - val_accuracy: 0.9257
#
# Epoch 00168: val_accuracy did not improve from 0.92670
#
# Epoch 00168: saving model to cnn-model_3.h5
# Epoch 169/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.3843 - val_accuracy: 0.9262
#
# Epoch 00169: val_accuracy did not improve from 0.92670
#
# Epoch 00169: saving model to cnn-model_3.h5
# Epoch 170/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0198 - accuracy: 0.9929 - val_loss: 0.3832 - val_accuracy: 0.9262
#
# Epoch 00170: val_accuracy did not improve from 0.92670
#
# Epoch 00170: saving model to cnn-model_3.h5
# Epoch 171/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 0.3866 - val_accuracy: 0.9259
#
# Epoch 00171: val_accuracy did not improve from 0.92670
#
# Epoch 00171: saving model to cnn-model_3.h5
# Epoch 172/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.3847 - val_accuracy: 0.9259
#
# Epoch 00172: val_accuracy did not improve from 0.92670
#
# Epoch 00172: saving model to cnn-model_3.h5
# Epoch 173/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.3849 - val_accuracy: 0.9263
#
# Epoch 00173: val_accuracy did not improve from 0.92670
#
# Epoch 00173: saving model to cnn-model_3.h5
# Epoch 174/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.3858 - val_accuracy: 0.9258
#
# Epoch 00174: val_accuracy did not improve from 0.92670
#
# Epoch 00174: saving model to cnn-model_3.h5
# Epoch 175/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.3828 - val_accuracy: 0.9270
#
# Epoch 00175: val_accuracy improved from 0.92670 to 0.92700, saving model to cnn-model_3-0175-0.927000.h5
#
# Epoch 00175: saving model to cnn-model_3.h5
# Epoch 176/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0196 - accuracy: 0.9929 - val_loss: 0.3858 - val_accuracy: 0.9261
#
# Epoch 00176: val_accuracy did not improve from 0.92700
#
# Epoch 00176: saving model to cnn-model_3.h5
# Epoch 177/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.3857 - val_accuracy: 0.9259
#
# Epoch 00177: val_accuracy did not improve from 0.92700
#
# Epoch 00177: saving model to cnn-model_3.h5
# Epoch 178/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0184 - accuracy: 0.9941 - val_loss: 0.3838 - val_accuracy: 0.9259
#
# Epoch 00178: val_accuracy did not improve from 0.92700
#
# Epoch 00178: saving model to cnn-model_3.h5
# Epoch 179/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 0.3813 - val_accuracy: 0.9266
#
# Epoch 00179: val_accuracy did not improve from 0.92700
#
# Epoch 00179: saving model to cnn-model_3.h5
# Epoch 180/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.3843 - val_accuracy: 0.9256
#
# Epoch 00180: val_accuracy did not improve from 0.92700
#
# Epoch 00180: saving model to cnn-model_3.h5
# Epoch 181/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.3847 - val_accuracy: 0.9263
#
# Epoch 00181: val_accuracy did not improve from 0.92700
#
# Epoch 00181: saving model to cnn-model_3.h5
# Epoch 182/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.3844 - val_accuracy: 0.9262
#
# Epoch 00182: val_accuracy did not improve from 0.92700
#
# Epoch 00182: saving model to cnn-model_3.h5
# Epoch 183/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.3873 - val_accuracy: 0.9252
#
# Epoch 00183: val_accuracy did not improve from 0.92700
#
# Epoch 00183: saving model to cnn-model_3.h5
# Epoch 184/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.3856 - val_accuracy: 0.9261
#
# Epoch 00184: val_accuracy did not improve from 0.92700
#
# Epoch 00184: saving model to cnn-model_3.h5
# Epoch 185/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0200 - accuracy: 0.9931 - val_loss: 0.3871 - val_accuracy: 0.9260
#
# Epoch 00185: val_accuracy did not improve from 0.92700
#
# Epoch 00185: saving model to cnn-model_3.h5
# Epoch 186/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.3870 - val_accuracy: 0.9256
#
# Epoch 00186: val_accuracy did not improve from 0.92700
#
# Epoch 00186: saving model to cnn-model_3.h5
# Epoch 187/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.3871 - val_accuracy: 0.9255
#
# Epoch 00187: val_accuracy did not improve from 0.92700
#
# Epoch 00187: saving model to cnn-model_3.h5
# Epoch 188/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.3875 - val_accuracy: 0.9257
#
# Epoch 00188: val_accuracy did not improve from 0.92700
#
# Epoch 00188: saving model to cnn-model_3.h5
# Epoch 189/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 0.3868 - val_accuracy: 0.9262
#
# Epoch 00189: val_accuracy did not improve from 0.92700
#
# Epoch 00189: saving model to cnn-model_3.h5
# Epoch 190/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.3859 - val_accuracy: 0.9261
#
# Epoch 00190: val_accuracy did not improve from 0.92700
#
# Epoch 00190: saving model to cnn-model_3.h5
# Epoch 191/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0189 - accuracy: 0.9933 - val_loss: 0.3854 - val_accuracy: 0.9258
#
# Epoch 00191: val_accuracy did not improve from 0.92700
#
# Epoch 00191: saving model to cnn-model_3.h5
# Epoch 192/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.3849 - val_accuracy: 0.9265
#
# Epoch 00192: val_accuracy did not improve from 0.92700
#
# Epoch 00192: saving model to cnn-model_3.h5
# Epoch 193/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0180 - accuracy: 0.9938 - val_loss: 0.3857 - val_accuracy: 0.9262
#
# Epoch 00193: val_accuracy did not improve from 0.92700
#
# Epoch 00193: saving model to cnn-model_3.h5
# Epoch 194/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 0.3881 - val_accuracy: 0.9260
#
# Epoch 00194: val_accuracy did not improve from 0.92700
#
# Epoch 00194: saving model to cnn-model_3.h5
# Epoch 195/200
# 390/390 [==============================] - 37s 94ms/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.3858 - val_accuracy: 0.9266
#
# Epoch 00195: val_accuracy did not improve from 0.92700
#
# Epoch 00195: saving model to cnn-model_3.h5
# Epoch 196/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 0.3855 - val_accuracy: 0.9268
#
# Epoch 00196: val_accuracy did not improve from 0.92700
#
# Epoch 00196: saving model to cnn-model_3.h5
# Epoch 197/200
# 390/390 [==============================] - 37s 93ms/step - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.3881 - val_accuracy: 0.9259
#
# Epoch 00197: val_accuracy did not improve from 0.92700
#
# Epoch 00197: saving model to cnn-model_3.h5
# Epoch 198/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.3886 - val_accuracy: 0.9263
#
# Epoch 00198: val_accuracy did not improve from 0.92700
#
# Epoch 00198: saving model to cnn-model_3.h5
# Epoch 199/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0188 - accuracy: 0.9935 - val_loss: 0.3878 - val_accuracy: 0.9257
#
# Epoch 00199: val_accuracy did not improve from 0.92700
#
# Epoch 00199: saving model to cnn-model_3.h5
# Epoch 200/200
# 390/390 [==============================] - 36s 93ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 0.3870 - val_accuracy: 0.9263
#
# Epoch 00200: val_accuracy did not improve from 0.92700
#
# Epoch 00200: saving model to cnn-model_3.h5
# Test loss: 0.3869576156139374
# Test accuracy: 0.9262999892234802
# Test error: 0.07370001077651978
